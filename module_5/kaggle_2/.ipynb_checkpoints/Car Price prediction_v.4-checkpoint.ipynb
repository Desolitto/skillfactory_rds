# %% [markdown]
# # Итоговое задание по Проекту 5. Выбираем авто выгодно
# ***
# ### Импорт библиотек

# %%
import numpy as np 
import pandas as pd
import re
import sys
import matplotlib.pyplot as plt
import seaborn as sns
import collections
# %matplotlib inline

from sklearn.feature_selection import f_classif
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, StandardScaler
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import BaggingRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, ExtraTreesRegressor
from sklearn.ensemble import GradientBoostingRegressor, AdaBoostRegressor
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from tqdm.notebook import tqdm
from sklearn.base import clone
from catboost import CatBoostRegressor
import os

# %%
RANDOM_SEED = 42
# !pip freeze > requirements.txt
CURRENT_DATE = pd.to_datetime('05/12/2020')

# %% [markdown]
# Зададим необходимые функции сразу

# %%
def IQRhist(col):
    dft = (df.loc[df['Train'] == 1][col])
    median = dft.median()
    perc25 = dft.quantile(0.25)
    perc75 = dft.quantile(0.75)
    IQR = perc75 - perc25
    print('25-й перцентиль: {},'.format(round(perc25,4)), '75-й перцентиль: {},'.format(round(perc75,4)),
          "IQR: {}, ".format(round(IQR,4)), "Границы выбросов: [{f}, {l}].".format(f=round(perc25 - 1.5*IQR,4), l=round(perc75 + 1.5*IQR,4)))
    out_count = dft.apply(
        lambda x: None if x < perc25 - 1.5*IQR or x > perc75 + 1.5*IQR else x).isna().sum()
    print(f'Кол-во выбросов = {out_count}, Процент выбросов среди тренировочного датасета {round((out_count/len(dft)*100),2)}')
    df[col].loc[df[col].between(perc25 - 1.5*IQR, perc75 + 1.5*IQR)].hist(bins=10, range=(dft.min()-5, dft.max()+5),
                                                                          label='IQR')

    plt.legend()

# Для удобства зададим функцию, которая создаст отдельный датафрейм с этими признаками для сравнения
def check_df(df1,df2):
    '''
    Функция создает отдельный датафрейм с признаками: название,количество уникальных значений, их тип, содержание.
    А так же показывает несоответствие признаков
    '''
    ## Соберем данные по первому датасету
    list_tags_1 = list(df1.columns)
    temp_dict = {}
    temp_dict['Уникальность_1'] = df1.nunique().values
    temp_dict['Первая_строка_1'] =df1.loc[0].values
    temp_dict['тип_1'] = df1.dtypes
    temp_dict['Признак_1'] = list_tags_1
    temp_df1 = pd.DataFrame.from_dict(temp_dict)
    
    ## Соберем данные по второму датасету
    list_tags_2 = list(df2.columns)
    temp_dict2 = {}
    temp_dict2['Признак_2'] = list_tags_2
    temp_dict2['тип_2'] = df2.dtypes
    temp_dict2['Первая_строка_2'] =df2.loc[0].values
    temp_dict2['Уникальность_2'] = df2.nunique().values
    temp_df2 = pd.DataFrame.from_dict(temp_dict2)
    
    ##объеденим датасеты
    temp_df = pd.concat([temp_df1,temp_df2], axis=1, sort=False)
    temp_df.reset_index(inplace = True)
    del temp_df['index']
    display(temp_df)
    
    ## Создадим словари для сравнения данных
    temp_dict3 = {}
    temp_df3= pd.DataFrame(temp_df)
    temp_list  = []
    temp_list2  = []
    temp_list3  = []
    temp_list4  = []
    temp_list5  = []

    for i in range(len(temp_df)):
        if str(temp_df3['тип_2'][i]) != str(temp_df3['тип_1'][i]):
            temp_list.append(temp_df3['Признак_1'][i])
            temp_list2.append(temp_df3['Признак_2'][i])
            temp_list3.append(str(temp_df3['тип_1'][i]) + ' != ' + str(temp_df3['тип_2'][i]))
            temp_list4.append(i)
        
    ## Создаем сравнительный датасет
    temp_dict3['index']= temp_list4
    temp_dict3['Признак_1']= temp_list
    temp_dict3['Отличие'] = temp_list3
    temp_dict3['Признак_2']= temp_list2

    temp_df4 = pd.DataFrame.from_dict(temp_dict3)
    temp_df4.set_index('index',inplace=True)

    print(f'Вывод:\n 1. Не совпали типы в {len(temp_df4)} столбцах:')
    display(temp_df4)

    return

#Функция анализа признаков
def describe_cols(df):
    list_ = list(df.columns)
    temp_dict = {}
    temp_dict['Признак'] = list_
    temp_dict['Тип'] = df.dtypes
    temp_dict['Кол-во значений'] = df.describe(include='all').loc['count']
    temp_dict['Кол-во пропусков(NaN)'] = df.isnull().sum().values 
    temp_dict['Кол-во уникальных'] = df.nunique().values
    temp_df = pd.DataFrame.from_dict(temp_dict, orient='index')
    display(temp_df.T)

    return

# %%
print(os.listdir('./'))
# Out:
# ['.ipynb_checkpoints', 'all_auto_ru3.csv', 'all_auto_ru3.rar', 'all_auto_ru4.csv', 'all_auto_ru4.rar', 'all_car_brands_and_their_models_from_auto_ru.csv', 'Car Price prediction_v.4.ipynb', 'catboost_info', 'catboost_single_model_baseline.model', 'parser-Copy4.ipynb', 'requirements.txt', 'sample_submission.csv', 'sf-dst-car-price-prediction.zip', 'test.csv']

# %% [markdown]
# ### Импорт данных

# %%
from importlib import reload
print(os.listdir('./'))
DIR_TRAIN  = '../' # подключил к ноутбуку свой внешний датасет
DIR_TEST   = '../'
# Out:
# ['.ipynb_checkpoints', 'all_auto_ru3.csv', 'all_auto_ru3.rar', 'all_auto_ru4.csv', 'all_auto_ru4.rar', 'all_car_brands_and_their_models_from_auto_ru.csv', 'Car Price prediction_v.4.ipynb', 'catboost_info', 'catboost_single_model_baseline.model', 'parser-Copy4.ipynb', 'requirements.txt', 'sample_submission.csv', 'sf-dst-car-price-prediction.zip', 'test.csv']

# %%
train = pd.read_csv('all_auto_ru4.csv')
test = pd.read_csv('test.csv')
submit = pd.read_csv('sample_submission.csv')
pd.set_option('display.max_columns', None)
print('Размерность тренировочного датасета: ', train.shape)
display(train.head(2))
print('Размерность тестового датасета: ', test.shape)
display(test.head(2))
print('Размерность датасета c примером сабмишена: ', submit.shape)
display(submit.head(2))
# Out:
# Размерность тренировочного датасета:  (84370, 26)
#   bodyType brand   color fuelType  modelDate                    name  \
# 0    Седан  AUDI  040001   бензин     2011.0  3.0 AMT (300 л.с.) 4WD
# 1    Седан  AUDI  FAFBFB   бензин     1997.0       2.4 AT (165 л.с.)
#
#    numberOfDoors  productionDate vehicleConfiguration vehicleTransmission  \
# 0            4.0            2012      SEDAN ROBOT 3.0               ROBOT
# 1            4.0            2000  SEDAN AUTOMATIC 2.4           AUTOMATIC
#
#   engineDisplacement  enginePower  \
# 0                3.0        300.0
# 1                2.4        165.0
#
#                                          description  mileage    Привод  Руль  \
# 0  Всем доброго времени суток! Вашему вниманию пр...   224000    полный  LEFT
# 1  Автомобиль не гнилой, обслуживался своевременн...   240000  передний  LEFT
#
#    Состояние  Владельцы        ПТС  Таможня                    Владение  \
# 0        NaN        3.0  DUPLICATE     True  {'year': 2018, 'month': 8}
# 1        NaN        3.0   ORIGINAL     True                         NaN
#
#        price                                     equipment_dict  hidden  \
# 0  1300000.0  {'asr': True, 'tinted-glass': True, 'esp': Tru...   False
# 1   240000.0  {'cruise-control': True, 'asr': True, 'tinted-...   False
#
#      vendor model
# 0  EUROPEAN    A6
# 1  EUROPEAN    A6
# Размерность тестового датасета:  (34686, 32)
#   bodyType  brand                                            car_url   color  \
# 0  лифтбек  SKODA  https://auto.ru/cars/used/sale/skoda/octavia/1...   синий
# 1  лифтбек  SKODA  https://auto.ru/cars/used/sale/skoda/octavia/1...  чёрный
#
#   complectation_dict                                        description  \
# 0                NaN  Все автомобили, представленные в продаже, прох...
# 1                NaN  ЛОТ: 01217195\nАвтопрага Север\nДанный автомоб...
#
#   engineDisplacement enginePower  \
# 0            1.2 LTR     105 N12
# 1            1.6 LTR     110 N12
#
#                                       equipment_dict fuelType  \
# 0  {"engine-proof":true,"tinted-glass":true,"airb...   бензин
# 1  {"cruise-control":true,"asr":true,"esp":true,"...   бензин
#
#                                                image  mileage  modelDate  \
# 0  https://autoru.naydex.net/o9DBXQ270/5ac010hAY0...    74000       2013
# 1  https://autoru.naydex.net/o9DBXQ270/5ac010hAY0...    60563       2017
#
#                                           model_info model_name  \
# 0  {"code":"OCTAVIA","name":"Octavia","ru_name":"...    OCTAVIA
# 1  {"code":"OCTAVIA","name":"Octavia","ru_name":"...    OCTAVIA
#
#                  name  numberOfDoors  parsing_unixtime priceCurrency  \
# 0  1.2 AMT (105 л.с.)              5        1603226273           RUB
# 1   1.6 MT (110 л.с.)              5        1603226277           RUB
#
#    productionDate     sell_id  \
# 0            2014  1100575026
# 1            2017  1100549428
#
#                                            super_gen     vehicleConfiguration  \
# 0  {"id":"10373605","displacement":1197,"engine_t...       LIFTBACK ROBOT 1.2
# 1  {"id":"20913311","displacement":1598,"engine_t...  LIFTBACK MECHANICAL 1.6
#
#   vehicleTransmission    vendor    Владельцы Владение       ПТС    Привод  \
# 0    роботизированная  EUROPEAN  3 или более      NaN  Оригинал  передний
# 1        механическая  EUROPEAN   1 владелец      NaN  Оригинал  передний
#
#     Руль           Состояние     Таможня
# 0  Левый  Не требует ремонта  Растаможен
# 1  Левый  Не требует ремонта  Растаможен
# Размерность датасета c примером сабмишена:  (34686, 2)
#       sell_id  price
# 0  1100575026      0
# 1  1100549428      0

# %% [markdown]
# ### Первичная обработка датасетов

# %% [markdown]
# #### Для начала сравним датасеты

# %% [markdown]
# Рассмотрим каждую колонку:
#     - её название,
#     - количество уникальных значений,
#     - её тип,
#     - её содержание.
# И проверим их различие

# %%
check_df(train, test)
# Out:
#     Уникальность_1                                    Первая_строка_1  \
# 0            160.0                                              Седан
# 1             36.0                                               AUDI
# 2             16.0                                             040001
# 3              7.0                                             бензин
# 4             74.0                                               2011
# 5           3866.0                             3.0 AMT (300 л.с.) 4WD
# 6              5.0                                                  4
# 7             71.0                                               2012
# 8           1598.0                                    SEDAN ROBOT 3.0
# 9              4.0                                              ROBOT
# 10           468.0                                                3.0
# 11           378.0                                                300
# 12         48461.0  Всем доброго времени суток! Вашему вниманию пр...
# 13         16608.0                                             224000
# 14             3.0                                             полный
# 15             2.0                                               LEFT
# 16             0.0                                                NaN
# 17             3.0                                                  3
# 18             2.0                                          DUPLICATE
# 19             1.0                                               True
# 20           277.0                         {'year': 2018, 'month': 8}
# 21          8197.0                                            1.3e+06
# 22         38266.0  {'asr': True, 'tinted-glass': True, 'esp': Tru...
# 23             1.0                                              False
# 24             6.0                                           EUROPEAN
# 25          1030.0                                                 A6
# 26             NaN                                                NaN
# 27             NaN                                                NaN
# 28             NaN                                                NaN
# 29             NaN                                                NaN
# 30             NaN                                                NaN
# 31             NaN                                                NaN
# 32             NaN                                                NaN
# 33             NaN                                                NaN
# 34             NaN                                                NaN
#
#       тип_1             Признак_1             Признак_2   тип_2  \
# 0    object              bodyType              bodyType  object
# 1    object                 brand                 brand  object
# 2    object                 color                 color  object
# 3    object              fuelType              fuelType  object
# 4   float64             modelDate             modelDate   int64
# 5    object                  name                  name  object
# 6   float64         numberOfDoors         numberOfDoors   int64
# 7     int64        productionDate        productionDate   int64
# 8    object  vehicleConfiguration  vehicleConfiguration  object
# 9    object   vehicleTransmission   vehicleTransmission  object
# 10   object    engineDisplacement    engineDisplacement  object
# 11  float64           enginePower           enginePower  object
# 12   object           description           description  object
# 13    int64               mileage               mileage   int64
# 14   object                Привод                Привод  object
# 15   object                  Руль                  Руль  object
# 16  float64             Состояние             Состояние  object
# 17  float64             Владельцы             Владельцы  object
# 18   object                   ПТС                   ПТС  object
# 19     bool               Таможня               Таможня  object
# 20   object              Владение              Владение  object
# 21  float64                 price                   NaN     NaN
# 22   object        equipment_dict        equipment_dict  object
# 23     bool                hidden                   NaN     NaN
# 24   object                vendor                vendor  object
# 25   object                 model                   NaN     NaN
# 26      NaN                   NaN               car_url  object
# 27      NaN                   NaN    complectation_dict  object
# 28      NaN                   NaN                 image  object
# 29      NaN                   NaN            model_info  object
# 30      NaN                   NaN            model_name  object
# 31      NaN                   NaN      parsing_unixtime   int64
# 32      NaN                   NaN         priceCurrency  object
# 33      NaN                   NaN               sell_id   int64
# 34      NaN                   NaN             super_gen  object
#
#                                       Первая_строка_2  Уникальность_2
# 0                                             лифтбек            24.0
# 1                                               SKODA            12.0
# 2                                               синий            16.0
# 3                                              бензин             5.0
# 4                                                2013            66.0
# 5                                  1.2 AMT (105 л.с.)          2780.0
# 6                                                   5             5.0
# 7                                                2014            69.0
# 8                                  LIFTBACK ROBOT 1.2           634.0
# 9                                    роботизированная             4.0
# 10                                            1.2 LTR            55.0
# 11                                            105 N12           315.0
# 12  Все автомобили, представленные в продаже, прох...         31732.0
# 13                                              74000         11268.0
# 14                                           передний             3.0
# 15                                              Левый             2.0
# 16                                 Не требует ремонта             1.0
# 17                                        3 или более             3.0
# 18                                           Оригинал             2.0
# 19                                         Растаможен             1.0
# 20                                                NaN           275.0
# 21                                                NaN             NaN
# 22  {"engine-proof":true,"tinted-glass":true,"airb...         23705.0
# 23                                                NaN             NaN
# 24                                           EUROPEAN             2.0
# 25                                                NaN             NaN
# 26  https://auto.ru/cars/used/sale/skoda/octavia/1...         34686.0
# 27                                                NaN          2364.0
# 28  https://autoru.naydex.net/o9DBXQ270/5ac010hAY0...         34557.0
# 29  {"code":"OCTAVIA","name":"Octavia","ru_name":"...           954.0
# 30                                            OCTAVIA           544.0
# 31                                         1603226273         34686.0
# 32                                                RUB             1.0
# 33                                         1100575026         34686.0
# 34  {"id":"10373605","displacement":1197,"engine_t...          5890.0
# Вывод:
#  1. Не совпали типы в 18 столбцах:
#            Признак_1            Отличие           Признак_2
# index
# 4          modelDate   float64 != int64           modelDate
# 6      numberOfDoors   float64 != int64       numberOfDoors
# 11       enginePower  float64 != object         enginePower
# 16         Состояние  float64 != object           Состояние
# 17         Владельцы  float64 != object           Владельцы
# 19           Таможня     bool != object             Таможня
# 21             price     float64 != nan                 NaN
# 23            hidden        bool != nan                 NaN
# 25             model      object != nan                 NaN
# 26               NaN      nan != object             car_url
# 27               NaN      nan != object  complectation_dict
# 28               NaN      nan != object               image
# 29               NaN      nan != object          model_info
# 30               NaN      nan != object          model_name
# 31               NaN       nan != int64    parsing_unixtime
# 32               NaN      nan != object       priceCurrency
# 33               NaN       nan != int64             sell_id
# 34               NaN      nan != object           super_gen

# %% [markdown]
# ##### Промежуточный итог:
# Видно что в 18 столбцах различаются типы значений,
# 3 столбцов нет в тестовом датасете и 15 в тренировочном.
#
# 1.Приведем столбцы типа int64 к float64, поскольку мы еще подробно не исследовали датасет,
# и не знаем какие значения могут принимать параметры.
#
# 2.Так же для столбцов с отличиями: float64 != object, bool != object
# изменим тип на object.

# %%
#1
change_type = ['productionDate', 'mileage','modelDate','numberOfDoors']
for col in change_type:
        train[col] = train[col].astype('float64')

# %%
#2
change_type = ['enginePower', 'Состояние', 'Владельцы']
for col in change_type:
        train[col] = train[col].astype('object')

# %%
#Типом bool оказался признак Таможня, он принмает значения True/False,  
#в тестовом он задан как Растаможен/Не растаможен
#Пока что приведем данный признак к значеним тестового датасета
#train['Таможня'] = train['Таможня'].map({True: 'Растаможен', False:'Не растаможен'})
train['Таможня'].value_counts()
# Out:
# True    84370
# Name: Таможня, dtype: int64

# %% [markdown]
# ### Итог:
# ---
# Как уже было сказано 3 столбцов нет в тестовом датасете и 15 в тренировочном.
#
# В тестовом нет целевой переменной, поскольку ее требуется определить.
# А так же отсутствуют признаки hidden, model, но есть признаки model_info и model_name, так что скорее всего просто можно будет преобрзоавать в один признак
# Пока что оставим их и попробуем добавить их в тестовый датасет.
#
# В тренировочном отсутствует столбцец sell_id, который нам будет нужен для формирования файла submition.
# car_url, complectation_dict, image ,parsing_unixtime, priceCurrency, super_gen

# %% [markdown]
# ### Обработка данных перед слиянием

# %% [markdown]
# Признак bodyType отличается регистром в обоих датасетах
# Приведем тренировочный датасет к нижнему регистру

# %%
train['bodyType'] = train['bodyType'].apply(lambda x: str(x).lower())
train['bodyType'].value_counts()[:5]
# Out:
# внедорожник 5 дв.    37405
# седан                23111
# хэтчбек 5 дв.         6492
# минивэн               2835
# лифтбек               2730
# Name: bodyType, dtype: int64

# %%
train['color'].value_counts()
# Out:
# 040001    24281
# FAFBFB    15523
# 97948F    11631
# CACECB     8762
# 0000CC     7889
# EE1D19     4431
# 200204     3542
# 007F00     2131
# C49648     2009
# 22A0F8     1546
# 660099      732
# FF8649      541
# FFD600      525
# DEA522      449
# 4A2197      362
# FFC0CB       16
# Name: color, dtype: int64

# %%
test['color'].value_counts()
# Out:
# чёрный         11010
# белый           6133
# серебристый     4113
# серый           3984
# синий           3289
# красный         1531
# коричневый      1501
# зелёный          952
# бежевый          639
# голубой          457
# золотистый       266
# пурпурный        254
# фиолетовый       219
# жёлтый           194
# оранжевый        131
# розовый           13
# Name: color, dtype: int64

# %% [markdown]
# Признак color в тренировочном датасете указан в шестнадцатеричном коде цветов.
# Но их всего 16 поэтому приведм коды к значениям цветов.

# %%
test['color'].value_counts()[:5]
# Out:
# чёрный         11010
# белый           6133
# серебристый     4113
# серый           3984
# синий           3289
# Name: color, dtype: int64

# %%
dict_color = {'040001':'чёрный', 'EE1D19':'красный', '0000CC':'синий', 
              'CACECB':'серебристый', '007F00':'зелёный', 'FAFBFB':'белый', 
              '97948F':'серый', '22A0F8':'голубой', '660099':'пурпурный', 
              '200204':'коричневый', 'C49648':'бежевый', 'DEA522':'золотистый', 
              '4A2197':'фиолетовый', 'FFD600':'жёлтый', 'FF8649':'оранжевый', 
              'FFC0CB':'розовый'}
train['color'] = train['color'].map(dict_color)

# %%
train['color'].value_counts()[:5]
# Out:
# чёрный         24281
# белый          15523
# серый          11631
# серебристый     8762
# синий           7889
# Name: color, dtype: int64

# %%
train['vehicleTransmission'].value_counts()
# Out:
# AUTOMATIC     48211
# MECHANICAL    20180
# ROBOT          8679
# VARIATOR       7298
# Name: vehicleTransmission, dtype: int64

# %%
test['vehicleTransmission'].value_counts()
# Out:
# автоматическая      19596
# механическая         7209
# вариатор             3999
# роботизированная     3882
# Name: vehicleTransmission, dtype: int64

# %% [markdown]
# Признак vehicleTransmission - тип трасмиссии, приведем к виду тестового датасета

# %%
train['vehicleTransmission'] = train['vehicleTransmission'].map(
    {'MECHANICAL': 'механическая', 'AUTOMATIC': 'автоматическая', 'ROBOT': 'роботизированная', 'VARIATOR': 'вариатор'})
train['vehicleTransmission'].value_counts()
# Out:
# автоматическая      48211
# механическая        20180
# роботизированная     8679
# вариатор             7298
# Name: vehicleTransmission, dtype: int64

# %% [markdown]
# Признак руль приведем к виду тестового датасета

# %%
train['Руль'] = train['Руль'].map({'RIGHT':'Правый', 'LEFT':'Левый'})
train['Руль'].value_counts()
# Out:
# Левый     83144
# Правый     1226
# Name: Руль, dtype: int64

# %% [markdown]
# Признак ПТС приведем к виду тестового датасета

# %%
train['ПТС'] = train['ПТС'].map({'ORIGINAL':'Оригинал', 'DUPLICATE':'Дубликат'})
train['ПТС'].value_counts()
# Out:
# Оригинал    76302
# Дубликат     7014
# Name: ПТС, dtype: int64

# %%
display(train['Владельцы'].value_counts())
display(test['Владельцы'].value_counts())
# Out:
# 3.0    25901
# 1.0    21847
# 2.0    17814
# Name: Владельцы, dtype: int64
# 3 или более    15957
# 1 владелец      9459
# 2 владельца     9270
# Name: Владельцы, dtype: int64

# %% [markdown]
# Признак Владельцы приведем к виду тестового датасета

# %%
train['Владельцы'] = train['Владельцы'].map({3.0:'3 или более', 2.0:'2 владельца', 1.0:'1 владелец'})
display(train['Владельцы'].value_counts())
# Out:
# 3 или более    25901
# 1 владелец     21847
# 2 владельца    17814
# Name: Владельцы, dtype: int64

# %%
display(train['Владение'].value_counts()[:5])
display(test['Владение'].value_counts()[:5])
# Out:
# {'year': 2019, 'month': 5}     405
# {'year': 2018, 'month': 11}    333
# {'year': 2018, 'month': 6}     327
# {'year': 2017, 'month': 11}    294
# {'year': 2018, 'month': 12}    287
# Name: Владение, dtype: int64
# 1 год и 10 месяцев    209
# 2 года                197
# 1 год                 194
# 1 год и 1 месяц       193
# 1 год и 2 месяца      187
# Name: Владение, dtype: int64

# %% [markdown]
# Признак Владение - в таблице сверху в первых строках Nan поэтому нужно отдельно проверить,
# Данные записаны в различном формате в разных датасетах, оставим до этапа анализа

# %% [markdown]
# Признак model и model_name тренировочного и тестового датасета несут одну и ту же информацию,
# Объеденим их под названием model_name

# %%
train['model_name'] = train['model']
train.drop(['model'], axis = 1, inplace = True)

# %% [markdown]
# ### Итог
# Несоответсвие  осталось только в столбцах -
# Владение, car_url, complectation_dict, image ,parsing_unixtime, priceCurrency, sell_id, super_gen
# Вернемся к данным признаку позже в детальном анализе

# %%
# удаляем дубликаты
before_drop = len(train)

train = train.drop_duplicates()
after_drop = len(train)
print(f'Кол-во дубликатов: , {before_drop-after_drop}')
print('Кол-во строк в трейне было: ', before_drop)
print('Кол-во строк в трейне стало: ', after_drop)
# Out:
# Кол-во дубликатов: , 26499
# Кол-во строк в трейне было:  84370
# Кол-во строк в трейне стало:  57871

# %% [markdown]
# ### Слияние датасетов в один

# %%
# ВАЖНО! для корректной обработки признаков объединяем трейн и тест в один датасет
train['Train'] = 1 # помечаем где у нас трейн
test['Train'] = 0 # помечаем где у нас тест

df = train.append(test, sort=False).reset_index(drop=True) # объединяем

# %%
# проверка  после слияния
df.head(2)
# Out:
#   bodyType brand   color fuelType  modelDate                    name  \
# 0    седан  AUDI  чёрный   бензин     2011.0  3.0 AMT (300 л.с.) 4WD
# 1    седан  AUDI   белый   бензин     1997.0       2.4 AT (165 л.с.)
#
#    numberOfDoors  productionDate vehicleConfiguration vehicleTransmission  \
# 0            4.0          2012.0      SEDAN ROBOT 3.0    роботизированная
# 1            4.0          2000.0  SEDAN AUTOMATIC 2.4      автоматическая
#
#   engineDisplacement enginePower  \
# 0                3.0         300
# 1                2.4         165
#
#                                          description   mileage    Привод  \
# 0  Всем доброго времени суток! Вашему вниманию пр...  224000.0    полный
# 1  Автомобиль не гнилой, обслуживался своевременн...  240000.0  передний
#
#     Руль Состояние    Владельцы       ПТС Таможня                    Владение  \
# 0  Левый       NaN  3 или более  Дубликат    True  {'year': 2018, 'month': 8}
# 1  Левый       NaN  3 или более  Оригинал    True                         NaN
#
#        price                                     equipment_dict hidden  \
# 0  1300000.0  {'asr': True, 'tinted-glass': True, 'esp': Tru...  False
# 1   240000.0  {'cruise-control': True, 'asr': True, 'tinted-...  False
#
#      vendor model_name  Train car_url complectation_dict image model_info  \
# 0  EUROPEAN         A6      1     NaN                NaN   NaN        NaN
# 1  EUROPEAN         A6      1     NaN                NaN   NaN        NaN
#
#    parsing_unixtime priceCurrency  sell_id super_gen
# 0               NaN           NaN      NaN       NaN
# 1               NaN           NaN      NaN       NaN

# %%
df.shape
# Out:
# (92557, 35)

# %% [markdown]
# ### Предварительный анализ данных

# %%
def describe_cols(df):
    list_ = list(df.columns)
    temp_dict = {}
    temp_dict['Признак'] = list_
    temp_dict['Тип'] = df.dtypes
    temp_dict['Кол-во значений'] = df.describe(include='all').loc['count']
    temp_dict['Кол-во пропусков(NaN)'] = df.isnull().sum().values 
    temp_dict['Кол-во уникальных'] = df.nunique().values
    temp_df = pd.DataFrame.from_dict(temp_dict, orient='index')
    display(temp_df.T)

    return

# %%
describe_cols(df[df['Train']==1])
# Out:
#                  Признак      Тип Кол-во значений Кол-во пропусков(NaN)  \
# 0               bodyType   object           57871                     0
# 1                  brand   object           57871                     0
# 2                  color   object           57871                     0
# 3               fuelType   object           57871                     0
# 4              modelDate  float64           57869                     2
# 5                   name   object           57869                     2
# 6          numberOfDoors  float64           57869                     2
# 7         productionDate  float64           57871                     0
# 8   vehicleConfiguration   object           57869                     2
# 9    vehicleTransmission   object           57869                     2
# 10    engineDisplacement   object           57869                     2
# 11           enginePower   object           57869                     2
# 12           description   object           55770                  2101
# 13               mileage  float64           57871                     0
# 14                Привод   object           57869                     2
# 15                  Руль   object           57871                     0
# 16             Состояние   object               0                 57871
# 17             Владельцы   object           47356                 10515
# 18                   ПТС   object           57523                   348
# 19               Таможня   object           57871                     0
# 20              Владение   object           14340                 43531
# 21                 price  float64           57668                   203
# 22        equipment_dict   object           57871                     0
# 23                hidden   object           57871                     0
# 24                vendor   object           57871                     0
# 25            model_name   object           57871                     0
# 26                 Train    int64           57871                     0
# 27               car_url   object               0                 57871
# 28    complectation_dict   object               0                 57871
# 29                 image   object               0                 57871
# 30            model_info   object               0                 57871
# 31      parsing_unixtime  float64               0                 57871
# 32         priceCurrency   object               0                 57871
# 33               sell_id  float64               0                 57871
# 34             super_gen   object               0                 57871
#
#    Кол-во уникальных
# 0                159
# 1                 36
# 2                 16
# 3                  7
# 4                 74
# 5               3866
# 6                  5
# 7                 71
# 8               1598
# 9                  4
# 10               468
# 11               378
# 12             48461
# 13             16608
# 14                 3
# 15                 2
# 16                 0
# 17                 3
# 18                 2
# 19                 1
# 20               277
# 21              8197
# 22             38266
# 23                 1
# 24                 6
# 25              1030
# 26                 1
# 27                 0
# 28                 0
# 29                 0
# 30                 0
# 31                 0
# 32                 0
# 33                 0
# 34                 0

# %%
describe_cols(df[df['Train']==0])
# Out:
#                  Признак      Тип Кол-во значений Кол-во пропусков(NaN)  \
# 0               bodyType   object           34686                     0
# 1                  brand   object           34686                     0
# 2                  color   object           34686                     0
# 3               fuelType   object           34686                     0
# 4              modelDate  float64           34686                     0
# 5                   name   object           34686                     0
# 6          numberOfDoors  float64           34686                     0
# 7         productionDate  float64           34686                     0
# 8   vehicleConfiguration   object           34686                     0
# 9    vehicleTransmission   object           34686                     0
# 10    engineDisplacement   object           34686                     0
# 11           enginePower   object           34686                     0
# 12           description   object           34686                     0
# 13               mileage  float64           34686                     0
# 14                Привод   object           34686                     0
# 15                  Руль   object           34686                     0
# 16             Состояние   object           34686                     0
# 17             Владельцы   object           34686                     0
# 18                   ПТС   object           34685                     1
# 19               Таможня   object           34686                     0
# 20              Владение   object           11995                 22691
# 21                 price  float64               0                 34686
# 22        equipment_dict   object           24690                  9996
# 23                hidden   object               0                 34686
# 24                vendor   object           34686                     0
# 25            model_name   object           34686                     0
# 26                 Train    int64           34686                     0
# 27               car_url   object           34686                     0
# 28    complectation_dict   object            6418                 28268
# 29                 image   object           34686                     0
# 30            model_info   object           34686                     0
# 31      parsing_unixtime  float64           34686                     0
# 32         priceCurrency   object           34686                     0
# 33               sell_id  float64           34686                     0
# 34             super_gen   object           34686                     0
#
#    Кол-во уникальных
# 0                 24
# 1                 12
# 2                 16
# 3                  5
# 4                 66
# 5               2780
# 6                  5
# 7                 69
# 8                634
# 9                  4
# 10                55
# 11               315
# 12             31732
# 13             11268
# 14                 3
# 15                 2
# 16                 1
# 17                 3
# 18                 2
# 19                 1
# 20               275
# 21                 0
# 22             23705
# 23                 0
# 24                 2
# 25               544
# 26                 1
# 27             34686
# 28              2364
# 29             34557
# 30               954
# 31             34686
# 32                 1
# 33             34686
# 34              5890

# %% [markdown]
# ### ИТОГ
# ---
# В тренировочной выборке 84370 строк, в тестовой 34686. Всего данных - 119056 строк.
# Всего 34 признаков, из них:
# В тестовом - 31, из них:
# 6 - числовых - mileage, modelDate, productionDate,numberOfDoors,
# sell_id(для генерации submition), parsing_unixtime
# 28 - категориальных (возможно часть из них станен числовыми при полном анализе),
#
# 2 признака были добавлены от тренировочного:
# 1- числовой - price,
# 1 - бинарный - hidden,
# и 1 - бинарный Train - для разделения train и test

# %% [markdown]
# ### Описания полей датасета
#
# - bodyType - тип кузова автомобиля
# - brand - марка (бренд) автомобиля
# - color - цвет автомобиля
# - fuelType - тип топлива
# - modelDate - дата выпуска модели
# - name - комбинация нескольких характеристик (модели, объема двигателя и привода)
# - numberOfDoors - кол-во дверей
# - productionDate - дата производства авто
# - vehicleConfiguration - комбинация типа кузова автомобиля, типа трансмиссии и объема двигателя
# - vehicleTransmission - тип трансмиссии (коробки передач)
# - engineDisplacement - объем двигателя в литрах
# - enginePower - мощность двигателя (л.с.)
# - description - дополнительные характеристики по комплектации авто
# - mileage - пробег автомобиля (км.)
# - Комплектация - дополнительные характеристики по комплектации авто
# - Привод - характеристика привода автомобиля, которое передает энергию от двигателя на колеса.
# - Руль - характеристика руля по стороне расположения руля в автомобиле
# - Состояние - характеристика необходимости проведения ремонта
# - Владельцы - кол-во владельцев (3 значения: 1 владелец, 2 владельца, 3 и более)
# - ПТС - тип ПТС (паспорт технического средства)
# - Таможня - информация о том расстаможен автомобиль или нет (2 значения - Растаможен, Не ратаможен)
# - Владение - срок владения автомобилем в годах и месяцах
# - price - цена указанная в объявлении на авто.ру
# - hidden - характеристика объявления на авто.ру
# - equipment_dict -  дополнительные оборудование автомобиля
# - vendor - страна производитель
# - model_name - название модели автомобиля
# - car_url - ссылка на объявление
# - complectation_dict - комплектация автомобиля
# - image - фотография автомобиля
# - parsing_unixtime - время парсинга в unix
# - priceCurrency - валюта
# - sell_id - сервисный для генерации submition
# - super_gen -  дополнилнительная переменная словари с даннами о двигаетле автомобиля
# - Train - сервисный для разделения train и test

# %%
cols = df.columns 
# желтый - пропущенные данные, синий - не пропущенные
colours = ['#000099', '#ffff00'] 
sns.heatmap(df[cols].isnull(), cmap=sns.color_palette(colours))

# %% [markdown]
# #### Детальная информация по пропускам датасета раздельно:
# ----
# В тренировочном датасете признаки:
# modelDate name, numberOfDoors, vehicleConfiguration,
# vehicleTransmission, engineDisplacement, enginePower, Привод
# имеют 2 пропускa (можно удалить,  2 значения не имеют влияние на такой выборке).
# В description 2603 (>2%) пропуска, попробуем заполнить.
# (много но не критично можно попробовать удалить и посмотреть разницу).
# Состояние - 84370 (100.0%) - пробуем заполнить из description или удалим.
# Владельцы - 18808 (>18%) , попробуем заполнить.
# Владение - 67711 (>70%) - поразному заполненый признак в в разных сетах, удалим.
# car_url	 - 84370 (100.0%) - cсылка на сайт, удаляем.
# complectation_dict - 84370 (100.0%), полезная информация, неполученная в результате парсинга, удалим признак.
# image	- 84370 (100.0%) - фото авто, удаляем.
# model_info	- 84370 (100.0%) -  доп. информация по модели, удаляем.
# parsing_unixtime - 84370 (100.0%) - удалим, так как не можем заполнить.
# priceCurrency - 84370 (100.0%) -  стоимость везде в рублях, бесполезный признак.
# super_gen - 84370 (100.0%) - удаляем, т.к. вся информация есть в других признаках.
# sell_id - 84370 (100.0%) - это столбец для генерации файла submition(ничего не делаем)
#
# В тестовом датасете признаки:
#
# Владение - 22691 (>63%) - надо попробовать заполнить
# (но пропусках много в обоих датасетах, пока что кажется разумным удалить этот признак).
# price - 34686 (100.0%)- целевая переменная(ничего не делаем).
# equipment_dict - 9996 (>25%) -  доп характеристики, попробуем заполнить.
# complectation_dict - 28268 (>80%) - полезная информация, но слишком много пропусков, удаляем
# hidden - 84370 (100.0%) => надо удалить.

# %% [markdown]
# Предварительно оценим скоррелированность числовых признаков

# %%
plt.figure(figsize=(10,5))
sns.heatmap(df[['modelDate','numberOfDoors','productionDate','numberOfDoors','mileage', 'price']].corr().abs(), vmin=0, vmax=1, annot=True)

# %% [markdown]
# Между productionDate и modelDate  слишком выская корреляция, есть смысл удалить productionDate и оставить только modelDate,
# пока оставляем посмотрим на общую корреляцию после изменения типов переменных.

# %% [markdown]
# признак Таможня бесполезен так как содержит одно значение - Растаможен удаляем
# Состояние - только одно значение - "Не требует ремонта" после заолнение этого признака в тренировочном датасете надо взять из трейна только авто не требующие ремонта(посмотрим на выбросы по ценам), либо удалить признак

# %% [markdown]
# #### Внесем данные по типам переменных в списки

# %%
# бинарная переменная ()
bin_cols = []
# категориальные переменные(19)
cat_cols = ['bodyType', 'brand', 'color', 'fuelType', 'name',
       'vehicleConfiguration', 'vehicleTransmission', 'engineDisplacement', 'enginePower',
       'description', 'Привод', 'Руль', 'Состояние', 'Владельцы',
       'ПТС', 'equipment_dict', 'hidden',
       'vendor', 'model_name']
# числовые переменные (4) 
num_cols = ['modelDate','numberOfDoors','productionDate','mileage']
# сервисные переменные (2)
servis_cols = ['Train', 'sell_id']
# целевая переменная (1)
target_col = ['price']
all_cols =cat_cols+num_cols+servis_cols+bin_cols+ target_col
print(f'Кол-во столбцов, для дальнейшей работы после предварительного анализа:= {len(all_cols)}')
# Out:
# Кол-во столбцов, для дальнейшей работы после предварительного анализа:= 26

# %% [markdown]
#  Реализуем выводы перед детальным анализом по переменным

# %%
#Сохраним купию датасета на всякий случай
df_copy = df.copy()

# %%
len(df[df['Train']==0])
# Out:
# 34686

# %%
describe_cols(df[df['Train']==1])
# Out:
#                  Признак      Тип Кол-во значений Кол-во пропусков(NaN)  \
# 0               bodyType   object           57871                     0
# 1                  brand   object           57871                     0
# 2                  color   object           57871                     0
# 3               fuelType   object           57871                     0
# 4              modelDate  float64           57869                     2
# 5                   name   object           57869                     2
# 6          numberOfDoors  float64           57869                     2
# 7         productionDate  float64           57871                     0
# 8   vehicleConfiguration   object           57869                     2
# 9    vehicleTransmission   object           57869                     2
# 10    engineDisplacement   object           57869                     2
# 11           enginePower   object           57869                     2
# 12           description   object           55770                  2101
# 13               mileage  float64           57871                     0
# 14                Привод   object           57869                     2
# 15                  Руль   object           57871                     0
# 16             Состояние   object               0                 57871
# 17             Владельцы   object           47356                 10515
# 18                   ПТС   object           57523                   348
# 19               Таможня   object           57871                     0
# 20              Владение   object           14340                 43531
# 21                 price  float64           57668                   203
# 22        equipment_dict   object           57871                     0
# 23                hidden   object           57871                     0
# 24                vendor   object           57871                     0
# 25            model_name   object           57871                     0
# 26                 Train    int64           57871                     0
# 27               car_url   object               0                 57871
# 28    complectation_dict   object               0                 57871
# 29                 image   object               0                 57871
# 30            model_info   object               0                 57871
# 31      parsing_unixtime  float64               0                 57871
# 32         priceCurrency   object               0                 57871
# 33               sell_id  float64               0                 57871
# 34             super_gen   object               0                 57871
#
#    Кол-во уникальных
# 0                159
# 1                 36
# 2                 16
# 3                  7
# 4                 74
# 5               3866
# 6                  5
# 7                 71
# 8               1598
# 9                  4
# 10               468
# 11               378
# 12             48461
# 13             16608
# 14                 3
# 15                 2
# 16                 0
# 17                 3
# 18                 2
# 19                 1
# 20               277
# 21              8197
# 22             38266
# 23                 1
# 24                 6
# 25              1030
# 26                 1
# 27                 0
# 28                 0
# 29                 0
# 30                 0
# 31                 0
# 32                 0
# 33                 0
# 34                 0

# %% [markdown]
# ### Детальный анализ по переменным
# ---

# %% [markdown]
# #### 1. bodyType
# #### Тип кузова автомобиля

# %%
df_Train = df[df['Train']==1]
df_Test = df[df['Train']==0]
print(f'Всего в тесте типов кузова: {df_Test.bodyType.nunique()}')
print(f'Всего в трейне типов кузова: {df_Train.bodyType.nunique()}')
# Out:
# Всего в тесте типов кузова: 24
# Всего в трейне типов кузова: 159

# %%
# посмотрим на них 
print(f'Список 21 типов кузова из теста: \n{df_Test.bodyType.unique()}')
print(f'Список первых 20 из 144 типов кузова из трейна: \n {df_Train.bodyType.unique()[:20]}')
# Out:
# Список 21 типов кузова из теста:
# ['лифтбек' 'внедорожник 5 дв.' 'хэтчбек 5 дв.' 'седан' 'компактвэн'
#  'универсал 5 дв.' 'пикап одинарная кабина' 'хэтчбек 3 дв.' 'купе'
#  'кабриолет' 'минивэн' 'пикап двойная кабина' 'внедорожник 3 дв.'
#  'родстер' 'микровэн' 'седан 2 дв.' 'купе-хардтоп' 'фастбек' 'тарга'
#  'внедорожник открытый' 'лимузин' 'пикап полуторная кабина'
#  'седан-хардтоп' 'фургон']
# Список первых 20 из 144 типов кузова из трейна:
#  ['седан' 'внедорожник 5 дв.' 'универсал 5 дв.' 'седан long' 'купе'
#  'лифтбек sportback' 'лифтбек' 'хэтчбек 5 дв. sportback' 'хэтчбек 3 дв.'
#  'кабриолет' 'кабриолет roadster' 'хэтчбек 5 дв.' 'седан gran coupe'
#  'лифтбек gran turismo' 'лифтбек gran coupe' 'родстер' 'компактвэн'
#  'компактвэн gran tourer' 'седан 2 дв.' 'купе-хардтоп']

# %%
# оставляем только типы кузова как в тесте
list_bodyType_test = list(df_Test.bodyType.unique())
df = df[df['bodyType'].isin(list_bodyType_test)]

# %%
df_Train = df[df['Train']==1]
print(f'Кол-во строк в трейне: {len(df_Train)}')
# Out:
# Кол-во строк в трейне: 55108

# %%
df['bodyType'].value_counts()
# Out:
# внедорожник 5 дв.          35264
# седан                      29864
# хэтчбек 5 дв.               7572
# лифтбек                     4615
# универсал 5 дв.             3555
# минивэн                     2297
# компактвэн                  1761
# купе                        1693
# хэтчбек 3 дв.               1397
# пикап двойная кабина         565
# внедорожник 3 дв.            402
# купе-хардтоп                 212
# кабриолет                    188
# родстер                      155
# фургон                       140
# седан-хардтоп                 21
# микровэн                      21
# внедорожник открытый          19
# пикап одинарная кабина        14
# пикап полуторная кабина       13
# седан 2 дв.                    9
# тарга                          8
# лимузин                        6
# фастбек                        3
# Name: bodyType, dtype: int64

# %% [markdown]
# #### bodyType
# Тип кузова
# Категориальный признак, оставили только типы кузова из тестового сета(53980), пропусков нет.

# %% [markdown]
# #### 2. brand
# #### Марка (бренд) автомобиля

# %%
print(f'Всего в датасета марок: {df.brand.nunique()}')
print(f'Марки: \n{df.brand.value_counts()[:20]}')
# Out:
# Всего в датасета марок: 36
# Марки:
# NISSAN        7851
# VOLKSWAGEN    7688
# BMW           7656
# MERCEDES      7493
# TOYOTA        6730
# AUDI          6329
# MITSUBISHI    5450
# SKODA         5263
# HYUNDAI       3416
# KIA           3274
# FORD          3174
# VOLVO         3055
# CHEVROLET     2467
# RENAULT       2329
# HONDA         1915
# OPEL          1896
# LEXUS         1741
# MAZDA         1710
# INFINITI      1596
# LAND_ROVER    1252
# Name: brand, dtype: int64

# %%
old_len_train1 = len(df[df['Train']==1])
print('Кол-во строк в трейне:= ', old_len_train1)
# Out:
# Кол-во строк в трейне:=  55108

# %% [markdown]
# #### brand
# Категориальный признак, все марки машин пока, что оставляем как есть, пропусков нет

# %% [markdown]
# #### 3. color
# #### Цвет автомобиля

# %%
df['color'].value_counts()
# Out:
# чёрный         25007
# белый          16340
# серый          11415
# серебристый    10590
# синий           8875
# красный         4735
# коричневый      3916
# зелёный         2612
# бежевый         1912
# голубой         1327
# золотистый       685
# пурпурный        645
# жёлтый           639
# фиолетовый       540
# оранжевый        530
# розовый           26
# Name: color, dtype: int64

# %%
df[df['Train']==1].groupby(['color'])['price'].median().sort_values(ascending=False)
#max()
# Out:
# color
# коричневый     1103700.0
# белый          1079500.0
# чёрный          962500.0
# оранжевый       899000.0
# серый           800000.0
# синий           681632.0
# розовый         580000.0
# бежевый         575750.0
# красный         529000.0
# жёлтый          512500.0
# фиолетовый      490000.0
# серебристый     490000.0
# голубой         450000.0
# пурпурный       400000.0
# золотистый      390000.0
# зелёный         330000.0
# Name: price, dtype: float64

# %% [markdown]
# #### color
# категориальный признак, 16 значений, пропусков нет

# %% [markdown]
# #### 4. fuelType
# #### Тип топлива(5 видов топлива: бензин, дизель, электро, гибрид, газ)

# %%
df_Train = df[df['Train']==1]
df_Test = df[df['Train']==0]
print(f'Список зачений по fuelType в трейне:= {list(df_Train.fuelType.unique())}')
print(f'Список зачений по fuelType в тесте:= {list(df_Test.fuelType.unique())}')
#В этой переменной было 5 уникальных значений в трейне и 5 в тесте
# Out:
# Список зачений по fuelType в трейне:= ['бензин', 'дизель', 'электро', 'гибрид', 'газ']
# Список зачений по fuelType в тесте:= ['бензин', 'дизель', 'гибрид', 'электро', 'газ']

# %%
print(f'Распределение по типам топлива в трейне: \n{df_Train.fuelType.value_counts()}')
print(f'Распределение по типам топлива в тесте: \n{df_Test.fuelType.value_counts()}')
# Out:
# Распределение по типам топлива в трейне:
# бензин     46581
# дизель      8236
# гибрид       196
# электро       90
# газ            5
# Name: fuelType, dtype: int64
# Распределение по типам топлива в тесте:
# бензин     28601
# дизель      5800
# гибрид       223
# электро       55
# газ            7
# Name: fuelType, dtype: int64

# %%
# уберем газ так как автомобилей на газе очень мало и в трейне и тесте
#df = df[df['fuelType'] != 'газ ']

# %%
df_Train = df[df['Train']==1]
print(f'Кол-во строк в трейне: {len(df_Train)}')
# Out:
# Кол-во строк в трейне: 55108

# %% [markdown]
# #### fuelType
# Категориальный признак. 5 значения ('газ' пока оставили )(53980). Возможно есть смысл преоборазовать даный признак в числовой или dummy переменную. Пропуски отсутствуют.

# %%
label_encoder = LabelEncoder()
df['fuelType'] = label_encoder.fit_transform(df['fuelType'])
df['fuelType']= df['fuelType'].astype('int64')
cat_cols.remove('fuelType')
num_cols.append('fuelType')

# %% [markdown]
# #### 5. modelDate - дата выпуска модели
# #### 6. productionDate - дата производства авто

# %% [markdown]
# Рассмотрим сразу эти оба признака так, как было уже сказано что у них очень сильная корреляция.
# У признака modelDate был 1 пропуск но предыдущие преобразования датасета удалили его

# %%
print(f'Количество пропусков в modelDate - {df["modelDate"].isnull().sum()}')
print(f'Количество пропусков в productionDate - {df["productionDate"].isnull().sum()}')
# Out:
# Количество пропусков в modelDate - 0
# Количество пропусков в productionDate - 0

# %%
len_train = len(df[df['Train']==1])
print('Кол-во строк в трейне:= ', len_train)
# Out:
# Кол-во строк в трейне:=  55108

# %% [markdown]
# ### Итог:
#
# Пока, что оставляем оба признака, после всез преобразований сравним у кого сильнее корреляция с другими чиловыми признаками

# %% [markdown]
# ### 7. name
# #### комбинация нескольких характеристик (модели, объема и мощности двигателя и привода)

# %% [markdown]
# в данной переменной содержатся данные нескольких характеристик.
# Также не все значения в engineDisplacement имееют численное значение , поэтому их можно будет взять из этой переменной
# Привод из данной переменной не нужен

# %%
df[['name','engineDisplacement','Привод','enginePower']]
# Out:
#                                      name engineDisplacement    Привод  \
# 0                  3.0 AMT (300 л.с.) 4WD                3.0    полный
# 1                       2.4 AT (165 л.с.)                2.4  передний
# 2                  2.0 AMT (249 л.с.) 4WD                2.0    полный
# 3                   4.0 AT (605 л.с.) 4WD                4.0    полный
# 5                  2.0 AMT (249 л.с.) 4WD                2.0    полный
# ...                                   ...                ...       ...
# 92552              316i 1.6 AT (136 л.с.)            1.6 LTR    задний
# 92553  520d xDrive 2.0d AT (190 л.с.) 4WD            2.0 LTR    полный
# 92554              523i 2.5 AT (170 л.с.)            2.5 LTR    задний
# 92555          20d 2.0d AT (184 л.с.) 4WD            2.0 LTR    полный
# 92556          30d 3.0d AT (235 л.с.) 4WD            3.0 LTR    полный
#
#       enginePower
# 0             300
# 1             165
# 2             249
# 3             605
# 5             249
# ...           ...
# 92552     136 N12
# 92553     190 N12
# 92554     170 N12
# 92555     184 N12
# 92556     235 N12
#
# [89794 rows x 4 columns]

# %% [markdown]
# #### 7.1 engineDisplacement

# %%
def engine_from_name(row):
    row = str(row)
    volume = re.findall('\d\.\d', row)
    if volume == []:
        return None
    return int(float(volume[0]))
# поле engineDisplacement заполненно не полностью именно мощностью, в отличии от поля name
# поэтому вытаскиваем мощность из поля name
df['engineDisplacement2'] = df['name'].apply(engine_from_name)

# %%
df['engineDisplacement2'].isnull().sum()
# Out:
# 145

# %%
df[df['engineDisplacement2'].isna()].fuelType
# Out:
# 1078     4
# 1107     4
# 1124     4
# 1468     4
# 1564     4
#         ..
# 90539    4
# 90571    4
# 90669    4
# 92030    4
# 92375    4
# Name: fuelType, Length: 145, dtype: int64

# %% [markdown]
# Попробуем заполнить пропуски аналогичными объемами двигателей автомобилей, со схожими параметрами

# %%
df_Train = df[df['Train']==1]
temp_df = df_Train[df_Train['engineDisplacement2'].isna()]

# %%
def most_common(df):
    list_param = []
    list_ = list(df.columns)
    for col in list_:
        if col=='description':
            pass
        else:
            c = collections.Counter(df[col])
            list_param.append(c.most_common()[0])
    print(list_param)
most_common(temp_df)
# Out:
# [('внедорожник 5 дв.', 38), ('AUDI', 35), ('чёрный', 27), (4, 90), (2018.0, 38), ('55 Electro AT (301 кВт) 4WD', 35), (5.0, 71), (2020.0, 53), ('ALLROAD_5_DOORS AUTOMATIC 55', 35), ('автоматическая', 90), ('55', 35), (408.0, 35), (0.0, 54), ('полный', 56), ('Левый', 73), (nan, 1), (nan, 54), ('Оригинал', 90), (True, 90), (nan, 74), (6627558.0, 2), ('{}', 6), (False, 90), ('EUROPEAN', 65), ('E_TRON', 35), (1, 90), (nan, 90), (nan, 90), (nan, 90), (nan, 90), (nan, 1), (nan, 90), (nan, 1), (nan, 90), (nan, 1)]

# %% [markdown]
# Возьмем тип автомобиля, мощность двигателя +- 10%, а также чтоб автомобиль был не электрокаром AUDI

# %%
df_Train = df[df['Train']==1]
temp_df = df_Train[(df_Train['bodyType'] == list_bodyType_test[3]) &
                    (df_Train['brand'] == 'AUDI') & (df_Train['fuelType'] != 'электро') &
                    (df_Train['enginePower'] >= 170-17) &
                    (df_Train['enginePower'] <= 170+17) ]
print(temp_df.shape)
round(temp_df.engineDisplacement2.mean(),)
# Out:
# (330, 36)
# C:\Programs\anaconda\lib\site-packages\pandas\core\ops\array_ops.py:253: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   res_values = method(rvalues)
# 2

# %%
df['engineDisplacement2'] = df['engineDisplacement2'].fillna(1.0)
print(f" Количество пропусков: {df['engineDisplacement2'].isnull().sum()}")
# Out:
#  Количество пропусков: 0

# %%
IQRhist('engineDisplacement2')
# Out:
# 25-й перцентиль: 1.0, 75-й перцентиль: 2.0, IQR: 1.0,  Границы выбросов: [-0.5, 3.5].
# Кол-во выбросов = 3065, Процент выбросов среди тренировочного датасета 5.56

# %%
df[df['engineDisplacement2']>=7][:2]
# Out:
#           bodyType     brand  color  fuelType  modelDate               name  \
# 6830  купе-хардтоп  CADILLAC  белый         0     1967.0  7.7 AT (380 л.с.)
# 6982     кабриолет  CADILLAC  белый         0     1971.0  8.2 AT (218 л.с.)
#
#       numberOfDoors  productionDate         vehicleConfiguration  \
# 6830            2.0          1969.0  COUPE_HARDTOP AUTOMATIC 7.7
# 6982            2.0          1974.0         CABRIO AUTOMATIC 8.2
#
#      vehicleTransmission engineDisplacement enginePower  \
# 6830      автоматическая                7.7         380
# 6982      автоматическая                8.2         218
#
#                                             description  mileage    Привод  \
# 6830  Американская классика, на полном ходу в отличн...  15000.0    задний
# 6982  После реставрация. \nНа учёте. Полностью честн...  25000.0  передний
#
#        Руль Состояние    Владельцы       ПТС Таможня  \
# 6830  Левый       NaN   1 владелец  Оригинал    True
# 6982  Левый       NaN  2 владельца  Оригинал    True
#
#                         Владение      price equipment_dict hidden    vendor  \
# 6830  {'year': 1970, 'month': 5}  2500000.0             {}  False  AMERICAN
# 6982                         NaN  2600000.0             {}  False  AMERICAN
#
#      model_name  Train car_url complectation_dict image model_info  \
# 6830   ELDORADO      1     NaN                NaN   NaN        NaN
# 6982   ELDORADO      1     NaN                NaN   NaN        NaN
#
#       parsing_unixtime priceCurrency  sell_id super_gen  engineDisplacement2
# 6830               NaN           NaN      NaN       NaN                  7.0
# 6982               NaN           NaN      NaN       NaN                  8.0

# %%
#удалим выбросы где объем двигателя больше 7
df = df[(df['Train']==1) & (df['engineDisplacement2']<7)| (df['Train']==0)]

# %%
len(df[df['Train']==0])
# Out:
# 34686

# %%
df.shape
# Out:
# (89787, 36)

# %%
# переводим в float64
df['engineDisplacement2'] = df['engineDisplacement2'].astype('float64')

# %% [markdown]
# #### Итог engineDisplacement
# Создали новый признак engineDisplacement2, который показывает те же показтели,
# но все они имеют численные значения, избавились от пропусков путем подобора аналогичных значений из датасета.
# Посмотрели на выбросы, отобрали 7 машин, которые могут повлиять на обучение, пока что оставляем, посмотрим как скажется на метрике

# %%
num_cols.append('engineDisplacement2')
cat_cols.remove('engineDisplacement')
len_train = len(df[df['Train']==1])
print('Кол-во строк в трейне: ', len_train)
# Out:
# Кол-во строк в трейне:  55101

# %% [markdown]
# #### 7.2 enginePower - мощность двигателя (л.с.)
# по результатам предварительного анализа эта переменная была отнесена к категориальнымu

# %%
df.head(1)
# Out:
#   bodyType brand   color  fuelType  modelDate                    name  \
# 0    седан  AUDI  чёрный         0     2011.0  3.0 AMT (300 л.с.) 4WD
#
#    numberOfDoors  productionDate vehicleConfiguration vehicleTransmission  \
# 0            4.0          2012.0      SEDAN ROBOT 3.0    роботизированная
#
#   engineDisplacement enginePower  \
# 0                3.0         300
#
#                                          description   mileage  Привод   Руль  \
# 0  Всем доброго времени суток! Вашему вниманию пр...  224000.0  полный  Левый
#
#   Состояние    Владельцы       ПТС Таможня                    Владение  \
# 0       NaN  3 или более  Дубликат    True  {'year': 2018, 'month': 8}
#
#        price                                     equipment_dict hidden  \
# 0  1300000.0  {'asr': True, 'tinted-glass': True, 'esp': Tru...  False
#
#      vendor model_name  Train car_url complectation_dict image model_info  \
# 0  EUROPEAN         A6      1     NaN                NaN   NaN        NaN
#
#    parsing_unixtime priceCurrency  sell_id super_gen  engineDisplacement2
# 0               NaN           NaN      NaN       NaN                  3.0

# %%
df_Train = df[df['Train']==1]
df_Test = df[df['Train']==0]
# проверим все значения тестового сета по мощности 
df_Test.enginePower.unique()
# Out:
# array(['105 N12', '110 N12', '152 N12', '200 N12', '102 N12', '150 N12',
#        '90 N12', '180 N12', '220 N12', '122 N12', '70 N12', '140 N12',
#        '125 N12', '54 N12', '86 N12', '75 N12', '64 N12', '95 N12',
#        '260 N12', '170 N12', '80 N12', '68 N12', '160 N12', '115 N12',
#        '280 N12', '53 N12', '60 N12', '143 N12', '42 N12', '101 N12',
#        '58 N12', '193 N12', '79 N12', '30 N12', '100 N12', '50 N12',
#        '163 N12', '225 N12', '420 N12', '211 N12', '245 N12', '560 N12',
#        '500 N12', '249 N12', '450 N12', '605 N12', '250 N12', '354 N12',
#        '120 N12', '290 N12', '230 N12', '350 N12', '204 N12', '255 N12',
#        '340 N12', '177 N12', '272 N12', '372 N12', '210 N12', '130 N12',
#        '300 N12', '190 N12', '239 N12', '435 N12', '333 N12', '271 N12',
#        '326 N12', '238 N12', '310 N12', '233 N12', '252 N12', '133 N12',
#        '460 N12', '520 N12', '400 N12', '525 N12', '367 N12', '265 N12',
#        '550 N12', '580 N12', '88 N12', '165 N12', '430 N12', '335 N12',
#        '174 N12', '224 N12', '136 N12', '256 N12', '338 N12', '112 N12',
#        '218 N12', '360 N12', '93 N12', '182 N12', '113 N12', '240 N12',
#        '270 N12', '137 N12', '155 N12', '61 N12', '254 N12', '116 N12',
#        '71 N12', '285 N12', '408 N12', '166 N12', '156 N12', '257 N12',
#        '201 N12', '162 N12', '194 N12', '142 N12', '154 N12', '147 N12',
#        '281 N12', '243 N12', '118 N12', '128 N12', '91 N12', '83 N12',
#        '205 N12', '247 N12', '188 N12', '295 N12', '275 N12', '78 N12',
#        '109 N12', '94 N12', '185 N12', '258 N12', '145 N12', '132 N12',
#        '135 N12', '52 N12', '66 N12', '124 N12', '98 N12', '215 N12',
#        '158 N12', '99 N12', '103 N12', '131 N12', '126 N12', '235 N12',
#        '181 N12', '315 N12', '203 N12', '231 N12', '82 N12', '304 N12',
#        '175 N12', '320 N12', '213 N12', '144 N12', '146 N12', '151 N12',
#        '111 N12', '286 N12', '306 N12', '107 N12', '184 N12', '313 N12',
#        '264 N12', '575 N12', '407 N12', '192 N12', '129 N12', '555 N12',
#        '625 N12', '329 N12', '370 N12', '381 N12', '269 N12', '600 N12',
#        '510 N12', '544 N12', '462 N12', '355 N12', '507 N12', '609 N12',
#        '431 N12', '530 N12', '387 N12', '610 N12', '197 N12', '343 N12',
#        '445 N12', '171 N12', '51 N12', '46 N12', '347 N12', '321 N12',
#        '167 N12', '141 N12', '169 N12', '405 N12', '117 N12', '114 N12',
#        '173 N12', '234 N12', '540 N12', '106 N12', '49 N12', '248 N12',
#        '317 N12', '309 N12', '97 N12', '121 N12', '268 N12', '149 N12',
#        '87 N12', '85 N12', '65 N12', '67 N12', '127 N12', '485 N12',
#        '186 N12', '222 N12', '307 N12', '262 N12', '302 N12', '284 N12',
#        '325 N12', '168 N12', '221 N12', '330 N12', '283 N12', '328 N12',
#        '303 N12', '278 N12', '388 N12', '571 N12', '585 N12', '612 N12',
#        '401 N12', '279 N12', '455 N12', '382 N12', '557 N12', '517 N12',
#        '394 N12', '422 N12', '292 N12', '469 N12', '522 N12', '296 N12',
#        '639 N12', '390 N12', '476 N12', '630 N12', '402 N12', '487 N12',
#        '558 N12', '421 N12', '316 N12', '514 N12', '457 N12', '626 N12',
#        '242 N12', '38 N12', '32 N12', '223 N12', '72 N12', '305 N12',
#        '183 N12', '273 N12', '159 N12', '76 N12', '148 N12', '179 N12',
#        '73 N12', '277 N12', '282 N12', '178 N12', '288 N12', '199 N12',
#        '266 N12', '92 N12', '74 N12', '324 N12', '232 N12', '157 N12',
#        '69 N12', '212 N12', '276 N12', '202 N12', '77 N12', '164 N12',
#        '96 N12', '84 N12', '228 N12', '108 N12', '208 N12', '263 N12',
#        '294 N12', '318 N12', '380 N12', '219 N12', '214 N12', '383 N12',
#        '241 N12', '57 N12', '55 N12', '104 N12', '48 N12', '40 N12',
#        '44 N12', '227 N12', '139 N12', '209 N12', '195 N12', '189 N12',
#        '480 N12', '591 N12', '301 N12'], dtype=object)

# %%
# в тесте вытащим значение мощности перед строкой ' N12'
df.loc[df['Train']==0, 'enginePower'] = df[df['Train']==0]['enginePower'].apply(lambda x: int(x.split()[0]))

# %%
# переводим в int64
df['enginePower'] = df['enginePower'].astype('int64')

# перенесем признак в числовые
cat_cols.remove('enginePower')
num_cols.append('enginePower')

# %%
IQRhist('enginePower')
# Out:
# 25-й перцентиль: 115.0, 75-й перцентиль: 197.0, IQR: 82.0,  Границы выбросов: [-8.0, 320.0].
# Кол-во выбросов = 3225, Процент выбросов среди тренировочного датасета 5.85

# %%
df[df['enginePower']>320][:2]
# Out:
#            bodyType brand    color  fuelType  modelDate  \
# 3   универсал 5 дв.  AUDI  голубой         0     2014.0
# 33             купе  AUDI  красный         0     2017.0
#
#                      name  numberOfDoors  productionDate  \
# 3   4.0 AT (605 л.с.) 4WD            5.0          2017.0
# 33  2.9 AT (450 л.с.) 4WD            2.0          2018.0
#
#            vehicleConfiguration vehicleTransmission engineDisplacement  \
# 3   WAGON_5_DOORS AUTOMATIC 4.0      автоматическая                4.0
# 33          COUPE AUTOMATIC 2.9      автоматическая                2.9
#
#     enginePower                                        description  mileage  \
# 3           605  - бензиновый двигатель 4.0 V8 (CWUC), 8-ст АК...  29620.0
# 33          450  Выкупим Ваш автомобиль в день обращения – до 1...  10167.0
#
#     Привод   Руль Состояние    Владельцы       ПТС Таможня  \
# 3   полный  Левый       NaN  2 владельца  Оригинал    True
# 33  полный  Левый       NaN   1 владелец  Оригинал    True
#
#                       Владение      price  \
# 3   {'year': 2019, 'month': 3}  6050000.0
# 33                         NaN  5944000.0
#
#                                        equipment_dict hidden    vendor  \
# 3   {'cruise-control': True, 'asr': True, 'esp': T...  False  EUROPEAN
# 33  {'cruise-control': True, 'esp': True, 'usb': T...  False  EUROPEAN
#
#    model_name  Train car_url complectation_dict image model_info  \
# 3         RS6      1     NaN                NaN   NaN        NaN
# 33        RS5      1     NaN                NaN   NaN        NaN
#
#     parsing_unixtime priceCurrency  sell_id super_gen  engineDisplacement2
# 3                NaN           NaN      NaN       NaN                  4.0
# 33               NaN           NaN      NaN       NaN                  2.0

# %%
#удалим выбросы где мощность двигателя больше 320
df = df[(df['Train']==1) & (df['enginePower']<320)| (df['Train']==0)]

# %% [markdown]
# #### Итог enginePower
# Исправли признак, теперь он имеет только численные значения.
# Посмотрели на выбросы, отобрали 5.7% машин, которые могут повлиять на обучение,
# пока что оставляем, посмотрим как скажется на метрике

# %%
len(df[df['Train']==0])
# Out:
# 34686

# %%
len_train = len(df[df['Train']==1])
print('Кол-во строк в трейне: ', len_train)
# Out:
# Кол-во строк в трейне:  51819

# %% [markdown]
# ### Name
# Категориальный признак, помог заполнить пропуски найти выбросы или ошибки в датасетах,  необходимости в нем не вижу, можно удалить

# %%
cat_cols.remove('name')
len_train = len(df[df['Train']==1])
print('Кол-во строк в трейне: ', len_train)
# Out:
# Кол-во строк в трейне:  51819

# %% [markdown]
# ### 8. numberOfDoors -
# #### Количество дверей

# %%
# переведем в int64 критерий numberOfDoors
df['numberOfDoors'] = df['numberOfDoors'].astype('int64')
df['numberOfDoors'].value_counts()
# Out:
# 5    51456
# 4    31168
# 2     1988
# 3     1891
# 0        2
# Name: numberOfDoors, dtype: int64

# %%
df['numberOfDoors'].value_counts()
# Out:
# 5    51456
# 4    31168
# 2     1988
# 3     1891
# 0        2
# Name: numberOfDoors, dtype: int64

# %% [markdown]
# Фактически это категориальный признак с 4 значениями, но для корректной
# групповой обработки числовых признаков он представлен чилосвым

# %%
len_train = len(df[df['Train']==1])
print('Кол-во строк в трейне: ', len_train)
# Out:
# Кол-во строк в трейне:  51819

# %% [markdown]
# ### 9. vehicleConfiguration
# #### комбинация типа кузова автомобиля, типа трансмиссии и объема двигателя

# %%
df.vehicleConfiguration.value_counts()
# Out:
# ALLROAD_5_DOORS AUTOMATIC 2.0        3898
# SEDAN MECHANICAL 1.6                 3677
# ALLROAD_5_DOORS VARIATOR 2.0         3282
# SEDAN AUTOMATIC 1.6                  3012
# SEDAN AUTOMATIC 2.0                  2855
#                                      ...
# MINIVAN AUTOMATIC 3.1                   1
# MINIVAN MECHANICAL 1.4                  1
# COMPACTVAN AUTOMATIC 1.6d               1
# HATCHBACK_3_DOORS MECHANICAL 1.3d       1
# COUPE ROBOT 2.5                         1
# Name: vehicleConfiguration, Length: 1439, dtype: int64

# %% [markdown]
# #### vehicleConfiguration
# В данном признаке есть все что указно в других признаках

# %%
# удаляем
cat_cols.remove('vehicleConfiguration')

# %% [markdown]
# ### 10. vehicleTransmission
# #### тип трансмиссии (коробки передач)

# %%
# Значения в тесте в трейне
Train_df = df[df['Train']==1]
Train_df['vehicleTransmission'].value_counts()
# Out:
# автоматическая      26167
# механическая        15598
# роботизированная     5228
# вариатор             4826
# Name: vehicleTransmission, dtype: int64

# %%
# Значения в тесте
Test_df = df[df['Train']==0]
Test_df['vehicleTransmission'].value_counts()
# Out:
# автоматическая      19596
# механическая         7209
# вариатор             3999
# роботизированная     3882
# Name: vehicleTransmission, dtype: int64

# %%
df[df['Train']==1]['vehicleTransmission'].isna().sum()
# Out:
# 0

# %% [markdown]
# ### vehicleTransmission
# Категориальный признак, 4 значения, Был 1 пропуск, но мы его уже удалили

# %%
len_train = len(df[df['Train']==1])
print('Кол-во строк в трейне: ', len_train)
# Out:
# Кол-во строк в трейне:  51819

# %% [markdown]
# ### 11. description
# #### дополнительные характеристики по комплектации авто

# %%
# Значения в тесте в трейне
Train_df = df[df['Train']==1]
Train_df['description'].sample(2)
# Out:
# 2669     Продам свой авто, в связи с покупкой  недвижим...
# 33837    ЛОТ: 01230555\nFAVORIT MOTORS KIA Юго-Запад\n\...
# Name: description, dtype: object

# %%
# Значения в тесте
Test_df = df[df['Train']==0]
Test_df['description'].sample(2)
# Out:
# 74464    • Автомобиль проверен по 110 пунктам\n• Автокр...
# 66714    В продаже BMW 528i немецкой сборке с полным пр...
# Name: description, dtype: object

# %%
df['description'] = df['description'].fillna('[]')
df['description_word'] = df['description'].apply(lambda x: [str(i).lower() for i in x.split()])

# %%
df['count_words_d'] = df['description'].apply(lambda x: len(x.split()))
vectorizer = CountVectorizer()
text_feat = vectorizer.fit_transform(df['description'])
# создаем новые признаки кол-во среднее кол-во токенов и их сумма в описании
df['mean_c_w'] = text_feat.mean(axis=1)
df['sum_c_w'] = text_feat.sum(axis=1)

# %%
df[['description','description_word','count_words_d','mean_c_w','sum_c_w']]
# Out:
#                                              description  \
# 0      Всем доброго времени суток! Вашему вниманию пр...
# 1      Автомобиль не гнилой, обслуживался своевременн...
# 2      Эксклюзивные условия в Ауди Центре Север.\nТол...
# 5      Эксклюзивные условия в Ауди Центре Север.\nТол...
# 6      ●Скидка до 150 000 рублей при покупке в кредит...
# ...                                                  ...
# 92552  Продается BMW 316i в отличном состоянии. Прода...
# 92553                     Продаётся отличный автомобиль.
# 92554                                  Хорошее состояние
# 92555  Автомобиль в идеальном состоянии . Куплен новы...
# 92556   Пробег реальный, состояние отличное! Авторска...
#
#                                         description_word  count_words_d  \
# 0      [всем, доброго, времени, суток!, вашему, внима...            398
# 1      [автомобиль, не, гнилой,, обслуживался, своевр...             61
# 2      [эксклюзивные, условия, в, ауди, центре, север...            336
# 5      [эксклюзивные, условия, в, ауди, центре, север...            336
# 6      [●скидка, до, 150, 000, рублей, при, покупке, ...            196
# ...                                                  ...            ...
# 92552  [продается, bmw, 316i, в, отличном, состоянии....             60
# 92553                 [продаётся, отличный, автомобиль.]              3
# 92554                               [хорошее, состояние]              2
# 92555  [автомобиль, в, идеальном, состоянии, ., купле...             75
# 92556  [пробег, реальный,, состояние, отличное!, авто...             74
#
#        mean_c_w  sum_c_w
# 0      0.003029      346
# 1      0.000499       57
# 2      0.002539      290
# 5      0.002539      290
# 6      0.001462      167
# ...         ...      ...
# 92552  0.000473       54
# 92553  0.000026        3
# 92554  0.000018        2
# 92555  0.000604       69
# 92556  0.000587       67
#
# [86505 rows x 5 columns]

# %%
# удаляем 'description'
cat_cols.remove('description')

# добавляем 'count_words_d', 'mean_c_w', 'sum_c_w'
num_cols.append('count_words_d')
num_cols.append('mean_c_w')
num_cols.append('sum_c_w')

# %% [markdown]
# Итог
# Состояние вытащить не получится, слишком размыто оно может быть написано.
# Создали 3 числовых признака count_words_d, mean_c_w, sum_c_w

# %% [markdown]
# ### 12. mileage
# #### пробег автомобиля (км.)

# %%
# переведем в int64 критерий mileage
df['mileage'] = df['mileage'].astype('int64')
IQRhist('mileage')
# Out:
# 25-й перцентиль: 46000.0, 75-й перцентиль: 186000.0, IQR: 140000.0,  Границы выбросов: [-164000.0, 396000.0].
# Кол-во выбросов = 734, Процент выбросов среди тренировочного датасета 1.42

# %%
# посмотрим какое количество машин с пробегами более 400000
df[(df['Train']==1) & (df['mileage']>400000)].mileage.value_counts().sum()
# Out:
# 607

# %%
# посмотрим какое количество машин с пробегами более 400000
df[(df['Train']==0) & (df['mileage']>400000)].mileage.value_counts().sum()
# Out:
# 694

# %%
#Удалим выбросы
df = df[(df['Train']==1) & (df['mileage']<400000)| (df['Train']==0)]

# %% [markdown]
# #### mileage
# признак числовой.
# Посмотрели на выбросы, отобрали 544 выбросов с пробегом выше 400000 км из трейна, которые могут повлиять на обучение,
# пока что оставляем, посмотрим как скажется на метрике. Пропусков нет.

# %%
len_train = len(df[df['Train']==1])
print('Кол-во строк в трейне: ', len_train)
# Out:
# Кол-во строк в трейне:  51115

# %% [markdown]
# ### 13.Привод
# #### Характеристика привода автомобиля

# %%
Train_df = df[df['Train']==1]
Test_df = df[df['Train']==0]
display(Train_df['Привод'].value_counts())
display(Test_df['Привод'].value_counts())
# Out:
# передний    29079
# полный      19565
# задний       2471
# Name: Привод, dtype: int64
# передний    15565
# полный      15020
# задний       4101
# Name: Привод, dtype: int64

# %% [markdown]
# #### Привод
# Категориальный признак, 3 значения, пропусков нет, возможно перевести в числовой, посмотрим как скажется на метрике

# %%
len_train = len(df[df['Train']==1])
print('Кол-во строк в трейне: ', len_train)
# Out:
# Кол-во строк в трейне:  51115

# %% [markdown]
# ### 14. Владельцы

# %%
Train_df = df[df['Train']==1]
Test_df = df[df['Train']==0]
display(Train_df['Владельцы'].value_counts(),
Test_df['Владельцы'].value_counts())
# Out:
# 3 или более    17725
# 1 владелец     13330
# 2 владельца    11397
# Name: Владельцы, dtype: int64
# 3 или более    15957
# 1 владелец      9459
# 2 владельца     9270
# Name: Владельцы, dtype: int64

# %%
# на этапе предварительного анализа были пропуски , проверим
len(df[df['Владельцы'].isna()])
# Out:
# 8663

# %%
# посмотрим статистику по пробегу по 2 владельцам 
df[(df['Владельцы']=='2 владельца') & (df['mileage']>0)].mileage.describe()
# Out:
# count     11397.000000
# mean     142707.515838
# std       72710.934968
# min          11.000000
# 25%       90522.000000
# 50%      134000.000000
# 75%      185000.000000
# max      399000.000000
# Name: mileage, dtype: float64

# %%
# посмотрим статистику по пробегу по 3 и более владельцам 
df[(df['Владельцы']=='3 или более') & (df['mileage']>0)].mileage.describe()
# Out:
# count      33682.000000
# mean      195452.473161
# std        88200.457310
# min           10.000000
# 25%       135000.000000
# 50%       182000.000000
# 75%       245000.000000
# max      1000000.000000
# Name: mileage, dtype: float64

# %%
# переведем в числовой формат 
# вытащим количество владльцев перед первым пробелом'
df.loc[:, 'Владельцы'] = df['Владельцы'].apply(lambda x: int(x.split()[0]) if type(x)==str else None)

# %%
df.loc[df['Владельцы'].isna()].head(3)
# Out:
#             bodyType brand        color  fuelType  modelDate  \
# 2  внедорожник 5 дв.  AUDI        серый         0     2017.0
# 5  внедорожник 5 дв.  AUDI        серый         0     2017.0
# 7              седан  AUDI  серебристый         0     2018.0
#
#                              name  numberOfDoors  productionDate  \
# 2          2.0 AMT (249 л.с.) 4WD              5          2020.0
# 5          2.0 AMT (249 л.с.) 4WD              5          2020.0
# 7  45 TFSI 2.0 AMT (245 л.с.) 4WD              4          2020.0
#
#         vehicleConfiguration vehicleTransmission engineDisplacement  \
# 2  ALLROAD_5_DOORS ROBOT 2.0    роботизированная                2.0
# 5  ALLROAD_5_DOORS ROBOT 2.0    роботизированная                2.0
# 7             SEDAN ROBOT 45    роботизированная                 45
#
#    enginePower                                        description  mileage  \
# 2          249  Эксклюзивные условия в Ауди Центре Север.\nТол...        0
# 5          249  Эксклюзивные условия в Ауди Центре Север.\nТол...        0
# 7          245  Эксклюзивные условия в Ауди Центре Север.\nТол...        0
#
#    Привод   Руль Состояние  Владельцы       ПТС Таможня Владение      price  \
# 2  полный  Левый       NaN        NaN  Оригинал    True      NaN  4138735.0
# 5  полный  Левый       NaN        NaN  Оригинал    True      NaN  3645222.0
# 7  полный  Левый       NaN        NaN  Оригинал    True      NaN  3490000.0
#
#                                       equipment_dict hidden    vendor  \
# 2  {'cruise-control': True, 'asr': True, 'esp': T...  False  EUROPEAN
# 5  {'cruise-control': True, 'asr': True, 'esp': T...  False  EUROPEAN
# 7  {'cruise-control': True, 'asr': True, 'esp': T...  False  EUROPEAN
#
#   model_name  Train car_url complectation_dict image model_info  \
# 2         Q5      1     NaN                NaN   NaN        NaN
# 5         Q5      1     NaN                NaN   NaN        NaN
# 7         A6      1     NaN                NaN   NaN        NaN
#
#    parsing_unixtime priceCurrency  sell_id super_gen  engineDisplacement2  \
# 2               NaN           NaN      NaN       NaN                  2.0
# 5               NaN           NaN      NaN       NaN                  2.0
# 7               NaN           NaN      NaN       NaN                  2.0
#
#                                     description_word  count_words_d  mean_c_w  \
# 2  [эксклюзивные, условия, в, ауди, центре, север...            336  0.002539
# 5  [эксклюзивные, условия, в, ауди, центре, север...            336  0.002539
# 7  [эксклюзивные, условия, в, ауди, центре, север...            345  0.002609
#
#    sum_c_w
# 2      290
# 5      290
# 7      298

# %%
# вроде бы это новые автомобили, проверим
df.loc[df['Владельцы'].isna()].productionDate.describe()
# Out:
# count    8663.000000
# mean     2019.979684
# std         0.145915
# min      2018.000000
# 25%      2020.000000
# 50%      2020.000000
# 75%      2020.000000
# max      2020.000000
# Name: productionDate, dtype: float64

# %%
# видно что это новые автомобили, поэтому заполним Владельцев нулями
df['Владельцы'].fillna(0.0, inplace=True)

# %%
# переводим в int64
df['Владельцы'] = df['Владельцы'].astype('int64')

# %%
df['Владельцы'].value_counts()
# Out:
# 3    33682
# 1    22789
# 2    20667
# 0     8663
# Name: Владельцы, dtype: int64

# %%
df['Владельцы'].shape
# Out:
# (85801,)

# %%
len_train = len(df[df['Train']==1])
print('Кол-во строк в трейне: ', len_train)
# Out:
# Кол-во строк в трейне:  51115

# %% [markdown]
# ### 15.Состояние

# %%
Train_df = df[df['Train']==1]
Test_df = df[df['Train']==0]
display(Train_df['Состояние'].value_counts(),
Test_df['Состояние'].value_counts())
# Out:
# Series([], Name: Состояние, dtype: int64)
# Не требует ремонта    34686
# Name: Состояние, dtype: int64

# %% [markdown]
# Так как в тренировочном датасете данный признак пуст а в тестовом всего один признак, удалим его

# %%
cat_cols.remove('Состояние')

# %% [markdown]
# ### 16.ПТС

# %%
Train_df = df[df['Train']==1]
Test_df = df[df['Train']==0]
display(Train_df['ПТС'].value_counts(),
Test_df['ПТС'].value_counts())
print(f"Пропуски train: {Train_df['ПТС'].isna().sum()}")
print(f"Пропуски test: {Test_df['ПТС'].isna().sum()}")
# Out:
# Оригинал    45660
# Дубликат     5197
# Name: ПТС, dtype: int64
# Оригинал    30098
# Дубликат     4587
# Name: ПТС, dtype: int64
# Пропуски train: 258
# Пропуски test: 1

# %%
# Заполним отсутствующие значения вариантом "нет"
df['ПТС'].fillna('Нет', inplace = True)

# %% [markdown]
# ### ПТС
# Категориальный признак, добавили значение 'Нет' для проусков, 3 значения, пропусков нет, можно перевести в числовой

# %%
len_train = len(df[df['Train']==1])
print('Кол-во строк в трейне: ', len_train)
# Out:
# Кол-во строк в трейне:  51115

# %% [markdown]
# #### 17. vendor

# %%
Train_df = df[df['Train']==1]
Test_df = df[df['Train']==0]
display(Train_df['vendor'].value_counts(),
Test_df['vendor'].value_counts())
print(f"Пропуски train: {Train_df['vendor'].isna().sum()}")
print(f"Пропуски test: {Test_df['vendor'].isna().sum()}")
# Out:
# EUROPEAN    22289
# JAPANESE    13730
# KOREAN       7269
# AMERICAN     5914
# CHINESE       988
# RUSSIAN       925
# Name: vendor, dtype: int64
# EUROPEAN    20682
# JAPANESE    14004
# Name: vendor, dtype: int64
# Пропуски train: 0
# Пропуски test: 0

# %% [markdown]
# Категориальный признак, пропусков нет

# %% [markdown]
# #### 18.  hidden
# Удаляем признак , так как не понятно как его заполнять

# %%
cat_cols.remove('hidden')

# %% [markdown]
# ### 19. equipment_dict

# %%
Train_df = df[df['Train']==1]
Test_df = df[df['Train']==0]
#display(Train_df['equipment_dict'].value_counts(),
#Test_df['equipment_dict'].value_counts())
print(f"Пропуски train: {Train_df['equipment_dict'].isna().sum()}")
print(f"Пропуски test: {Test_df['equipment_dict'].isna().sum()}")
# Out:
# Пропуски train: 0
# Пропуски test: 9996

# %% [markdown]
# #### 19. equipment_dict
# Нет возможности заполнить тестовый пропуски, пока что удалю этот признак

# %%
cat_cols.remove('equipment_dict')

# %% [markdown]
# ### 20. Price
# #### Цена
# Целевая переменная

# %% [markdown]
# Рассмотрим пропуски, и удалим их поскольку делать подгон целевой переменной бессмысленно

# %%
print(f"Пропуски: {df[df['Train']==1]['price'].isna().sum()}")
df = df[((df['Train']==1)&(df['price'].isna()==False)) | (df['Train']==0)]
# Out:
# Пропуски: 173

# %% [markdown]
# #### Price
# Целевая переменная, пропуски удалены

# %%
len_train = len(df[df['Train']==1])
print('Кол-во строк в трейне: ', len_train)
# Out:
# Кол-во строк в трейне:  50942

# %% [markdown]
# Остались только пременные sell_id и Train

# %%
# пронумеруем трейн 
df.loc[df['Train']==1,'sell_id'] = np.array(range(1000000, 1000000+len(df[df['Train']==1])))

# %%
df.sell_id
# Out:
# 0        1.000000e+06
# 1        1.000001e+06
# 2        1.000002e+06
# 5        1.000003e+06
# 6        1.000004e+06
#              ...
# 92552    1.101369e+09
# 92553    1.101370e+09
# 92554    1.101365e+09
# 92555    1.101363e+09
# 92556    1.101256e+09
# Name: sell_id, Length: 85628, dtype: float64

# %%
plt.figure(figsize=(10,5))
display(df[num_cols].corr().abs())
sns.heatmap(df[num_cols].corr().abs(), vmin=0, vmax=1, annot=True)
# Out:
#                      modelDate  numberOfDoors  productionDate   mileage  \
# modelDate             1.000000       0.216024        0.971871  0.697329
# numberOfDoors         0.216024       1.000000        0.226579  0.120661
# productionDate        0.971871       0.226579        1.000000  0.720969
# mileage               0.697329       0.120661        0.720969  1.000000
# fuelType              0.109406       0.139420        0.116202  0.027998
# engineDisplacement2   0.005132       0.061302        0.028240  0.031453
# enginePower           0.190110       0.002960        0.159457  0.118328
# count_words_d         0.368142       0.111601        0.378342  0.395363
# mean_c_w              0.361291       0.105272        0.370737  0.388518
# sum_c_w               0.361291       0.105272        0.370737  0.388518
#
#                      fuelType  engineDisplacement2  enginePower  \
# modelDate            0.109406             0.005132     0.190110
# numberOfDoors        0.139420             0.061302     0.002960
# productionDate       0.116202             0.028240     0.159457
# mileage              0.027998             0.031453     0.118328
# fuelType             1.000000             0.255197     0.138865
# engineDisplacement2  0.255197             1.000000     0.825273
# enginePower          0.138865             0.825273     1.000000
# count_words_d        0.053527             0.022200     0.088910
# mean_c_w             0.060033             0.029808     0.099235
# sum_c_w              0.060033             0.029808     0.099235
#
#                      count_words_d  mean_c_w   sum_c_w
# modelDate                 0.368142  0.361291  0.361291
# numberOfDoors             0.111601  0.105272  0.105272
# productionDate            0.378342  0.370737  0.370737
# mileage                   0.395363  0.388518  0.388518
# fuelType                  0.053527  0.060033  0.060033
# engineDisplacement2       0.022200  0.029808  0.029808
# enginePower               0.088910  0.099235  0.099235
# count_words_d             1.000000  0.995466  0.995466
# mean_c_w                  0.995466  1.000000  1.000000
# sum_c_w                   0.995466  1.000000  1.000000

# %% [markdown]
# Как мы видим высокая корреляция между modelDate и productionDate, enginePower и engineDisplacement2
# Удалим признаки modelDate и enginePower, поскольку у них более высокая корреляция с другими признаками

# %%
num_cols.remove("modelDate")
num_cols.remove("enginePower")

# %% [markdown]
# ### Значимость переменных

# %%
imp_num = pd.Series(f_classif(df[df['Train']==1][num_cols], df[df['Train']==1]['price'])[0], index = num_cols)
imp_num.sort_values(inplace = True)
imp_num.plot(kind = 'barh')
plt.title('Significance of num variables')
plt.xlabel('F-value')
# Out:
# Text(0.5, 0, 'F-value')

# %% [markdown]
# Как видим наиболее значимый числовой признак  это количество слов
# минимальный -  количество дверей. попробуем удалить и узнаем измениться ли результаты

# %%
#num_cols.remove("numberOfDoors")

# %% [markdown]
# ### Подготовка данных к машинному обучению

# %%
all_cols =cat_cols+num_cols+servis_cols+bin_cols+ target_col
print(f'Кол-во столбцов, для дальнейшей работы после предварительного анализа:= {len(all_cols)}')
# Out:
# Кол-во столбцов, для дальнейшей работы после предварительного анализа:= 21

# %%
df2 = df[all_cols]

# %%
describe_cols(df2)
# Out:
#                 Признак      Тип Кол-во значений Кол-во пропусков(NaN)  \
# 0              bodyType   object           85628                     0
# 1                 brand   object           85628                     0
# 2                 color   object           85628                     0
# 3   vehicleTransmission   object           85628                     0
# 4                Привод   object           85628                     0
# 5                  Руль   object           85628                     0
# 6             Владельцы    int64           85628                     0
# 7                   ПТС   object           85628                     0
# 8                vendor   object           85628                     0
# 9            model_name   object           85628                     0
# 10        numberOfDoors    int64           85628                     0
# 11       productionDate  float64           85628                     0
# 12              mileage    int64           85628                     0
# 13             fuelType    int64           85628                     0
# 14  engineDisplacement2  float64           85628                     0
# 15        count_words_d    int64           85628                     0
# 16             mean_c_w  float64           85628                     0
# 17              sum_c_w    int64           85628                     0
# 18                Train    int64           85628                     0
# 19              sell_id  float64           85628                     0
# 20                price  float64           50942                 34686
#
#    Кол-во уникальных
# 0                 24
# 1                 36
# 2                 16
# 3                  4
# 4                  3
# 5                  2
# 6                  4
# 7                  3
# 8                  6
# 9               1045
# 10                 5
# 11                78
# 12             22764
# 13                 5
# 14                 7
# 15              1234
# 16              2661
# 17              1022
# 18                 2
# 19             85628
# 20              6790

# %%
len(df[df['Train']==0])
# Out:
# 34686

# %%
df3 = pd.get_dummies(df2, columns = ['bodyType', 'brand', 'color', 'fuelType', 'vehicleTransmission', 'Привод', 'Владельцы', 'Руль','ПТС', 'model_name', 'engineDisplacement2','vendor'])

# %%
train_data = df3.query('Train == 1').drop(['Train', 'sell_id'], axis=1)
test_data = df3.query('Train == 0').drop(['Train', 'sell_id'], axis=1)

y = train_data.price            # наш таргет
X = train_data.drop(['price'], axis=1)
# Воспользуемся специальной функцие train_test_split для разбивки тестовых данных
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=RANDOM_SEED)
# проверяем
test_data.shape, train_data.shape, X.shape, X_train.shape, X_test.shape
# Out:
# ((34686, 1162), (50942, 1162), (50942, 1161), (40753, 1161), (10189, 1161))

# %% [markdown]
# ### Обучение моделей

# %%
def mape(y_true, y_pred):
        '''
        mean absolute percentage error (средняя абсолютная процентная ошибка)
        '''
        return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
# CATBOOST
ITERATIONS = 5000
LR         = 0.1

# %%
model = CatBoostRegressor(iterations = ITERATIONS,
                          learning_rate = LR,
                          random_seed = RANDOM_SEED,
                          eval_metric='MAPE',
                          custom_metric=['R2', 'MAE']
                         )
model.fit(X_train, y_train,
         #cat_features=cat_features_ids,
         eval_set=(X_test, y_test),
         verbose_eval=100,
         use_best_model=True,
         plot=True
         )
# Out:
#             <style>
#                 .highcharts-tooltip {
#     display: none !important;
# }
# .highcharts-halo {
#     display: none !important;
# }
#
# .catboost {
#     position: relative;
# }
#
# .catboost-panel {
#     position: absolute;
#     height: 100%;
#     width: 280px;
# }
#
# .catboost-panel__controls {
#     margin-left: 0;
# }
#
# .catboost-panel__controls_label {
#     padding: 5px 0 0 8px;
#     cursor: pointer;
#     width: 80px;
#     box-sizing: content-box;
# }
# .catboost-panel__controls_label_time {
#     width: inherit;
# }
#
# .catboost-panel__controls2 {
#     margin-top: 10px;
# }
#
# .catboost-panel__controls2_label {
#     padding: 5px 11px 0 8px;
#     cursor: pointer;
#     width: 90px;
#     box-sizing: content-box;
# }
# .catboost-panel__controls2_label-long {
#     width: 170px;
# }
#
# .catboost-panel__series {
#     height: 340px;
#     overflow-y: auto;
# }
#
# .catboost-graph {
#     margin-left: 290px;
# }
#
# .catboost-graph__tabs {
#     padding: 0 0 0 20px;
# }
#
# .catboost-graph__tab {
#     display: inline-block;
#     padding: 5px 10px 0 0;
# }
#
# .catboost-graph__tab {
#     color: #999;
#     cursor: pointer;
#     transition: color 0.1s linear;
# }
#
# .catboost-graph__tab:hover {
#     color: #333;
# }
#
# .catboost-graph__tab_active {
#     color: #000;
#     cursor: auto;
# }
#
# .catboost-graph__charts {
#     padding-top: 20px;
# }
#
# .catboost-graph__chart {
#     display: none;
# }
#
# .catboost-graph__chart_active {
#     display: block;
# }
#
# .catboost-panel__serie {
#     padding-bottom: 5px;
#     border-bottom: 1px solid rgba(0, 0, 0, 0.3);
#     position: relative;
# }
#
# .catboost-panel__serie_bottom,
# .catboost-panel__serie_middle,
# .catboost-panel__serie_top {
#     white-space: nowrap;
#     position: relative;
# }
#
# #catboost-control-test {
#     margin-left: 11px;
# }
#
# .catboost-panel__serie_label {
#     padding: 0 0 0 8px;
#     width: 200px;
#     text-overflow: ellipsis;
#     box-sizing: border-box;
#     cursor: pointer;
#     margin-bottom: 0;
#     overflow: hidden;
#     position: relative;
#     top: 5px;
# }
#
# .catboost-panel__serie_hint {
#     position: absolute;
#     font-size: 9px;
#     left: 0;
# }
#
# .catboost-panel__serie__learn_hint {
#     top: 56px;
# }
#
# .catboost-panel__serie__test_hint {
#     top: 82px;
# }
#
# .catboost-panel__serie_bottom {
#     padding-bottom: 6px;
# }
#
# .catboost-panel__serie_time {
#     position: absolute;
#     top: 5px;
#     right: 2px;
#     height: 20px;
#     padding: 0 0 0 20px;
#     margin-bottom: 3px;
#     overflow: hidden;
#
#     text-overflow: ellipsis;
#     box-sizing: border-box;
#     text-align: left;
# }
#
# .catboost-panel__serie_learn_pic,
# .catboost-panel__serie_test_pic {
#     width: 13px;
#     height: 1px;
#     border-top-width: 1px;
#     position: relative;
#     top: -3px;
#     margin-right: 5px;
# }
#
# .catboost-panel__serie_learn_pic {
#     border-top-style: dashed;
# }
#
# .catboost-panel__serie_test_pic {
#     border-top-style: solid;
# }
#
# .catboost-panel__serie-value {
#     display: inline-block;
#     min-width: 30px;
#     margin-right: 2px;
# }
#
# .catboost-panel__controls_label .catboost-panel__serie_learn_pic {
#     padding-left: 4px;
# }
#
# .catboost-panel__serie_names {
#     white-space: nowrap;
# }
#
# .catboost-panel__serie_scroll {
#     width: 240px;
#     overflow-x: auto;
#     margin-left: 20px;
# }
#
# .catboost-panel__serie_learn_name,
# .catboost-panel__serie_test_name,
# .catboost-panel__serie_learn_value,
# .catboost-panel__serie_test_value,
# .catboost-panel__serie_best_learn_value,
# .catboost-panel__serie_best_test_value {
#     width: 85px;
#     position: relative;
#     padding: 0 8px 0 0;
#     box-sizing: content-box;
#     overflow: hidden;
#     text-overflow: ellipsis;
#     top: 5px;
# }
#
# .catboost-panel__serie_iteration,
# .catboost-panel__serie_best_iteration {
#     display: inline-block;
#     position: absolute;
#     box-sizing: content-box;
#     overflow: hidden;
#     right: 2px;
# }
#
# .catboost-panel__serie_iteration {
#     top: 55px;
# }
#
# .catboost-panel__serie_best_iteration {
#     top: 80px;
# }
#
# .catboost-panel__control_slider {
#     width: 100px !important;
#     margin-left: 0;
#     position: relative;
#     display: inline-block !important;
#     top: 3px;
# }
#
# .catboost-panel__control_slidervalue {
#     width: 50px;
#     padding: 2px 3px;
#     margin-left: 4px;
# }
#
# .catboost-panel__serie_time_spend,
# .catboost-panel__serie_time_left {
#     display: inline-block;
# }
#
# .catboost-panel__serie_time_left {
#     margin-left: 10px;
# }
#
# .catboost-panel__serie_learn_pic,
# .catboost-panel__serie_learn_name,
# .catboost-panel__serie_learn_value,
# .catboost-panel__serie_best_learn_value {
#     display: inline-block;
# }
# .catboost-panel__serie_test_pic,
# .catboost-panel__serie_test_name,
# .catboost-panel__serie_test_value,
# .catboost-panel__serie_best_test_value {
#     display: inline-block;
# }
#
# .catboost-panel__series_learn_disabled .catboost-panel__serie_learn_pic,
# .catboost-panel__series_learn_disabled .catboost-panel__serie_learn_name,
# .catboost-panel__series_learn_disabled .catboost-panel__serie_learn_value,
# .catboost-panel__series_learn_disabled .catboost-panel__serie_best_learn_value {
#     display: none;
# }
# .catboost-panel__series_test_disabled .catboost-panel__serie_test_pic,
# .catboost-panel__series_test_disabled .catboost-panel__serie_test_name,
# .catboost-panel__series_test_disabled .catboost-panel__serie_test_value,
# .catboost-panel__series_test_disabled .catboost-panel__serie_best_test_value {
#     display: none;
# }
#
# /*
# .catboost-panel__series_learn_disabled .catboost-panel__serie_test_value,
# .catboost-panel__series_learn_disabled .catboost-panel__serie_best_test_value {
#     width: 216px;
# }
# .catboost-panel__series_test_disabled .catboost-panel__serie_learn_value,
# .catboost-panel__series_test_disabled .catboost-panel__serie_best_learn_value {
#     width: 216px;
# }
# */
# .catboost-panel__series_test_disabled .catboost-panel__serie__test_hint,
# .catboost-panel__series_test_disabled .catboost-panel__serie_best_iteration {
#     display: none;
# }
#
# .catboost-panel__series_test_disabled.catboost-panel__series_learn_disabled .catboost-panel__serie_middle {
#     display: none;
# }
#
# .catboost-panel__series_test_disabled .catboost-panel__serie_bottom {
#     display: none;
# }
#
#             </style>
#             <script>
#                 window.__define = window.define;window.__require = window.require;window.define = undefined;window.require = undefined;/**
# * plotly.js (basic - minified) v1.27.1
# * Copyright 2012-2017, Plotly, Inc.
# * All rights reserved.
# * Licensed under the MIT license
# */
# !function(t){if("object"==typeof exports&&"undefined"!=typeof module)module.exports=t();else if("function"==typeof define&&define.amd)define([],t);else{var e;e="undefined"!=typeof window?window:"undefined"!=typeof global?global:"undefined"!=typeof self?self:this,e.Plotly=t()}}(function(){var t;return function t(e,r,n){function a(i,l){if(!r[i]){if(!e[i]){var s="function"==typeof require&&require;if(!l&&s)return s(i,!0);if(o)return o(i,!0);var c=new Error("Cannot find module '"+i+"'");throw c.code="MODULE_NOT_FOUND",c}var u=r[i]={exports:{}};e[i][0].call(u.exports,function(t){var r=e[i][1][t];return a(r||t)},u,u.exports,t,e,r,n)}return r[i].exports}for(var o="function"==typeof require&&require,i=0;i<n.length;i++)a(n[i]);return a}({1:[function(t,e,r){"use strict";var n=t("../src/lib"),a={"X,X div":"font-family:'Open Sans', verdana, arial, sans-serif;margin:0;padding:0;","X input,X button":"font-family:'Open Sans', verdana, arial, sans-serif;","X input:focus,X button:focus":"outline:none;","X a":"text-decoration:none;","X a:hover":"text-decoration:none;","X .crisp":"shape-rendering:crispEdges;","X .user-select-none":"-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;-o-user-select:none;user-select:none;","X svg":"overflow:hidden;","X svg a":"fill:#447adb;","X svg a:hover":"fill:#3c6dc5;","X .main-svg":"position:absolute;top:0;left:0;pointer-events:none;","X .main-svg .draglayer":"pointer-events:all;","X .cursor-default":"cursor:default;","X .cursor-pointer":"cursor:pointer;","X .cursor-crosshair":"cursor:crosshair;","X .cursor-move":"cursor:move;","X .cursor-col-resize":"cursor:col-resize;","X .cursor-row-resize":"cursor:row-resize;","X .cursor-ns-resize":"cursor:
# MetricVisualizer(layout=Layout(align_self='stretch', height='500px'))
# 0:	learn: 1
# 3000:	learn: 0.1195486	test: 0.1408802	best: 0.1408802 (3000)	total: 32.5s	remaining: 21.7s
# 3100:	learn: 0.1188965	test: 0.1404690	best: 0.1404690 (3100)	total: 33.7s	remaining: 20.7s
# 3200:	learn: 0.1180049	test: 0.1399262	best: 0.1399262 (3200)	total: 35s	remaining: 19.7s
# 3300:	learn: 0.1174079	test: 0.1398067	best: 0.1397966 (3294)	total: 36.4s	remaining: 18.7s
# 3400:	learn: 0.1167220	test: 0.1395124	best: 0.1394946 (3391)	total: 37.6s	remaining: 17.7s
# 3500:	learn: 0.1160080	test: 0.1391636	best: 0.1391634 (3499)	total: 38.8s	remaining: 16.6s
# 3600:	learn: 0.1153123	test: 0.1388411	best: 0.1388411 (3599)	total: 40.3s	remaining: 15.7s
# 3700:	learn: 0.1147191	test: 0.1385606	best: 0.1385584 (3693)	total: 41.6s	remaining: 14.6s
# 3800:	learn: 0.1141229	test: 0.1382208	best: 0.1382208 (3800)	total: 42.8s	remaining: 13.5s
# 3900:	learn: 0.1135989	test: 0.1380110	best: 0.1380110 (3900)	total: 44.3s	remaining: 12.5s
# 4000:	learn: 0.1129845	test: 0.1377145	best: 0.1377145 (4000)	total: 45.7s	remaining: 11.4s
# 4100:	learn: 0.1124142	test: 0.1376042	best: 0.1376042 (4100)	total: 47.2s	remaining: 10.4s
# 4200:	learn: 0.1119388	test: 0.1374498	best: 0.1374498 (4200)	total: 48.5s	remaining: 9.23s
# 4300:	learn: 0.1114388	test: 0.1372593	best: 0.1372593 (4300)	total: 49.7s	remaining: 8.09s
# 4400:	learn: 0.1106718	test: 0.1368735	best: 0.1368732 (4397)	total: 51.3s	remaining: 6.98s
# 4500:	learn: 0.1101402	test: 0.1367435	best: 0.1367435 (4500)	total: 52.6s	remaining: 5.83s
# 4600:	learn: 0.1096549	test: 0.1365228	best: 0.1365159 (4597)	total: 54.3s	remaining: 4.71s
# 4700:	learn: 0.1092401	test: 0.1364287	best: 0.1364007 (4688)	total: 55.6s	remaining: 3.53s
# 4800:	learn: 0.1087587	test: 0.1362911	best: 0.1362760 (4738)	total: 57.2s	remaining: 2.37s
# 4900:	learn: 0.1082354	test: 0.1360918	best: 0.1360918 (4900)	total: 58.6s	remaining: 1.18s
# 4999:	learn: 0.1077938	test: 0.1360016	best: 0.1359847 (4966)	total: 1m	remaining: 0us
#
# bestTest = 0.1359846605
# bestIteration = 4966
#
# Shrink model to first 4967 iterations.

# %%
model.save_model('catboost_single_model_baseline.model')

# %%
predict = model.predict(X_test)

# оцениваем точность
print(f"Точность модели по метрике MAPE: {(mape(y_test, predict)):0.2f}%")
# Out:
# Точность модели по метрике MAPE: 13.60%

# %%
train_data1 = df3.query('Train == 1').drop(['Train', 'sell_id','price'], axis=1)
train_data = df3.query('Train == 1').drop(['Train', 'sell_id'], axis=1)
test_data = df3.query('Train == 0').drop(['Train', 'sell_id'], axis=1)
X = StandardScaler().fit_transform(train_data1)
test = StandardScaler().fit_transform(test_data)
Y = train_data['price'].values

# Воспользуемся специальной функцие train_test_split для разбивки тестовых данных
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=RANDOM_SEED)
# проверяем
test_data.shape, train_data.shape, X.shape, X_train.shape, X_test.shape
# Out:
# C:\Programs\anaconda\lib\site-packages\sklearn\utils\extmath.py:770: RuntimeWarning: invalid value encountered in true_divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# C:\Programs\anaconda\lib\site-packages\sklearn\utils\extmath.py:711: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   result = op(x, *args, **kwargs)
# ((34686, 1162), (50942, 1162), (50942, 1161), (40753, 1161), (10189, 1161))

# %%
# %%time
tree = DecisionTreeRegressor(max_features=int(X_train.shape[1]/3), max_depth=50)
tree.fit(X_train, y_train)
test_predict = tree.predict(X_test)
print(f"DecisionTreeRegressor Test MAPE: {mape(y_test, test_predict):0.3f}%")
# Out:
# DecisionTreeRegressor Test MAPE: 20.301%
# Wall time: 1.87 s

# %%
# %%time
gbr = GradientBoostingRegressor(n_estimators=100)
gbr.fit(X_train, y_train)
y_pred = gbr.predict(X_test)
print(f"GradientBoostingRegressor Test MAPE: {mape(y_test, y_pred):0.3f}%")
# Out:
# GradientBoostingRegressor Test MAPE: 29.483%
# Wall time: 3min 1s

# %%
# %%time
etr = ExtraTreesRegressor(random_state = RANDOM_SEED)
etr.fit(X_train, y_train)
y_pred = etr.predict(X_test)
print(f"ExtraTreeRegressor Test MAPE: {mape(y_test, y_pred):0.3f}%")
# Out:
# ExtraTreeRegressor Test MAPE: 13.864%
# Wall time: 6min 45s

# %%
# %%time
model = RandomForestRegressor(random_state = RANDOM_SEED, n_jobs = -1, verbose = 1)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
print(f"RandomForestRegressor Test MAPE: {mape(y_test, y_pred):0.3f}%")
# Out:
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:   18.7s
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:   53.8s finished
# [Parallel(n_jobs=12)]: Using backend ThreadingBackend with 12 concurrent workers.
# [Parallel(n_jobs=12)]: Done  26 tasks      | elapsed:    0.0s
# RandomForestRegressor Test MAPE: 13.792%
# Wall time: 54.4 s
# [Parallel(n_jobs=12)]: Done 100 out of 100 | elapsed:    0.0s finished

# %% [markdown]
# Итого лучший показатель у RandomForest MAPE - 13.60

# %% [markdown]
# Итоговые расчеты

# %%
train = df3.query('Train==1').drop(['Train', 'sell_id', ], axis = 1)
test = df3.query('Train==0').drop(['Train', 'sell_id'], axis = 1)
y_train = train.price.values            # наш таргет
X_train = train.drop(['price'], axis=1)

X_valid = test.drop(['price'], axis=1)

# %%
models = [CatBoostRegressor(iterations = ITERATIONS,
                          learning_rate = LR,
                          random_seed = RANDOM_SEED,
                          eval_metric='MAPE',
                          custom_metric=['R2', 'MAE']
                         ),
          ExtraTreesRegressor(random_state = RANDOM_SEED),
          RandomForestRegressor(random_state = RANDOM_SEED, n_jobs = -1, verbose = 1)]

# %%
def stacking_model_predict(d_models, X_train, y_train, X_test, df):
    for model_ in tqdm(d_models):
        model_.fit(X_train, y_train)
        y_pred = model_.predict(X_test)
        df[str(model_)[:6]] = np.round((y_pred)/10000,2)*10000
    df['price'] = df.iloc[:,2:].mean(axis=1)    
    return

# %%
# %%time
stacking_model_predict(models, X_train, y_train, X_valid, submit)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=3.0), HTML(value='')))
# 0:	learn: 1.7900873	total: 11ms	remaining: 55.2s
# 1:	learn: 1.6498357	total: 22ms	remaining: 54.9s
# 2:	learn: 1.5261577	total: 33.6ms	remaining: 56s
# 3:	learn: 1.4148243	total: 45.4ms	remaining: 56.7s
# 4:	learn: 1.3209092	total: 56.1ms	remaining: 56.1s
# 5:	learn: 1.2253303	total: 66.5ms	remaining: 55.4s
# 6:	learn: 1.1364422	total: 76.6ms	remaining: 54.6s
# 7:	learn: 1.0664352	total: 87ms	remaining: 54.3s
# 8:	learn: 1.0034149	total: 97.3ms	remaining: 54s
# 9:	learn: 0.9320384	total: 109ms	remaining: 54.2s
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:   11.7s
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:   34.7s finished
# [Parallel(n_jobs=12)]: Using backend ThreadingBackend with 12 concurrent workers.
# [Parallel(n_jobs=12)]: Done  26 tasks      | elapsed:    0.0s
# Wall time: 6min 29s
# [Parallel(n_jobs=12)]: Done 100 out of 100 | elapsed:    0.1s finished

# %%
submit[['sell_id', 'price']]
# Out:
#           sell_id         price
# 0      1100575026  7.792333e+05
# 1      1100549428  1.110033e+06
# 2      1100658222  8.151333e+05
# 3      1100937408  7.685667e+05
# 4      1101037972  8.007667e+05
# ...           ...           ...
# 34681  1101369263  9.955333e+05
# 34682  1101369581  2.394267e+06
# 34683  1101364889  2.757667e+05
# 34684  1101362518  1.272233e+06
# 34685  1101256068  1.105133e+06
#
# [34686 rows x 2 columns]

# %% [markdown]
# #### Следущий код доделать

# %% [markdown]
# train = df3.query('Train == 1').drop(['Train', 'sell_id'], axis=1)
# test = df3.query('Train == 0').drop(['Train', 'sell_id'], axis=1)
# test1 = df3.query('Train == 1').drop(['Train', 'sell_id','price'], axis=1)
# X = train.values
# y = df['price'][df['Train'] == 1]
# y = y.values
# X_pred = test1.values
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=True, random_state=42)

# %% [markdown]
# cv = KFold(n_splits=5, shuffle=True, random_state=42)
#
# def compute_metric(regr, X_train=X_train, y_train=y_train, X_test=X_test, y_test=y_test):
#     regr.fit(X_train, y_train)
#     y_test_pred = regr.predict(X_test)
#     return np.round(mape(y_test, y_test_pred)*100, 3)

# %% [markdown]
# def compute_meta_feature2(regr, X_train, X_test, y_train, cv, X_pred):
#
#     X_meta_train = np.zeros_like(y_train, dtype=np.float32)
#
#     splits = cv.split(X_train)
#     for train_fold_index, predict_fold_index in splits:
#         X_fold_train, X_fold_predict = X_train[train_fold_index], X_train[predict_fold_index]
#         y_fold_train = y_train[train_fold_index]
#
#         folded_regr = clone(regr)
#         folded_regr.fit(X_fold_train, y_fold_train)
#
#         X_meta_train[predict_fold_index] = folded_regr.predict(X_fold_predict)
#
#     meta_regr = clone(regr)
#     meta_regr.fit(X_train, y_train)
#
#     X_meta_test = meta_regr.predict(X_test)
#     X_meta_pred = meta_regr.predict(X_pred)
#
#     return X_meta_train, X_meta_test, X_meta_pred

# %% [markdown]
# def generate_meta_features2(regr_s, X_train, X_test, y_train, cv, X_pred):
#
#     features = [compute_meta_feature2(regr, X_train, X_test, y_train, cv, X_pred) for regr in tqdm(regr_s)]
#     stacked_features_train = np.vstack([features_train for features_train, features_test, features_pred in features]).T
#     stacked_features_test = np.vstack([features_test for features_train, features_test, features_pred in features]).T
#     stacked_features_pred = np.vstack([features_pred for features_train, features_test, features_pred in features]).T
#     return stacked_features_train, stacked_features_test, stacked_features_pred

# %% [markdown]
# stacked_features_train, stacked_features_test, stacked_features_pred = generate_meta_features2([
#     RandomForestRegressor(n_estimators=300, min_samples_split=2, min_samples_leaf=1,
#                           max_features='sqrt',max_depth=77, bootstrap=True, random_state=42),
#     AdaBoostRegressor(random_state=42),
#     ExtraTreesRegressor(random_state=42),
#     RandomForestRegressor(random_state=42)], X_train, X_test, y_train, cv, X_pred)
#
# regr = RandomForestRegressor(
#  n_estimators=300,
#  min_samples_split=2,
#  min_samples_leaf=1,
#  max_features='sqrt',
#  max_depth=77,
#  bootstrap=True,
#  random_state=42)
#
# print(f'Stacking MAPE = {compute_metric(regr, X_train=stacked_features_train, y_train=y_train, X_test=stacked_features_test, y_test=y_test)}%')
