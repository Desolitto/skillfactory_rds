# %%
import re
import numpy as np
import pandas as pd
import requests
import time
import os
from bs4 import BeautifulSoup
from collections import Counter

# %%
c = Counter()
for index, row in data.iterrows():
    names = row.production_companies.split(sep='|')
    for name in names:
        c[name]+=len(row.original_title)
len_film = c.most_common()
len_films = pd.DataFrame(data=len_film, columns=['production_companies','len_title'], dtype=None, copy=False)

# %%
b=0
if a in df_marks:
    b+=1
else:
    marks.setdefault(a, b)
    df_marks.append(a)

# %%
import pdb  
marks={}
df_marks= []
b=0
for elem in data['offers']:
    a = elem['vehicle_info']['mark_info']['code']
    if a in df_marks:
        b+=1
    else:
        marks.setdefault(a, b)
        df_marks.append(a)
        b=0
marks
# Out:
# > <ipython-input-9-948b841d12c3>(7)<module>()
# -> a = elem['vehicle_info']['mark_info']['code']
# (Pdb) next
# > <ipython-input-9-948b841d12c3>(8)<module>()
# -> if a in df_marks:
# (Pdb) next
# > <ipython-input-9-948b841d12c3>(11)<module>()
# -> marks.setdefault(a, b)
# (Pdb)
# > <ipython-input-9-948b841d12c3>(12)<module>()
# -> df_marks.append(a)
# (Pdb) next
# > <ipython-input-9-948b841d12c3>(13)<module>()
# -> b=0
# (Pdb) next
# > <ipython-input-9-948b841d12c3>(5)<module>()
# -> for elem in data['offers']:
# (Pdb) next
# > <ipython-input-9-948b841d12c3>(6)<module>()
# -> pdb.set_trace()
# (Pdb) next
# > <ipython-input-9-948b841d12c3>(7)<module>()
# -> a = elem['vehicle_info']['mark_info']['code']
# (Pdb) next
# > <ipython-input-9-948b841d12c3>(8)<module>()
# -> if a in df_marks:
# (Pdb) next
# > <ipython-input-9-948b841d12c3>(9)<module>()
# -> b+=1
# (Pdb) next
# > <ipython-input-9-948b841d12c3>(5)<module>()
# -> for elem in data['offers']:
# (Pdb) next
# > <ipython-input-9-948b841d12c3>(6)<module>()
# -> pdb.set_trace()
# (Pdb) next
# > <ipython-input-9-948b841d12c3>(7)<module>()
# -> a = elem['vehicle_info']['mark_info']['code']
# (Pdb) exit
# ---------------------------------------------------------------------------
# BdbQuit                                   Traceback (most recent call last)
# <ipython-input-9-948b841d12c3> in <module>
#       5 for elem in data['offers']:
#       6     pdb.set_trace()
# ----> 7     a = elem['vehicle_info']['mark_info']['code']
#       8     if a in df_marks:
#       9         b+=1
#
# <ipython-input-9-948b841d12c3> in <module>
#       5 for elem in data['offers']:
#       6     pdb.set_trace()
# ----> 7     a = elem['vehicle_info']['mark_info']['code']
#       8     if a in df_marks:
#       9         b+=1
#
# C:\Programs\anaconda\lib\bdb.py in trace_dispatch(self, frame, event, arg)
#      86             return # None
#      87         if event == 'line':
# ---> 88             return self.dispatch_line(frame)
#      89         if event == 'call':
#      90             return self.dispatch_call(frame, arg)
#
# C:\Programs\anaconda\lib\bdb.py in dispatch_line(self, frame)
#     111         if self.stop_here(frame) or self.break_here(frame):
#     112             self.user_line(frame)
# --> 113             if self.quitting: raise BdbQuit
#     114         return self.trace_dispatch
#     115
#
# BdbQuit:

# %%
marks={}
df_marks= []
for elem in data['offers']:
    a = elem['vehicle_info']['mark_info']['code']
    df_marks.append(a)
df_marks
# Out:
# ['AUDI',
#  'AUDI',
#  'AUDI',
#  'AUDI',
#  'AUDI',
#  'AUDI',
#  'AUDI',
#  'AUDI',
#  'AUDI',
#  'AUDI',
#  'AUDI',
#  'AUDI',
#  'AUDI',
#  'AUDI',
#  'AUDI',
#  'AUDI',
#  'AUDI',
#  'AUDI',
#  'AUDI',
#  'AUDI',
#  'AUDI',
#  'AUDI',
#  'AUDI',
#  'AUDI',
#  'AUDI',
#  'AUDI',
#  'AUDI',
#  'AUDI',
#  'AUDI',
#  'AUDI',
#  'AUDI',
#  'AUDI',
#  'AUDI',
#  'AUDI',
#  'AUDI',
#  'AUDI',
#  'AUDI',
#  'AUDI']

# %%
for num_page in range(1, 5):
            param = {
                'catalog_filter' : [{"mark": mark, "model": model}],
                'section': "all",
                'category': "cars",
                'sort': "fresh_relevance_1-desc",
                "top_days":"900",
                "geo_radius":200,
                "geo_id":[213],
                'page': num_page
            }
            response = requests.post(url, json=param, headers = HEADERS)
            data = response.json()

# %%
response.headers

# %%
url = "https://auto.ru/-/ajax/desktop/listing/"
HEADERS = {
    'Connection': 'keep-alive',
    'Content-Length': '876',
    'content-type': 'application/json',
    'Cookie': '_csrf_token=1c0ed592ec162073ac34d79ce511f0e50d195f763abd8c24; autoru_sid=a%3Ag5e3b198b299o5jhpv6nlk0ro4daqbpf.fa3630dbc880ea80147c661111fb3270%7C1580931467355.604800.8HnYnADZ6dSuzP1gctE0Fw.cd59AHgDSjoJxSYHCHfDUoj-f2orbR5pKj6U0ddu1G4; autoruuid=g5e3b198b299o5jhpv6nlk0ro4daqbpf.fa3630dbc880ea80147c661111fb3270; suid=48a075680eac323f3f9ad5304157467a.bc50c5bde34519f174ccdba0bd791787; from_lifetime=1580933172327; from=yandex; X-Vertis-DC=myt; crookie=bp+bI7U7P7sm6q0mpUwAgWZrbzx3jePMKp8OPHqMwu9FdPseXCTs3bUqyAjp1fRRTDJ9Z5RZEdQLKToDLIpc7dWxb90=; cmtchd=MTU4MDkzMTQ3MjU0NQ==; yandexuid=1758388111580931457; bltsr=1; ',
    'origin': 'https://auto.ru/cars/all/',
    'Referer': 'https://auto.ru/cars/all/',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:72.0) Gecko/20100101 Firefox/72.0',
    'x-csrf-token': '1c0ed592ec162073ac34d79ce511f0e50d195f763abd8c24',
}

# %%
df_marks_and_models = pd.read_csv('all_car_brands_and_their_models_from_auto_ru.csv', index_col=0)
print('Кол-во марок: ', df_marks_and_models.shape[0])
display(df_marks_and_models.head(2))
# Out:
# Кол-во марок:  262
#                                                   Models
# Mark
# AC                   ['378_GT', 'ACE', 'ACECA', 'COBRA']
# ACURA  ['CL', 'CSX', 'EL', 'ILX', 'INTEGRA', 'LEGEND'...

# %%
def utils_clean_values_dict(dict):
    for elem in dict:
        dict[elem] = 0
    return

# %%
dict_of_num_cars_of_models ={'AC':2, 'Acura':94, 'Alfa Romeo':65, 'Alpina':10, 
                             'AMC':2, 'Ariel':1, 'Asia':1, 'Aston Martin':25, 
                             'Audi':4093, 'Austin Healey':1, 'Bajaj':3, 
                             'Bentley':104, 'BMW':7423, 'Borgward':1, 
                             'Brilliance':10, 'Buick':17, 'BYD':22, 
                             'Cadillac':321, 'Changan':100, 'Chery':593, 
                             'Chevrolet':3670, 'Chrysler':316, 'Citroen':1142, 
                             'Dacia':9, 'Daewoo':1024, 'Daihatsu':47, 
                             'Daimler':5, 'Datsun':212, 'Delage':1, 'Derways':2, 
                             'DKW':1, 'Dodge':413, 'DongFeng':25, 'Doninvest':2, 
                             'DS':3, 'DW Hower':8, 'Eagle':1, 'Excalibur':1, 
                             'FAW':66, 'Ferrari':29, 'Fiat':206, 'Ford':4812, 
                             'Foton':2, 'GAC':14, 'Geely':302, 'Genesis':54, 
                             'GMC':26, 'Great Wall':420, 'Hafei':6, 'Haima':12, 
                             'Haval':110, 'Hawtai':4, 'Heinkel':1, 'Honda':1179, 
                             'HuangHai':1, 'Hummer':70, 'Hyundai':5712, 
                             'Infiniti':1041, 'Innocenti':1, 'Iran Khodro':21, 
                             'Isuzu':43, 'JAC':8, 'Jaguar':308, 'Jeep':466, 'JMC':1, 
                             'Kia':5595, 'LADA (ВАЗ)':8935, 'Lamborghini':14, 
                             'Lancia':8, 'Land Rover':1616, 'Lexus':985, 
                             'Lifan':295, 'Lincoln':62, 'Lotus':1, 'Luxgen':9, 
                             'Mahindra':1, 'Maserati':54, 'Maybach':7, 
                             'Mazda':2311, 'McLaren':5, 'Mercedes-Benz':8005, 
                             'Mercury':16, 'Metrocab':2, 'MG':10, 'MINI':313, 
                             'Mitsubishi':3935, 'Mitsuoka':3, 'Nissan':5776, 
                             'Oldsmobile':10, 'Opel':3131, 'Packard':2, 
                             'Peugeot':1636, 'Plymouth':13, 'Pontiac':38, 
                             'Porsche':714, 'Proton':3, 'PUCH':1, 'Ravon':112, 
                             'Renault':2771, 'Rolls-Royce':55, 'Rover':69, 
                             'Saab':147, 'Saturn':9, 'Scion':9, 'SEAT':77, 
                             'Shanghai Maple':1, 'Skoda':2810, 'Smart':89, 
                             'SsangYong':718, 'Subaru':934, 'Suzuki':878, 
                             'Tatra':5, 'Tesla':43, 'Tianma':2, 'Toyota':4648, 
                             'Triumph':1, 'Vauxhall':1, 'Volkswagen':7109, 
                             'Volvo':2069, 'Vortex':91, 'Wartburg':1, 'Willys':2, 
                             'Zotye':15, 'ZX':4, 'ГАЗ':935, 'Гоночный болид':2, 
                             'ЗАЗ':231, 'ЗИЛ':2, 'ИЖ':129, 'ЛуАЗ':45, 
                             'Москвич':198, 'СМЗ':4, 'ТагАЗ':68, 'УАЗ':1107}

# уберем модели с кол-вом объявлений ниже 300 и повысим регистр индексов 
list_keys_to_delete = []
for mark in dict_of_num_cars_of_models.keys():
    if dict_of_num_cars_of_models[mark] < 300:
        list_keys_to_delete.append(mark)
    
for key in list_keys_to_delete: del dict_of_num_cars_of_models[key]

for mark in list(dict_of_num_cars_of_models.keys()):
    mark_up = mark.upper()
    dict_of_num_cars_of_models[mark_up]=dict_of_num_cars_of_models.pop(mark)
    
# Удалим отечественные модели
for key in ['LADA (ВАЗ)','ГАЗ','УАЗ']: del dict_of_num_cars_of_models[key]
# исправим несоответствия
dict_of_num_cars_of_models['GREAT_WALL']=dict_of_num_cars_of_models.pop('GREAT WALL')
dict_of_num_cars_of_models['LAND_ROVER']=dict_of_num_cars_of_models.pop('LAND ROVER')
dict_of_num_cars_of_models['MERCEDES']=dict_of_num_cars_of_models.pop('MERCEDES-BENZ')
dict_of_num_cars_of_models['SSANG_YONG']=dict_of_num_cars_of_models.pop('SSANGYONG')

# запишем список релевантных марок для парсинга
list_of_relevant_marks = list(dict_of_num_cars_of_models.keys())

# %%
sum_of_ads = sum(dict_of_num_cars_of_models.values())
print(f"примерное кол-во строк после парсинга должно быть := {sum_of_ads}")
# Out:
# примерное кол-во строк после парсинга должно быть := 89189

# %%
dict_columns = {'bodyType':0, 'brand':0, 'color':0, 'fuelType':0, 'modelDate':0, 
                'name':0, 'numberOfDoors':0, 'productionDate':0, 
                'vehicleConfiguration':0, 'vehicleTransmission':0, 
                'engineDisplacement':0, 'enginePower':0, 'description':0, 
                'mileage':0, 'Комплектация':0, 'Привод':0, 'Руль':0, 
                'Состояние':0, 'Владельцы':0, 'ПТС':0, 'Таможня':0, 
                'Владение':0,'price':0, }

# создаем функцию для обработки 23 необходимых столбцов
def from_elem_to_dict(d_elem, d_dict):
    utils_clean_values_dict(d_dict)
    
    try: d_dict['bodyType'] = d_elem['vehicle_info']['configuration']['human_name']
    except: d_dict['bodyType'] = None

    try: d_dict['brand'] = d_elem['vehicle_info']['mark_info']['code']
    except: d_dict['brand'] = None

    try: d_dict['color'] = d_elem['color_hex']
    except: d_dict['color'] = None

    try: d_dict['fuelType'] = d_elem['lk_summary'].split()[-1]
    except: d_dict['fuelType'] = None

    try: d_dict['modelDate'] = d_elem['vehicle_info']['super_gen']['year_from']
    except: d_dict['modelDate'] = None

    try: d_dict['name'] =  d_elem['vehicle_info']['tech_param']['human_name']
    except: d_dict['name'] = None

    try: d_dict['numberOfDoors'] = d_elem['vehicle_info']['configuration']['doors_count']
    except: d_dict['numberOfDoors'] = None

    try: d_dict['productionDate'] = d_elem['documents']['year']
    except: d_dict['productionDate'] = None

    try: d_dict['vehicleTransmission'] = d_elem['vehicle_info']['tech_param']['transmission']
    except: d_dict['vehicleTransmission'] = None

    try: d_dict['engineDisplacement'] = d_elem['vehicle_info']['tech_param']['human_name'].split()[0]
    except: d_dict['engineDisplacement'] = None

    try: d_dict['vehicleConfiguration'] = elem['vehicle_info']['configuration']['body_type']+' '+d_dict['vehicleTransmission']+' '+d_dict['engineDisplacement']
    except: d_dict['vehicleConfiguration'] = None

    try: d_dict['enginePower'] = d_elem['vehicle_info']['tech_param']['power']
    except: d_dict['enginePower'] = None

    try: d_dict['description'] = d_elem['description']
    except: d_dict['description'] = None

    try: d_dict['mileage'] = d_elem['state']['mileage']
    except: d_dict['mileage'] = None

    try: d_dict['Комплектация'] = d_elem['vehicle_info']['complectation']
    except: d_dict['Комплектация'] = None

    try: d_dict['Привод'] = d_elem['lk_summary'].split(', ')[-2]
    except: d_dict['Привод'] = None

    try: d_dict['Руль'] = d_elem['vehicle_info']['steering_wheel']
    except: d_dict['Руль'] = None

    # 'Состояние' не найдено
    d_dict['Состояние'] = None

    try: d_dict['Владельцы'] = d_elem['documents']['owners_number']
    except: d_dict['Владельцы'] = None

    try: d_dict['ПТС'] = d_elem['documents']['pts']
    except: d_dict['ПТС'] = None

    try: d_dict['Таможня'] = d_elem['documents']['custom_cleared']
    except: d_dict['Таможня'] = None

    try: d_dict['Владение'] =  d_elem['documents']['purchase_date']
    except: d_dict['Владение'] = None


    try: d_dict['price'] = d_elem['price_info']['RUR']
    except: d_dict['price'] = None

    # дата размещения объявления решил добавить 
    try: d_dict['start_date'] =  d_elem['additional_info']['hot_info']['start_time']
    except: d_dict['start_date'] = None

    # статус объявления 
    try: d_dict['hidden'] =  d_elemelem['additional_info']['hidden']
    except: d_dict['hidden'] = None

    # модель 
    try:
        d_dict['model'] =  d_elem['model_info']['name']
    except: d_dict['model'] = None
    #d_dict['model'] =  model

# %%
url = "https://auto.ru/-/ajax/desktop/listing/"
HEADERS = {
    'Connection': 'keep-alive',
    'Content-Length': '876',
    'content-type': 'application/json',
    'Cookie': '_csrf_token=1c0ed592ec162073ac34d79ce511f0e50d195f763abd8c24; autoru_sid=a%3Ag5e3b198b299o5jhpv6nlk0ro4daqbpf.fa3630dbc880ea80147c661111fb3270%7C1580931467355.604800.8HnYnADZ6dSuzP1gctE0Fw.cd59AHgDSjoJxSYHCHfDUoj-f2orbR5pKj6U0ddu1G4; autoruuid=g5e3b198b299o5jhpv6nlk0ro4daqbpf.fa3630dbc880ea80147c661111fb3270; suid=48a075680eac323f3f9ad5304157467a.bc50c5bde34519f174ccdba0bd791787; from_lifetime=1580933172327; from=yandex; X-Vertis-DC=myt; crookie=bp+bI7U7P7sm6q0mpUwAgWZrbzx3jePMKp8OPHqMwu9FdPseXCTs3bUqyAjp1fRRTDJ9Z5RZEdQLKToDLIpc7dWxb90=; cmtchd=MTU4MDkzMTQ3MjU0NQ==; yandexuid=1758388111580931457; bltsr=1; ',
    'origin': 'https://auto.ru/cars/all/',
    'Referer': 'https://auto.ru/cars/all/',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:72.0) Gecko/20100101 Firefox/72.0',
    'x-csrf-token': '1c0ed592ec162073ac34d79ce511f0e50d195f763abd8c24',
}
param = {
                'catalog_filter' : [{"mark": 'AUDI'}],
                'section': "all",
                'category': "cars",
                'sort': "fresh_relevance_1-desc",
                "top_days":"900",
                "geo_radius":200,
                "geo_id":[213],
                'page': 1
            }
response = requests.post(url, json=param, headers = HEADERS)
data = response.json()

# %%
print(data['offers']['vehicle_info'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-53-a72d0e0baf24> in <module>
# ----> 1 print(data['offers']['vehicle_info'])
#
# TypeError: list indices must be integers or slices, not str

# %%
for elem in data['offers']:
    print(elem['vehicle_info']['mark_info']['code'])
# Out:
# AUDI
# AUDI
# AUDI
# AUDI
# AUDI
# AUDI
# AUDI
# AUDI
# AUDI
# AUDI
# AUDI
# AUDI
# AUDI
# AUDI
# AUDI
# AUDI
# AUDI
# AUDI
# AUDI
# AUDI
# AUDI
# AUDI
# AUDI
# AUDI
# AUDI
# AUDI
# AUDI
# AUDI
# AUDI
# AUDI
# AUDI
# AUDI
# AUDI
# AUDI
# AUDI
# AUDI
# AUDI
# AUDI

# %%
dict_columns = {'bodyType':0, 'brand':0, 'color':0, 'fuelType':0, 'modelDate':0, 
                'name':0, 'numberOfDoors':0, 'productionDate':0, 
                'vehicleConfiguration':0, 'vehicleTransmission':0, 
                'engineDisplacement':0, 'enginePower':0, 'description':0, 
                'mileage':0, 'Комплектация':0, 'Привод':0, 'Руль':0, 
                'Состояние':0, 'Владельцы':0, 'ПТС':0, 'Таможня':0, 
                'Владение':0,'price':0, }
for elem in data['offers']:
    print(elem)
    try:dict_columns['ПТС'] =  elem['documents']['pts']
    except: dict_columns['ПТС'] = None
# Out:
# {'availability': 'IN_STOCK', 'category': 'cars', 'color_hex': 'CACECB', 'delivery_info': {}, 'description': 'Эксклюзивные условия в Ауди Центре Север.\nТолько в этом месяце мы готовы сделать Вам лучшее предложение на новый Audi.\nНе упустите свой шанс. Даже если у Вас есть предложение, которое кажется оптимальным, позвоните нам, и мы постараемся его улучшить.\nНет ничего невозможного вместе с Ауди Центром Север.\n\nАуди Центр Север - официальный дилер Audi, являющийся одним из крупнейших дилеров в Европе.\nУ нас собрана команда ответственных профессионалов, которые любят автомобили Audi и знают о них все до мельчайших деталей.\nС момента своего открытия в 2001 году Ауди Центр Север не раз занимал лидерские позиции по объемам продаж новых автомобилей Audi и уровню удовлетворенности клиентов сервисным обслуживанием.\nМы постоянно стремимся стать лучше, и наш двигатель – это благодарность клиента!\n\nЕсли Audi, то в Ауди Центре Север.\n\n*В объявлении указаны актуальные цены с учетом акций на покупку новых автомобилей Audi в декабре.\n\n\nПредложение обновлено 04 декабря 2020г. в 19 ч 23 мин.\n\n\n———————————————————————————\nКомплектация 45 TFSI quattro S tronic\n———————————————————————————\n———————————————————————————\nПАССИВНАЯ БЕЗОПАСНОСТЬ\n———————————————————————————\nПодушка безопасности водителя\nПодушка безопасности пассажира\nПодушки безопасности занавесочного типа\nПодушки безопасности боковые передние\nАвтоматическое включение аварийной сигнализации при экстренном торможении\nКрепление для детского сиденья ISOFIX\n———————————————————————————\nАКТИВНАЯ БЕЗОПАСНОСТЬ И ПОДВЕСКА\n———————————————————————————\nАнтиблокировочная система тормозов\nСистема распределения тормозных усилий\nПомощь при экстренном торможении\nСистема курсовой устойчивости\nАнтипробуксовочная система\nЭлектронная блокировка дифференциала\nСистема контроля давления в шинах\nРекуперация энергии торможения\n———————————————————————————\nЭКСТЕРЬЕР\n———————————————————————————\nБоковые зеркала с повторителями указателей поворота\n———————————————————————————\nИНТЕРЬЕР\n———————————————————————————\nКожаный руль и ручка КПП\nПередний подлокотник\n———————————————————————————\nПРИБОРЫ ОСВЕЩЕНИЯ\n———————————————————————————\nБи-ксеноновые фары\nСветодиодный дневной свет\nСветодиодные задние фонари\nОмыватели фар\nАвтоматическая коррекция угла наклона фар\n———————————————————————————\nКОМФОРТ\n———————————————————————————\nРегулировка рулевой колонки по углу наклона\nРегулировка рулевой колонки по вылету\nДатчики дождя и света\nФункция Auto Start Stop\nКнопка запуска/остановки двигателя\nДатчики парковки спереди и сзади\nЭлектроприводы передних стекол\nЭлектроприводы задних стекол\nЭлектроприводы боковых зеркал\nЭлектроприводы поясничной опоры передних сидений\nОбогрев боковых зеркал\nОбогрев передних сидений\nКлимат-контроль двухзонный\n———————————————————————————\nАУДИО- И ИНФОРМАЦИОННО-РАЗВЛЕКАТЕЛЬНЫЕ СИСТЕМЫ\n———————————————————————————\nAudi Sound System\nMMI Radio\nМультифункциональное рулевое колесо\nБортовой компьютер\nКоммуникационная система Bluetooth\n———————————————————————————\nОХРАННЫЕ СИСТЕМЫ\n———————————————————————————\nЦентральный замок с ДУ\nИммобилайзер\n———————————————————————————\nЗАПАСНОЕ КОЛЕСО\n———————————————————————————\nмалоразмерное\n———————————————————————————', 'discount_options': {}, 'documents': {'pts_original': True, 'custom_cleared': True, 'year': 2020, 'vin': 'WAU**************', 'pts': 'ORIGINAL'}, 'is_favorite': False, 'old_category_id': 15, 'owner_expenses': {'transport_tax': {'tax_by_year': 20213, 'year': 2020, 'rid': 213, 'rate': 75, 'horse_power': 245, 'holding_period_month': 12, 'boost': 1.1}, 'osago_insurance': [{'insurance_company': 'TINKOFF', 'price': 6309}]}, 'section': 'new', 'seller_type': 'COMMERCIAL', 'services': [{'service': 'all_sale_special', 'is_active': True, 'prolongable': False}, {'service': 'all_sale_premium', 'is_active': True, 'prolongable': False}, {'service': 'all_sale_toplist', 'is_active': True, 'pro ...
# {'availability': 'IN_STOCK', 'category': 'cars', 'color_hex': '97948F', 'delivery_info': {}, 'description': 'Эксклюзивные условия в Ауди Центре Север.\nТолько в этом месяце мы готовы сделать Вам лучшее предложение на новый Audi.\nНе упустите свой шанс. Даже если у Вас есть предложение, которое кажется оптимальным, позвоните нам, и мы постараемся его улучшить.\nНет ничего невозможного вместе с Ауди Центром Север.\n\nАуди Центр Север - официальный дилер Audi, являющийся одним из крупнейших дилеров в Европе.\nУ нас собрана команда ответственных профессионалов, которые любят автомобили Audi и знают о них все до мельчайших деталей.\nС момента своего открытия в 2001 году Ауди Центр Север не раз занимал лидерские позиции по объемам продаж новых автомобилей Audi и уровню удовлетворенности клиентов сервисным обслуживанием.\nМы постоянно стремимся стать лучше, и наш двигатель – это благодарность клиента!\n\nЕсли Audi, то в Ауди Центре Север.\n\n*В объявлении указаны актуальные цены с учетом акций на покупку новых автомобилей Audi в декабре.\n\n\nПредложение обновлено 04 декабря 2020г. в 19 ч 23 мин.\n\n\n———————————————————————————\nКомплектация 45 TFSI quattro S tronic\n———————————————————————————\n———————————————————————————\nПАССИВНАЯ БЕЗОПАСНОСТЬ\n———————————————————————————\nПодушка безопасности водителя\nПодушка безопасности пассажира\nПодушки безопасности занавесочного типа\nПодушки безопасности боковые передние\nПреднатяжители ремней безопасности\nКрепление для детского сиденья ISOFIX\n———————————————————————————\nАКТИВНАЯ БЕЗОПАСНОСТЬ И ПОДВЕСКА\n———————————————————————————\nАнтиблокировочная система тормозов\nСистема распределения тормозных усилий\nПомощь при экстренном торможении\nСистема курсовой устойчивости\nАнтипробуксовочная система\nЭлектронная блокировка дифференциала\nСистема помощи при спуске с горы\nСистема контроля давления в шинах\nРекуперация энергии торможения\n———————————————————————————\nЭКСТЕРЬЕР\n———————————————————————————\nБоковые зеркала с повторителями указателей поворота\nРейлинги на крыше\n———————————————————————————\nИНТЕРЬЕР\n———————————————————————————\nКожаный руль\n———————————————————————————\nПРИБОРЫ ОСВЕЩЕНИЯ\n———————————————————————————\nБи-ксеноновые фары\nСветодиодный дневной свет\nСветодиодные задние фонари\nОмыватели фар\nАвтоматическая коррекция угла наклона фар\nПротивотуманные фары\n———————————————————————————\nКОМФОРТ\n———————————————————————————\nРегулировка рулевой колонки по углу наклона\nРегулировка рулевой колонки по вылету\nРучная регулировка высоты передних сидений\nФункция Auto Start Stop\nДатчики парковки сзади\nЭлектроприводы передних стекол\nЭлектроприводы задних стекол\nЭлектроприводы боковых зеркал\nЭлектроприводы двери багажника\nОбогрев боковых зеркал\nОбогрев передних сидений\nКлимат-контроль\nАтермальное остекление\n———————————————————————————\nАУДИО- И ИНФОРМАЦИОННО-РАЗВЛЕКАТЕЛЬНЫЕ СИСТЕМЫ\n———————————————————————————\nМагнитола Concert\nAudi Sound System\nБортовой компьютер\n———————————————————————————\nОХРАННЫЕ СИСТЕМЫ\n———————————————————————————\nЦентральный замок с ДУ\nИммобилайзер\n———————————————————————————\nЗАПАСНОЕ КОЛЕСО\n———————————————————————————\nмалоразмерное\n———————————————————————————', 'discount_options': {}, 'documents': {'pts_original': True, 'custom_cleared': True, 'year': 2020, 'vin': 'WAU**************', 'pts': 'ORIGINAL'}, 'is_favorite': False, 'old_category_id': 15, 'owner_expenses': {'transport_tax': {'tax_by_year': 20543, 'year': 2020, 'rid': 213, 'rate': 75, 'horse_power': 249, 'holding_period_month': 12, 'boost': 1.1}, 'osago_insurance': [{'insurance_company': 'TINKOFF', 'price': 6309}]}, 'section': 'new', 'seller_type': 'COMMERCIAL', 'services': [{'service': 'all_sale_special', 'is_active': True, 'prolongable': False}, {'service': 'all_sale_premium', 'is_active': True, 'prolongable': False}, {'service': 'all_sale_toplist', 'is_active': True, 'prolongable': False}, {'service': 'all_sale_premium', 'is_active': True, 'prolongable': False}], ...
# {'availability': 'IN_STOCK', 'badges': ['Bang&amp;olufsen', 'Nihgt vision', 'Управ-мая задняя подвеска'], 'category': 'cars', 'color_hex': '97948F', 'delivery_info': {}, 'description': 'Дата выдачи ПТС январь 2020г.\nПродажа март 2020г.!!!\n\nВ автомобиле есть абсолютно все !!!\n\nНОЧНОЕ ВИДЕНЬЕ !!!\n\nЗАДНИЕ ПОДРУЛИВАЮЩИЕ КОЛЕСА !!!\n\nПРОЕКЦИЯ !!!\n\nПАНОРАМНАЯ КРЫША !!!\n\nBANG & OLUFSEN С ВЫДВИЖНЫМИ КОЛОНКАМИ !!!\n\nАДАПТИВНЫЙ КРУИЗ КОНТРОЛЬ !!!\n\nИ МНОГОЕ ДРУГОЕ !!!\nВ ОБЩЕМ, СОБРАН ВЕСЬ КОНФИГУРАТОР !!!\nСТОИМОСТЬ НОВОГО ТАКОГО АВТОМОБИЛЯ 8 100 000 РУБЛЕЙ !!!\n\n!!! Подтвержденный оригинальный пробег !!!\n\nАвтомобиль в отличном состоянии !!!\n\nНет ни одного битого/крашеного элементы !!!\n\nЛюбые проверки приветствуются (официальный дилер, профессиональный подбор автомобилей).\n\nВозможен торг при осмотре автомобиля, продажа автомобиля в кредит, обмен.\n\nАвтомобиль всегда можно посмотреть сухим и чистым в любую погоду, а также в любое время.\n\nАвтомобиль на гарантии!!!\nАвтомобилю 8 месяцев !!!\nДата выдачи ПТС январь 2020г.\nПродажа март 2020г.!!!\n\nКомплектация:\n\n- Серый перламутр Daytona Gray\n\n- Пакет Infotainment\n\n- Пакет Sport selection\n\n- Светодиодные фары HD Matrix LED c Audi Laser Light\n\n- Пакет ассистирующих систем «Путешествие»\n\n- Пакет ассистирующих систем «Город»\n\n- Светодиодные фары HD Matrix LED c Audi laser light\n\n- Bang & Olufsen Advanced Sound System c 3D-звучанием\n\n- Система ночного видения с функцией распознавания пешеходов\n\n- Управляемая задняя подвеска\n\n- Передние сидения с системой вентиляции и функцией массажа\n\n- Черный стайлинг-пакет внешней отделки\n\n- Пакет отделки кожей верхней и нижней частей салона\n\n- Панорамная крыша\n\n- Звукоизолирующие боковые стекла\n\n- MMI Navigation plus с MMI touch response\n\n- Парковочный ассистент plus с функцией автоматической парковки и камерой 360°\n\n- Проекционный дисплей\n\n- Легкосплавные диски Audi Sport, дизайн «10 спиц Star», черные, с полированной обводкой, размер 9,5J x 21, с шинами 285/40 R21\n\n- Пакет контурного освещения салона\n\n- Кнопки управления со стеклянным покрытием черного цвета, с тактильной обратной связью, с расширенной отделкой aluminium\n\n- Audi virtual cockpit plus\n\n- Автодоводчик дверей\n\n- Обогрев передних и задних сидений\n\n- Климат-контроль с индивидуальной настройкой для четырех зон салона\n\n- Обивка сидений кожей Valcona с ромбовидной строчкой и оттиском S на спинках передних сидений\n- Спортивные передние сиденья S plus\n\n- Заднее сиденье с возможностью продольной регулировки\n\n- Декоративные вставки «дуб», серые\n\n- Проекция колец Audi для боковых дверей\n\n- Ассистент сохранения полосы движения с ассистентом аварийной остановки\n\n- Топливный бак увеличенного объема (85 л)', 'discount_options': {}, 'documents': {'owners_number': 1, 'pts_original': True, 'custom_cleared': True, 'year': 2019, 'vin': 'WAU**************', 'warranty': True, 'warranty_expire': {'year': 2024, 'month': 6, 'day': 1}, 'pts': 'ORIGINAL', 'license_plate': '******|799', 'vin_resolution': 'OK'}, 'is_favorite': False, 'old_category_id': 15, 'owner_expenses': {'transport_tax': {'tax_by_year': 18675, 'year': 2020, 'rid': 213, 'rate': 75, 'horse_power': 249, 'holding_period_month': 12, 'boost': 1}, 'osago_insurance': [{'insurance_company': 'TINKOFF', 'price': 6309}]}, 'section': 'used', 'seller_type': 'PRIVATE', 'services': [{'service': 'all_sale_special', 'is_active': True, 'prolongable': False}, {'service': 'all_sale_color', 'is_active': True, 'prolongable': False}, {'service': 'all_sale_toplist', 'is_active': True, 'prolongable': False}, {'service': 'all_sale_fresh', 'create_date': '1607065574006', 'is_active': True, 'prolongable': False}], 'status': 'ACTIVE', 'tags': ['big', 'oversize', 'prestige', 'online_view_available', 'badge', 'autoru_exclusive', 'wide-back-seats', 'big-trunk', 'all-terrain', 'vin_offers_history', 'options', 'available_for_checkup', 'handling', 'vin_resolution_ok', 'vin_checked', 'no_accidents ...
# {'availability': 'IN_STOCK', 'brand_cert_info': {'program_alias': 'AudiPlus', 'cert_status': 'BRAND_CERT_ACTIVE', 'created': '1605711170133', 'view': {'name': 'Audi с пробегом :plus', 'advantages_html': ['Автомобили Audi не&nbsp;старше 5&nbsp;лет с&nbsp;пробегом не&nbsp;более 120&nbsp;000&nbsp;км', 'Прозрачная юридическая и&nbsp;сервисная история', 'Подготовка к&nbsp;эксплуатации по&nbsp;110&nbsp;пунктам', 'Гарантия или послегарантийная поддержка&nbsp;– не&nbsp;менее 12&nbsp;месяцев без ограничения пробега', 'Обязательное предложение по&nbsp;трейд&#8209;ин'], 'description_html': 'В рамках программы Audi&nbsp;с&nbsp;пробегом&nbsp;:plus у&nbsp;вас есть возможность выбрать практически любой автомобиль из модельного ряда Audi, возраст которого не старше 5&nbsp;лет, а пробег не более 120&nbsp;000&nbsp;км. Каждый автомобиль проходит тщательную диагностику и подготовку и находится в отличном состоянии.<br><br>На все автомобили Audi&nbsp;с&nbsp;пробегом&nbsp;:plus предоставляется гарантия или постгарантийная поддержка минимум на&nbsp;12&nbsp;месяцев с даты приобретения автомобиля у официального дилера Audi в России.', 'logo': [{'sizes': {'full': '//yastatic.net/s3/vertis-frontend/autoru-frontend/manufacturer-cert-logo/AudiPlus/logo.png'}}], 'description_url': 'https://www.audi.ru/ru/web/ru/clients/used-cars/audi-plus.html?csref=sea:PhD:y_2019_audi_used_plus_brand_search:Audi_Context_Used_Plus_2019/?utm_source=manuf_cert'}}, 'category': 'cars', 'color_hex': '007F00', 'delivery_info': {}, 'description': 'ОДИН ВЛАДЕЛЕЦ!!!.... ПТС ОРИГИНАЛ!!!!.... ПОЛНЫЙ КОМПЛЕКТ КЛЮЧЕЙ!!!..... АВТОМОБИЛЬ НАХОДИТСЯ НА ЗАВОДСКОЙ ГАРАНТИИ ДО ОКТЯБРЯ 2021г.!!!!..... БОГАТЕЙШАЯ КОМПЛЕКТАЦИЯ!!!!..... МЯГКАЯ КОЖА!!!.... ЛЮК!!!..... КАМЕРА ЗАДНЕГО ВИДА!!!!.... 19 ОРИГИНАЛЬНЫЕ ЛЕГКОСПЛАВНЫЕ ДИСКИ!!!!.... ТОПОВАЯ АУДИО СИСТЕМА BANG of OLUFSEN!!!......\nДилерские центры АВТОDOM Алтуфьево (Ауди Центр Алтуфьево, VOLVO CAR АЛТУФЬЕВО и Jaguar Land Rover АВТОДОМ) удобно расположены на Севере Москвы, на 85-км МКАД.\nГруппа Компаний AВTODOM - автомобильный холдинг, специализирующийся на продажах и техническом обслуживании автомобилей премиум-сегмента с 1992 года. Мы - одна из первых в России компаний, которая предложила клиентам услуги по выкупу автомобиля и принятия автомобиля в зачет стоимости нового.\n\nПрофильные автомобили с пробегом в наших центрах продаются по программе сертифицированных автомобилей, таких как «Audi с пробегом: plus», Volvo Select и Jaguar Land Rover Approved\nНа каждый сертифицированный по программе производителя автомобиль с пробегом предоставляется гарантия изготовителя или пост гарантийная поддержка минимум на 12 месяцев.\nНам важно, чтобы при покупке автомобиля Вы чувствовали себя максимально защищенными!\n\nПродайте или обменяйте свой автомобиль на новый Audi, Volvo, Jaguar или Land Rover с доплатой на персональных условиях.\n\nМы обеспечиваем высокое качество обслуживания клиентов и делаем Вашу жизнь удобнее, позитивнее и ярче.\nНаши двери ежедневно открыты для Вас с 9:00 до 21:00, без перерыва и выходных.\n\nДо встречи в АВТОDOM Алтуфьево!\n\nГарантия производителя на данный автомобиль действует по октябрь 2021 года.\n\nКомплектация «Design 45 TFSI quattro S tronic»:\n• Антиблокировочная система\n• Антипробуксовочная система\n• Система курсовой устойчивости\n• Система помощи при экстренном торможении\n• Подушки безопасности водителя\n• Подушки безопасности пассажира\n• Боковые передние подушки безопасности\n• Оконные шторки безопасности\n• Ламинированные боковые стекла\n• Блокировка замков задних дверей\n• Система крепления детских автокресел\n• Иммобилайзер\n• Центральный замок\n• Бортовой компьютер\n• Круиз-контроль\n• Парктроник передний и задний\n• Камера заднего вида\n• Система помощи при старте в гору\n• Усилитель руля\n• Запуск двигателя с кнопки\n• Система “старт-стоп”\n• Электрорегулировка сиденья пассажира\n• Электростеклоподъемники передние и задние\n• Электропривод зеркал\n• Электропривод крышки багажника\n• Климат-контроль мног ...
# {'availability': 'IN_STOCK', 'category': 'cars', 'color_hex': '040001', 'delivery_info': {}, 'description': '• Автомобиль проверен по 110 пунктам\n• Автокредит по специальной ставке от 13,7%\n\nАуди Центр Север, официальный дилер Audi, входящий в группу компаний РОЛЬФ и являющийся одним из крупнейших дилеров в Европе, предлагает Вам ряд услуг по покупке и продаже автомобилей с пробегом.\n\nНа протяжении многих лет наш дилерский центр является лидером по продаже автомобилей с пробегом среди всех дилеров Audi в России и предоставляет клиентам самый большой выбор автомобилей с пробегом Audi и других марок.\nКаждый автомобиль проходит тщательную диагностику и подготовку, и гарантировано находится в отличном состоянии.\nЧтобы убедиться в правильном выборе, у Вас есть возможность пройти тест-драйв ― ознакомительную поездку на интересующем автомобиле.\nВы сможете ознакомиться с автомобилем не выходя из дома – наш менеджер проведет online презентацию и в видеозвонке покажет выбранный автомобиль.\nТакже Ауди Центр Север представляет уникальное предложение по кредитованию автомобилей с пробегом на индивидуальных условиях. Специалисты компании  подберут для Вас лучшие условия кредитования.', 'discount_options': {}, 'documents': {'owners_number': 2, 'pts_original': True, 'custom_cleared': True, 'year': 2016, 'vin': 'WUA**************', 'pts': 'ORIGINAL', 'vin_resolution': 'OK'}, 'is_favorite': False, 'old_category_id': 15, 'owner_expenses': {'transport_tax': {'tax_by_year': 181500, 'year': 2020, 'rid': 213, 'rate': 150, 'horse_power': 605, 'holding_period_month': 12, 'boost': 2}, 'osago_insurance': [{'insurance_company': 'TINKOFF', 'price': 6309}]}, 'section': 'used', 'seller_type': 'COMMERCIAL', 'status': 'ACTIVE', 'tags': ['big', 'oversize', 'prestige', 'online_view_available', 'fast', 'wide-back-seats', 'big-trunk', 'vin_offers_history', 'options', 'style', 'handling', 'vin_resolution_ok', 'vin_checked', 'sport', 'no_accidents', 'low_mileage', 'dealer_quarantine_calls', 'pts_original', 'redemption'], 'multiposting': {'classifieds': []}, 'additional_info': {'hidden': False, 'is_on_moderation': False, 'exchange': True, 'update_date': '1607109827000', 'creation_date': '1607045342000', 'mobile_autoservices_url': 'https://m.auto.ru/autoservice/all_works/AUDI/?geo_id=213', 'hot_info': {'is_hot': False, 'start_time': '2020-12-04T03:35:02Z', 'end_time': '2020-12-04T03:35:02Z'}, 'redemption_available': True, 'fresh_date': '1607045342000', 'counters_start_date': '1607045342000', 'chat_only': False, 'dealer_card_promo': 'SLEEP_PROMO', 'review_summary': {}, 'price_stats': {}, 'booking': {}, 'days_in_stock': 1, 'days_on_sale': 1}, 'counters': {}, 'grouping_info': None, 'hash': '92b97b95', 'id': '1101787478', 'price_info': {'price': 5999000, 'currency': 'RUR', 'EUR': 66462, 'RUR': 5999000, 'USD': 80791, 'with_nds': False}, 'price_history': [{'EUR': 66462, 'RUR': 5999000, 'USD': 80791, 'create_timestamp': 1607052902000}], 'recall_info': {}, 'saleId': '1101787478-92b97b95', 'salon': {'actual_stock': True, 'client_id': '352', 'code': 'audi_centr_sever_moskva', 'dealer_id': '20135027', 'logo_url': '//avatars.mds.yandex.net/get-verba/997355/2a00000168a415bed342b593ec84ed52f670/dealer_logo', 'loyalty_program': True, 'offer_counters': {'cars_all': 301}, 'name': 'Ауди Центр Север', 'phones': [{'phone': '+7 495 153-54-88'}, {'phone': '+7 499 707-53-64'}], 'place': {'address': 'Ленинградское шоссе, 63Б', 'coord': {'latitude': 55.863899, 'longitude': 37.463341}, 'geobase_id': '213', 'region_info': {'id': '213', 'name': 'Москва', 'genitive': 'Москвы', 'dative': 'Москве', 'accusative': 'Москву', 'prepositional': 'Москве', 'preposition': 'в', 'latitude': 55.753215, 'longitude': 37.622504, 'parent_ids': ['213', '1', '3', '225', '10001', '10000']}, 'metro': [{'rid': '215102', 'name': 'Беломорская', 'distance': 787.8094748561886, 'location': {'latitude': 55.865369, 'longitude': 37.475692}, 'lines': [{'name': 'Замоскворецкая линия', 'color': '#4f8242'}]}, {'rid': '20 ...
# {'availability': 'IN_STOCK', 'badges': ['Зимние колеса в подарок', 'Максимальные привилегии', 'Звоните'], 'category': 'cars', 'color_hex': 'FAFBFB', 'delivery_info': {}, 'description': 'Только до 31 декабря колёса в сборе или каско в подарок при покупке Audi в Ауди Центре Восток, в том числе в формате онлайн.\nУвеличенный бонус по программе Audi Family для владельцев Audi до 7 лет.\n\n*Подробности предложения уточняйте у сотрудников отдела продаж.\n\nПо-настоящему интересные условия для самых искушенных клиентов в Ауди Центре Восток.\n\nПервый дилерский центр, построенный по уникальной концепции «Терминал», в центральном регионе России, общей площадью 4700 кв.м.\nВ доступности ежедневно более 200 автомобилей в наличии в различных конфигурациях. \nНаши менеджеры с удовольствием помогут выбрать «тот самый» автомобиль и сформируют под ваш запрос конкурентное коммерческое предложение.\n\nДаже если у вас есть предложение, которое кажется вам оптимальным, позвоните нам, и мы постараемся его улучшить. \n\nПостоянные преимущества:\n \tгарантия качества сроком 4 года¹\n \tпрограмма помощи на дорогах²\n \tдополнительные бонусы в рамках программы трейд-ин;\n \tвыкуп вашего автомобиля до 100% от рыночной стоимости;\n \tспециальные условия страхования и кредитования, в том числе кредит без первоначального взноса³.\n\nПредложения для тех, кто готов получить все. Звоните сейчас, чтобы узнать все подробности.\n\n¹Программа действует для автомобилей, проданных через дилерскую сеть марки Audi на территории Российской Федерации не ранее 01.01.2013 и зарегистрированных на территории Российской Федерации. Программа действует в течение 2 лет с момента приобретения автомобиля. Участие в программе пролонгируется до 5 лет при условии обслуживания в официальном дилерском центре в соответствии с регламентом технического обслуживания, установленным производителем, после истечения гарантийного периода (подтверждение - соответствующие отметки в цифровой сервисной книжке). Подробную информацию уточняйте в Ауди Центре Восток.\n²Первоначальный взнос от 0%. Срок кредита от 2 до 7 лет на сумму до 3 млн. рублей. Ставка по кредиту от 15,5%.Подробности уточняйте у сотрудников отдела финансовых услуг Ауди Центра Восток.\n\n* Указаны максимальные цены перепродажи на модели Audi (распространяются на автомобили 2020 года выпуска) с учетом сдачи прежнего автомобиля в «трейд-ин» с ограничением по дате выпуска, стране производства и марке производителя. Предложение ограничено и действует до 31.12.2020. Подробные условия уточняйте в Ауди Центре Восток.\nНа автомобили марки Audi производителем предоставляется гарантия качества на срок 2 года, а также на дополнительные 2 года или до достижения общего пробега автомобиля 120 000 км (в зависимости от того, какое событие что наступит ранее), при этом в первые 2 года пробег не ограничивается и не учитывается.\n\nКомплектация 45 TDI quattro tiptronic\n\nАдаптивная пневматическая подвеска\nПолная окраска кузова\nтех. код\nЛиния Comfort line/ для ТТ: Линия Sport line\nДопуск ТС к эксплуатации, дополнение\nКомбинированная обивка сидений материалом Аlcantara / кожей\nAlloy wheels 9J x 20\nСпортивный пакет S line\nПакет дополнительного освещения\nЗаводской код\nЧерный стайлинг пакет внешней отделки Audi exclusive\nПередний комфортный  подлокотник\nСветодиодные фары Audi Matrix', 'discount_price': {'price': 5082000, 'status': 'ACTIVE'}, 'discount_options': {'tradein': 150000, 'max_discount': 479900}, 'documents': {'pts_original': True, 'custom_cleared': True, 'year': 2020, 'vin': 'WAU**************', 'pts': 'ORIGINAL'}, 'is_favorite': False, 'old_category_id': 15, 'owner_expenses': {'transport_tax': {'tax_by_year': 18675, 'year': 2020, 'rid': 213, 'rate': 75, 'horse_power': 249, 'holding_period_month': 12, 'boost': 1}, 'osago_insurance': [{'insurance_company': 'TINKOFF', 'price': 6309}]}, 'section': 'new', 'seller_type': 'COMMERCIAL', 'status': 'ACTIVE', 'tags': ['big', 'oversize', 'discount', 'prestige', 'dealer_discount', 'badge', 'w ...
# {'availability': 'IN_STOCK', 'category': 'cars', 'color_hex': '0000CC', 'delivery_info': {}, 'description': 'АВТОМОБИЛЬ В НАЛИЧИИ!!!\nПТС 2016года выпуска (в ПТС)!!!Автомобиль покупался за наличный расчёт в конце 2017 года у официального дилера .ДВА БЕРЕЖНЫХ СОБСТВЕННИКА!!!ДВА КЛЮЧА(фото прилагается)ДИЗЕЛЬ 249л.с.\n\nПОСЛЕДНЕЕ ТО (только оригинальные запчасти)!!!Перечень работ - \n- Масло в двигателе и масляный фильтр \n- Фильтр воздушный \n- Фильтр салонный \n- Свечи зажигания \n- Замена топливного фильтра \n- Тормозная жидкость \n- тормозные диски(передние и задние)\n- Охлаждающая жидкость \n- диагностика полного привода(отклонений не выявлено)\n- тормозные колодки(перед и зад) \n- приводной ремень(с роликами в комплекте) \n- диагностика полного привода(отклонений не выявлено) \n- компьютерная диагностика по 218 пунктам(нареканий не выявлено) \n- производился окрас заднего бампера и заднего правого пластикого расширителя!!!\n\nОЧЕНЬ БОГАТАЯ КОМПЛЕКТАЦИЯ S-LINE!!!\n- оригинальные литые диски R 21 S-line \n- рулевое колесо S-line c подогревом\n- внешний S-line\n- доводчик дверей\n- доводчик крышки багажника\n- электрическая задняя шторка\n- самый дорогой и красивый цвет в линейке\n- спортивные сиденья\n- комбинированный салон кожа+алькантара с перфорацией\n- полный электро пакет \n- подогрев сидений \n- климат контроль \n- круиз контроль\n- черный потолок\n- адаптивная LED оптика \n- диодные задние фонари \n- электропривод багажника\n- передние ходовые огни\n- камера заднего вида с динамической разметкой \n- запуск двигателя с кнопки\n- альтернативная подсветка салона\n- система предотвращения столкновения \n- датчик усталости водителя\n- ремни безопасности с автоматическим фиксатором\n- складывание зеркал\n- 4-х зонный климат-контроль\n- система предотвращения столкновения\n- Autohold\n\n\nПРЕИМУЩЕСТВА КОМПАНИИ ПАМАВТО-ТРЕЙД\n- Оформление КРЕДИТА непосредственно в автосалоне ПАМАВТО-ТРЕЙД\n• БЕЗ первоначального взноса!\n• По ДВУМ документам (паспорт и водительское удостоверение)!\n• Возможность сдать свой автомобиль в качестве первоначального взноса!\n• Более 15 банков сотрудничающих напрямую с ПАМАВТО-ТРЕЙД!\n• услуги подбора автомобиля с учетом пожеланий клиента!\n• полное сопровождение сделки!\n• гарантия юридической чистоты ( сертификат )!\n- обмен по системе TRADE-IN!\n- Фото и видео до и после предпродажной подготовки отправим на WhatsApp или Viber!\n- Осуществим видеоконференцию для подтверждения наличия нужного вам автомобиля!\n- 1 год технической гарантии на ДВИГАТЕЛЬ и КОРОБКУ ПЕРЕДАЧ - без ограничения пробега ( от сервис - партнёра)!\n- тест - драйв автомобиля ( ежедневно с 10 -00 до 21 -00 )!', 'discount_options': {}, 'documents': {'owners_number': 2, 'pts_original': True, 'custom_cleared': True, 'year': 2016, 'vin': 'WAU**************', 'pts': 'ORIGINAL', 'vin_resolution': 'OK'}, 'is_favorite': False, 'old_category_id': 15, 'owner_expenses': {'transport_tax': {'tax_by_year': 18675, 'year': 2020, 'rid': 213, 'rate': 75, 'horse_power': 249, 'holding_period_month': 12, 'boost': 1}, 'osago_insurance': [{'insurance_company': 'TINKOFF', 'price': 6309}]}, 'section': 'used', 'seller_type': 'COMMERCIAL', 'services': [{'service': 'all_sale_special', 'is_active': True, 'prolongable': False}, {'service': 'all_sale_toplist', 'is_active': True, 'prolongable': False}, {'service': 'all_sale_premium', 'is_active': True, 'prolongable': False}], 'status': 'ACTIVE', 'tags': ['good_price', 'big', 'oversize', 'fivestars', 'prestige', 'online_view_available', 'allowed_for_credit', 'fast', 'wide-back-seats', 'big-trunk', 'all-terrain', 'vin_offers_history', 'options', 'handling', 'vin_resolution_ok', 'economical', 'vin_checked', 'high_reviews_mark', 'dealer_quarantine_calls', 'pts_original', 'safe_car'], 'multiposting': {'classifieds': []}, 'additional_info': {'hidden': False, 'is_on_moderation': False, 'update_date': '1607089857000', 'creation_date': '1607087881700', 'mobile_autoservices_url': 'https://m.auto.ru/autoservice/all_works/A ...
# {'availability': 'IN_STOCK', 'category': 'cars', 'color_hex': 'EE1D19', 'delivery_info': {}, 'description': 'Выкупим Ваш автомобиль в день обращения – до 100% от рыночной стоимости!\n\nУникальные условия покупки автомобиля в Inchcape:\n\n· Покупка автомобиля за 1 день\n\n· Каждый автомобиль проходит комплексную диагностику более чем по 140 пунктам\n\n· Пожизненная гарантия юридической чистоты на каждый автомобиль с пробегом\n\n· Специальные условия при обмене своего автомобиля и покупке автомобиля в кредит\n\n___________________________________________________________________________________________\n\n+ Первоначальный взнос от 0%\n+ Процентная ставка от 5,9%\n+ Кредит по двум документам\n+ Одобрение кредита за 1 час и выдача автомобиля день в день\n+ Рассмотрение в 15 банках партнерах\n+ Лучшие тарифы КАСКО, ОСАГО, ГТО\n+ Продление заводской гарантии на автомобиль\n\n\n«Inchcape Certified» - Первый международный официальный гипермаркет автомобилей с пробегом и\nофициальный дилер BMW,Mini, Land Rover, Jaguar, Toyota, Lexus, Mitsubishi, Hyundai, Volvo, Infiniti\n∙ Полная прозрачность сделки и гарантия юридической чистоты автомобиля.\n∙ Возможность приобретения в кредит.\n∙ Возможность обменять на свой авто по программе Trade-In. (с доплатой в любую сторону)\n∙ Помощь в постановке на учет и полное документальное сопровождение сделки.\n\nМы будем рады видеть Вас в нашем центре каждый день с 9 до 21\n\nПреимущество данного автомобиля:\n2 собственника\nСигнализация\n\nОсобые условия на представленный автомобиль для вас при покупке в КРЕДИТ или ОБМЕНЕ\n\nКомплектация «Ambition»:\n• Антиблокировочная система\n• Система курсовой устойчивости\n• Подушки безопасности водителя с защитой коленей\n• Подушки безопасности пассажира\n• Боковые передние подушки безопасности\n• Оконные шторки безопасности\n• Система крепления детских автокресел\n• Иммобилайзер\n• Центральный замок\n• Бортовой компьютер\n• Электро усилитель руля\n• Активный усилитель руля\n• Система “старт-стоп”\n• Регулировка руля\n• Электростеклоподъемники передние и задние\n• Электропривод зеркал\n• Климат-контроль 1-зонный\n• Подогрев сидений водителя и пассажира\n• Обогрев зеркал\n• CD\n• AUX\n• Аудиоподготовка\n• Тканевая обивка салона\n• Темный салон\n• Отделка кожей рычага КПП\n• Кожаный руль\n• Спортивные передние сидения\n• Складывающееся заднее сидение\n• Третий задний подголовник\n• Передний центральный подлокотник\n• Прикуриватель и пепельница\n• Литые легкосплавные диски\n• Размер дисков 17″\n• Защита картера\n• Ксеноновые фары', 'discount_options': {}, 'documents': {'owners_number': 2, 'pts_original': True, 'custom_cleared': True, 'year': 2015, 'vin': 'WAU**************', 'pts': 'ORIGINAL', 'vin_resolution': 'OK'}, 'is_favorite': False, 'old_category_id': 15, 'owner_expenses': {'transport_tax': {'tax_by_year': 3125, 'year': 2020, 'rid': 213, 'rate': 25, 'horse_power': 125, 'holding_period_month': 12, 'boost': 1}, 'osago_insurance': [{'insurance_company': 'TINKOFF', 'price': 5521}]}, 'section': 'used', 'seller_type': 'COMMERCIAL', 'status': 'ACTIVE', 'tags': ['good_price', 'vin_service_history', 'medium', 'fivestars', 'prestige', 'comfort', 'allowed_for_credit', 'vin_offers_history', 'options', 'handling', 'vin_resolution_ok', 'economical', 'vin_checked', 'high_reviews_mark', 'low_mileage', 'dealer_quarantine_calls', 'pts_original', 'redemption'], 'multiposting': {'classifieds': []}, 'additional_info': {'hidden': False, 'is_on_moderation': False, 'exchange': True, 'update_date': '1607105182000', 'creation_date': '1607074040000', 'mobile_autoservices_url': 'https://m.auto.ru/autoservice/all_works/AUDI/?geo_id=213', 'hot_info': {'is_hot': False, 'start_time': '2020-11-10T13:07:11Z', 'end_time': '2020-11-10T13:07:11Z'}, 'redemption_available': True, 'fresh_date': '1607074040000', 'counters_start_date': '1607074040000', 'chat_only': False, 'dealer_card_promo': 'SLEEP_PROMO', 'review_summary': {'avg_rating': 4.800000190734863, 'counter': 11}, 'price_stats': {'last_year_ ...
# {'availability': 'IN_STOCK', 'badges': ['Скидка по trade-in 50000'], 'category': 'cars', 'color_hex': '040001', 'delivery_info': {}, 'description': 'Артикул: 25803\n\nПРИ ПОКУПКЕ АВТОМОБИЛЯ В КРЕДИТ, СПЕЦИАЛЬНАЯ СКИДКА ОТ 40\xa0000 до 60 000 РУБЛЕЙ!  \n\nАвтокредитование:\n— Первоначальный взнос от 0%;\n— Более 20 кредитных программ;\n— Минимальный пакет документов – паспорт и вод. удостоверение;\n— Срок кредита от 6 месяцев до 7 лет;\n— Сумма кредита от 60 000 руб. до 3 000 000 рублей;\n—  Без справок и трудовой книжки.\n— Досрочное погашение без штрафов и комиссий;\n— КАСКО – необязательно.\nСотрудничаем с 15 аккредитованными и сертифицированными банками РФ, среднее время ожидания решения банка 20–30 минут.\n\nПРИГЛАШАЕМ на бесплатный тест-драйв!\n\nПредоставляем ГАРАНТИЮ на двигатель и коробку передач - 1 Год!\nЗимняя резина в ПОДАРОК!\nРаботаем ежедневно , без праздников и выходных : 9:00 - 20:00!\n\n Вся история автомобиля юридически чиста и подтверждена соответствующими документами. В ходе проведенной диагностики дефектов не выявлено. Пробег оригинальный! Лакокрасочное покрытие в норме. Полный комплект ключей! Второй комплект резины на оригинальных литых дисках в подарок! \n\nПредлагаем обмен и выкуп по специальным ценам в Trade In Центре Автолидер Варшавка. Воспользуйтесь уникальной возможностью продать свой автомобиль с максимальной выгодой в 50 000 рублей! Звоните прямо сейчас!\n\nАвтомобиль находится в отличном состоянии. ПТС оригинал! Все ТО строго по регламенту завода производителя! Сервисная книжка со всеми отметками о ТО в наличие и подтверждает пробег! На автомобиле произведена предпродажная подготовка с заменой всех масел и фильтров так же произведена диагностика КПП и ходовой, в результате которой отклонений не выявлено. Лакокрасочное покрытие в норме. Полный комплект ключей! Второй комплект резины на оригинальных литых дисках в подарок! Автомобиль полностью готов к дальнейшей эксплуатации! Сборка Германия!!!', 'discount_options': {'tradein': 30000, 'credit': 30000, 'max_discount': 60000}, 'documents': {'owners_number': 2, 'pts_original': True, 'custom_cleared': True, 'year': 2011, 'vin': 'WAU**************', 'pts': 'ORIGINAL', 'vin_resolution': 'UNKNOWN'}, 'is_favorite': False, 'old_category_id': 15, 'owner_expenses': {'transport_tax': {'tax_by_year': 13715, 'year': 2020, 'rid': 213, 'rate': 65, 'horse_power': 211, 'holding_period_month': 12, 'boost': 1}, 'osago_insurance': [{'insurance_company': 'TINKOFF', 'price': 6309}]}, 'section': 'used', 'seller_type': 'COMMERCIAL', 'status': 'ACTIVE', 'tags': ['oversize', 'vin_resolution_unknown', 'medium', 'fivestars', 'prestige', 'excellent_price', 'badge', 'allowed_for_credit', 'fast', 'wide-back-seats', 'big-trunk', 'all-terrain', 'vin_offers_history', 'options', 'discount_options', 'handling', 'vin_checked', 'no_accidents', 'dealer_quarantine_calls', 'pts_original', 'equitable_price', 'safe_car', 'redemption'], 'multiposting': {'classifieds': []}, 'additional_info': {'hidden': False, 'is_on_moderation': False, 'exchange': True, 'update_date': '1607114909000', 'creation_date': '1607099837000', 'mobile_autoservices_url': 'https://m.auto.ru/autoservice/all_works/AUDI/?geo_id=213', 'hot_info': {'is_hot': False, 'start_time': '2020-09-25T15:09:32Z', 'end_time': '2020-09-25T15:09:32Z'}, 'redemption_available': True, 'fresh_date': '1607099837000', 'counters_start_date': '1607099837000', 'chat_only': False, 'dealer_card_promo': 'SLEEP_PROMO', 'review_summary': {'avg_rating': 4, 'counter': 31}, 'price_stats': {'last_year_price_percentage_diff': -12}, 'booking': {'allowed': True}, 'days_in_stock': 71, 'days_on_sale': 71}, 'counters': {}, 'grouping_info': None, 'hash': '070b1310', 'id': '1101015857', 'price_info': {'price': 905000, 'currency': 'RUR', 'EUR': 10026, 'RUR': 905000, 'USD': 12188, 'with_nds': False}, 'price_history': [{'EUR': 10026, 'RUR': 905000, 'USD': 12188, 'create_timestamp': 1607099955000}], 'recall_info': {}, 'saleId': '1101015857-070b1310', 'salon': {'act ...
# {'availability': 'IN_STOCK', 'badges': ['Каско в подарок', 'Максимальные привилегии', 'Звоните'], 'category': 'cars', 'color_hex': '040001', 'delivery_info': {}, 'description': 'Только в декабре Ауди Центр Варшавка дарит зимние колёса в сборе или каско в подарок при покупке Audi!\n\nАуди Центр Варшавка предлагает широкий выбор автомобилей в наличии. \n\nВ нашем дилерском центре для Вас доступны следующие привилегии:\n\n•\tвыкуп Вашего автомобиля в день обращения;\n•\tспециальная кредитная ставка;\n•\tдополнительное преимущество по программе трейд-ин;\n•\tспециальные предложения на сервисное обслуживание.*\n\nСвяжитесь с нами сегодня, получите специальное предложение и забронируйте Ваш новый Audi.\n*Все подробности в отделе продаж Ауди Центр Варшавка.\n---------------------------------------------------------------------------------------\nАуди Центр Варшавка - официальный дилер Audi.\n\n** Указаны максимальные цены перепродажи на модели Audi (распространяются на автомобили 2020 года выпуска) с учетом сдачи прежнего автомобиля в «трейд-ин» с ограничением по дате выпуска, стране производства и марке производителя. Предложение ограничено и действует до 31.12.2020. Подробные условия уточняйте в Ауди Центре Варшавка.\nНа автомобили марки Audi производителем предоставляется гарантия качества на срок 2 года, а также на дополнительные 2 года или до достижения общего пробега автомобиля 120 000 км (в зависимости от того, какое событие что наступит ранее), при этом в первые 2 года пробег не ограничивается и не учитывается.\n\n\nКомплектация 45 TDI quattro tiptronic\n\n\nПредложение обновлено 05 декабря 2020г. в 00 ч 19 мин.', 'discount_options': {}, 'documents': {'pts_original': True, 'custom_cleared': True, 'year': 2020, 'vin': 'WAU**************', 'pts': 'ORIGINAL'}, 'is_favorite': False, 'old_category_id': 15, 'owner_expenses': {'transport_tax': {'tax_by_year': 18675, 'year': 2020, 'rid': 213, 'rate': 75, 'horse_power': 249, 'holding_period_month': 12, 'boost': 1}, 'osago_insurance': [{'insurance_company': 'TINKOFF', 'price': 6309}]}, 'section': 'new', 'seller_type': 'COMMERCIAL', 'status': 'ACTIVE', 'tags': ['big', 'badge', 'oversize', 'wide-back-seats', 'big-trunk', 'all-terrain', 'options', 'handling', 'prestige', 'dealer_quarantine_calls', 'redemption', 'match_applications', 'new_car_old_price', 'priority_placement'], 'multiposting': {'classifieds': []}, 'additional_info': {'hidden': False, 'is_on_moderation': False, 'update_date': '1607117991000', 'creation_date': '1607090447000', 'mobile_autoservices_url': 'https://m.auto.ru/autoservice/all_works/AUDI/?geo_id=213', 'hot_info': {'is_hot': False, 'start_time': '2020-11-16T13:54:51Z', 'end_time': '2020-11-16T13:54:51Z'}, 'redemption_available': True, 'fresh_date': '1607090447000', 'counters_start_date': '1607090447000', 'chat_only': False, 'dealer_card_promo': 'SLEEP_PROMO', 'review_summary': {}, 'price_stats': {'last_year_price_percentage_diff': -13}, 'booking': {}, 'match_application_form': {'contexts': ['listing', 'group_card', 'gallery', 'footer']}, 'days_in_stock': 19, 'days_on_sale': 19}, 'counters': {}, 'grouping_info': None, 'hash': '416fb989', 'id': '1101604153', 'price_info': {'price': 5250000, 'currency': 'RUR', 'EUR': 58164, 'RUR': 5250000, 'USD': 70704, 'with_nds': False}, 'price_history': [{'EUR': 58164, 'RUR': 5250000, 'USD': 70704, 'create_timestamp': 1607090557000}], 'recall_info': {}, 'saleId': '1101604153-416fb989', 'salon': {'actual_stock': True, 'client_id': '22287', 'code': 'audi_centr_varshavka_moskva', 'dealer_id': '20143720', 'logo_url': '//avatars.mds.yandex.net/get-verba/1540742/2a0000016870db80568c6816d42253150da5/dealer_logo', 'loyalty_program': True, 'offer_counters': {'cars_all': 156}, 'name': 'Ауди Центр Варшавка', 'phones': [{'phone': '+7 495 181-17-12'}, {'phone': '+7 499 641-38-87'}], 'place': {'address': 'Варшавское шоссе, 91а', 'coord': {'latitude': 55.650089, 'longitude': 37.621163}, 'geobase_id': '213', 'region_info': {'id': '213', 'name': 'Мо ...
# {'availability': 'IN_STOCK', 'badges': ['Еще выгоднее в кредит'], 'category': 'cars', 'color_hex': '040001', 'delivery_info': {}, 'discount_options': {}, 'documents': {'owners_number': 2, 'pts_original': True, 'custom_cleared': True, 'year': 2018, 'vin': 'WAU**************', 'warranty': True, 'warranty_expire': {'year': 2022, 'month': 3, 'day': 1}, 'pts': 'ORIGINAL', 'vin_resolution': 'OK'}, 'is_favorite': False, 'old_category_id': 15, 'owner_expenses': {'transport_tax': {'tax_by_year': 51000, 'year': 2020, 'rid': 213, 'rate': 150, 'horse_power': 340, 'holding_period_month': 12, 'boost': 1}, 'osago_insurance': [{'insurance_company': 'TINKOFF', 'price': 6309}]}, 'section': 'used', 'seller_type': 'COMMERCIAL', 'status': 'ACTIVE', 'tags': ['big', 'vin_service_history', 'prestige', 'badge', 'fast', 'wide-back-seats', 'big-trunk', 'vin_offers_history', 'options', 'handling', 'vin_resolution_ok', 'vin_checked', 'warranty', 'low_mileage', 'dealer_quarantine_calls', 'pts_original', 'redemption'], 'multiposting': {'classifieds': []}, 'additional_info': {'hidden': False, 'is_on_moderation': False, 'exchange': True, 'update_date': '1607108519000', 'creation_date': '1607097766000', 'mobile_autoservices_url': 'https://m.auto.ru/autoservice/all_works/AUDI/?geo_id=213', 'hot_info': {'is_hot': False, 'start_time': '2020-10-12T18:40:10Z', 'end_time': '2020-10-12T18:40:10Z'}, 'redemption_available': True, 'fresh_date': '1607097766000', 'counters_start_date': '1607097766000', 'chat_only': False, 'dealer_card_promo': 'SLEEP_PROMO', 'review_summary': {}, 'price_stats': {'last_year_price_percentage_diff': -18}, 'booking': {}, 'days_in_stock': 54, 'days_on_sale': 54}, 'counters': {}, 'grouping_info': None, 'hash': '9975e666', 'id': '1101231204', 'price_info': {'price': 5698000, 'currency': 'RUR', 'EUR': 63127, 'RUR': 5698000, 'USD': 76738, 'with_nds': False}, 'price_history': [{'EUR': 63127, 'RUR': 5698000, 'USD': 76738, 'create_timestamp': 1607098261000}], 'recall_info': {}, 'saleId': '1101231204-9975e666', 'salon': {'actual_stock': True, 'client_id': '2672', 'code': 'zvezda_stolici_varshavka_moskva_mercedes', 'dealer_id': '20134447', 'logo_url': '//avatars.mds.yandex.net/get-verba/787013/2a000001696c5a23c5d98d37da6540028795/dealer_logo', 'loyalty_program': True, 'offer_counters': {'cars_all': 1147, 'trucks_all': 9}, 'name': 'Звезда Столицы Mercedes-Benz Варшавка', 'phones': [{'phone': '+7 499 641-33-73'}, {'phone': '+7 495 974-22-23'}], 'place': {'address': 'Варшавское шоссе, дом 127', 'coord': {'latitude': 55.621206, 'longitude': 37.616396}, 'geobase_id': '213', 'region_info': {'id': '213', 'name': 'Москва', 'genitive': 'Москвы', 'dative': 'Москве', 'accusative': 'Москву', 'prepositional': 'Москве', 'preposition': 'в', 'latitude': 55.753215, 'longitude': 37.622504, 'parent_ids': ['213', '1', '3', '225', '10001', '10000']}, 'metro': [{'rid': '20429', 'name': 'Южная', 'distance': 481.26151639545867, 'location': {'latitude': 55.622436, 'longitude': 37.609047}, 'lines': [{'name': 'Серпуховско-Тимирязевская линия', 'color': '#909090'}]}, {'rid': '20430', 'name': 'Пражская', 'distance': 1211.2871820664486, 'location': {'latitude': 55.612614, 'longitude': 37.604538}, 'lines': [{'name': 'Серпуховско-Тимирязевская линия', 'color': '#909090'}]}]}, 'registration_date': '2013-05-11T20:00:00Z', 'salon_id': '2638', 'is_official': True}, 'seller': {'location': {'address': 'Варшавское шоссе, дом 127', 'coord': {'latitude': 55.621204, 'longitude': 37.616398}, 'geobase_id': '213', 'region_info': {'id': '213', 'name': 'Москва', 'genitive': 'Москвы', 'dative': 'Москве', 'accusative': 'Москву', 'prepositional': 'Москве', 'preposition': 'в', 'latitude': 55.753215, 'longitude': 37.622504, 'parent_ids': ['213', '1', '3', '225', '10001', '10000']}, 'metro': [{'rid': '20429', 'name': 'Южная', 'distance': 481.26151639545867, 'location': {'latitude': 55.622436, 'longitude': 37.609047}, 'lines': [{'name': 'Серпуховско-Тимирязевская линия', 'color': '#909090'}]}, {'rid': '204 ...
# ...
# {'availability': 'IN_STOCK', 'category': 'cars', 'color_hex': '040001', 'delivery_info': {}, 'description': 'Месяц рекордных продаж Audi Q5\nДарим ТО при покупке, а также:\n- Зимняя резина + сезонное хранение шин\n- Охранный комплекс\n\n\nБезупречные условия в Ауди Центре Алтуфьево!\nПокупайте в Ауди Центр Алтуфьево - в самом крупном дилерском центре Европы!\nИндивидуальные условия покупки новых автомобилей Audi:\n\n- Кредит без первоначального взноса на Audi A3\n- Широкий выбор автомобилей в наличии с максимальным преимуществом от нового дилера\n- Бронируйте сейчас – платите потом\n- Гибкие условия обмена вашего автомобиля по программе трейд-ин с бонусом до 340 000 рублей\n- Уникальные кредитные программы от ООО «Фольксваген Банк РУС» от 0,7% с комфортными ежемесячными платежами\n- Дополнительные привилегии при покупке автомобиля в лизинг и доступ к закрытому корпоративному парку\n- 4 года гарантии на весь модельный ряд Audi\n- Индивидуальные подарки к каждому автомобилю\n- 5 этажей шоу-рума\n\nУ Вас есть предложение, которое кажется вам оптимальным? Позвоните нам, и мы подберем для Вас лучшие условия!\n*Цены на автомобили указаны с учетом скидок, подробности акций уточняйте у менеджеров.\n**Основные условия кредитования ПАО «Совкомбанк» (далее Банк) на покупку нового Audi A3 по продукту «Кредит на приобретение нового автомобиля» валюта кредита – рубли РФ; сумма кредита минимальная  800 тысяч руб до 4 900 000 млн руб. При первоначальном взносе 0%. Срок кредита от 6 мес до 84 мес.\nПроцентная ставка (в % годовых от 12,49% (два документа) и оформлении договора личного страхования, заключаемого в отношении заемщика. \nПри отказе заемщика от заключения договора личного страхования процентная ставка составит 15,99%\nОбеспечение по кредиту – залог приобретаемого автомобиля\n\nКомплектация 45 TFSI quattro S tronic\n\n\nПредложение обновлено 02 декабря 2020г. в 14 ч 39 мин.', 'discount_options': {}, 'documents': {'pts_original': True, 'custom_cleared': True, 'year': 2020, 'vin': 'WAU**************', 'pts': 'ORIGINAL'}, 'is_favorite': False, 'old_category_id': 15, 'owner_expenses': {'transport_tax': {'tax_by_year': 20543, 'year': 2020, 'rid': 213, 'rate': 75, 'horse_power': 249, 'holding_period_month': 12, 'boost': 1.1}, 'osago_insurance': [{'insurance_company': 'TINKOFF', 'price': 6309}]}, 'section': 'new', 'seller_type': 'COMMERCIAL', 'services': [{'service': 'all_sale_special', 'is_active': True, 'prolongable': False}, {'service': 'all_sale_premium', 'is_active': True, 'prolongable': False}, {'service': 'all_sale_toplist', 'is_active': True, 'prolongable': False}, {'service': 'all_sale_premium', 'is_active': True, 'prolongable': False}], 'status': 'ACTIVE', 'tags': ['oversize', 'medium', 'prestige', 'comfort', 'paris2016', 'fast', 'wide-back-seats', 'big-trunk', 'all-terrain', 'options', 'handling', 'economical', 'dealer_quarantine_calls', 'safe_car', 'redemption', 'new_car_old_price', 'priority_placement'], 'multiposting': {'classifieds': []}, 'additional_info': {'hidden': False, 'is_on_moderation': False, 'update_date': '1607082547000', 'creation_date': '1607067360000', 'mobile_autoservices_url': 'https://m.auto.ru/autoservice/all_works/AUDI/?geo_id=213', 'hot_info': {'is_hot': False, 'start_time': '2020-09-01T07:45:25Z', 'end_time': '2020-09-01T07:45:25Z'}, 'redemption_available': True, 'fresh_date': '1607067360000', 'counters_start_date': '1607067360000', 'chat_only': False, 'dealer_card_promo': 'SLEEP_PROMO', 'review_summary': {'avg_rating': 4.599999904632568, 'counter': 1}, 'price_stats': {'last_year_price_percentage_diff': -9}, 'booking': {}, 'match_application_form': {'contexts': ['listing', 'group_card', 'gallery', 'footer']}, 'days_in_stock': 95, 'days_on_sale': 95}, 'counters': {}, 'grouping_info': None, 'hash': '31009285', 'id': '1100471468', 'price_info': {'price': 3540000, 'currency': 'RUR', 'EUR': 39219, 'RUR': 3540000, 'USD': 47675, 'with_nds': False}, 'price_history': [{'EUR': 39219, 'RUR': 3540000, 'USD': 47675, ' ...
# {'availability': 'IN_STOCK', 'category': 'cars', 'color_hex': '97948F', 'delivery_info': {}, 'description': 'Безупречные условия в Ауди Центре Алтуфьево!\nПокупайте в Ауди Центр Алтуфьево - в самом крупном дилерском центре Европы!\nИндивидуальные условия покупки новых автомобилей Audi:\n\n- Кредит без первоначального взноса на Audi A3\n- Широкий выбор автомобилей в наличии с максимальным преимуществом от нового дилера\n- Бронируйте сейчас – платите потом\n- Гибкие условия обмена вашего автомобиля по программе трейд-ин с бонусом до 340 000 рублей\n- Уникальные кредитные программы от ООО «Фольксваген Банк РУС» от 0,7% с комфортными ежемесячными платежами\n- Дополнительные привилегии при покупке автомобиля в лизинг и доступ к закрытому корпоративному парку\n- 4 года гарантии на весь модельный ряд Audi\n- Индивидуальные подарки к каждому автомобилю\n- 5 этажей шоу-рума\n\nУ Вас есть предложение, которое кажется вам оптимальным? Позвоните нам, и мы подберем для Вас лучшие условия!\n*Цены на автомобили указаны с учетом скидок, подробности акций уточняйте у менеджеров.\n**Основные условия кредитования ПАО «Совкомбанк» (далее Банк) на покупку нового Audi A3 по продукту «Кредит на приобретение нового автомобиля» валюта кредита – рубли РФ; сумма кредита минимальная  800 тысяч руб до 4 900 000 млн руб. При первоначальном взносе 0%. Срок кредита от 6 мес до 84 мес.\nПроцентная ставка (в % годовых от 12,49% (два документа) и оформлении договора личного страхования, заключаемого в отношении заемщика. \nПри отказе заемщика от заключения договора личного страхования процентная ставка составит 15,99%\nОбеспечение по кредиту – залог приобретаемого автомобиля\n\nКомплектация 45 TFSI S tronic\n\n\nПредложение обновлено 02 декабря 2020г. в 14 ч 39 мин.', 'discount_options': {}, 'documents': {'pts_original': True, 'custom_cleared': True, 'year': 2020, 'vin': 'WAU**************', 'pts': 'ORIGINAL'}, 'is_favorite': False, 'old_category_id': 15, 'owner_expenses': {'transport_tax': {'tax_by_year': 18675, 'year': 2020, 'rid': 213, 'rate': 75, 'horse_power': 249, 'holding_period_month': 12, 'boost': 1}, 'osago_insurance': [{'insurance_company': 'TINKOFF', 'price': 6309}]}, 'section': 'new', 'seller_type': 'COMMERCIAL', 'services': [{'service': 'all_sale_special', 'is_active': True, 'prolongable': False}, {'service': 'all_sale_premium', 'is_active': True, 'prolongable': False}, {'service': 'all_sale_toplist', 'is_active': True, 'prolongable': False}, {'service': 'all_sale_premium', 'is_active': True, 'prolongable': False}], 'status': 'ACTIVE', 'tags': ['new4new', 'oversize', 'fast', 'options', 'handling', 'economical', 'medium', 'prestige', 'dealer_quarantine_calls', 'redemption', 'new_car_old_price', 'priority_placement'], 'multiposting': {'classifieds': []}, 'additional_info': {'hidden': False, 'is_on_moderation': False, 'update_date': '1607092275000', 'creation_date': '1607067356000', 'mobile_autoservices_url': 'https://m.auto.ru/autoservice/all_works/AUDI/?geo_id=213', 'hot_info': {'is_hot': False, 'start_time': '2020-10-06T13:04:29Z', 'end_time': '2020-10-06T13:04:29Z'}, 'redemption_available': True, 'fresh_date': '1607067356000', 'counters_start_date': '1607067356000', 'chat_only': False, 'dealer_card_promo': 'SLEEP_PROMO', 'review_summary': {}, 'price_stats': {'last_year_price_percentage_diff': -13}, 'booking': {}, 'match_application_form': {'contexts': ['listing', 'group_card', 'gallery', 'footer']}, 'days_in_stock': 60, 'days_on_sale': 60}, 'counters': {}, 'grouping_info': None, 'hash': 'bbad4373', 'id': '1101163122', 'price_info': {'price': 3677500, 'currency': 'RUR', 'EUR': 40743, 'RUR': 3677500, 'USD': 49527, 'with_nds': False}, 'price_history': [{'EUR': 40743, 'RUR': 3677500, 'USD': 49527, 'create_timestamp': 1607067665000}], 'recall_info': {}, 'saleId': '1101163122-bbad4373', 'salon': {'actual_stock': True, 'client_id': '41862', 'code': 'audi_centr_altufevo_moskva', 'dealer_id': '20730976', 'logo_url': '//avatars.mds.yandex.net/get-verba/997 ...
# {'availability': 'IN_STOCK', 'category': 'cars', 'color_hex': '200204', 'delivery_info': {}, 'description': 'ПТС оригинал, 1 владелец.\n\n。Подушка безопасности пассажира с функцией деактивации\n。Преднатяжители ремней безопасности\n。Quattro \n。Электронная блокировка дифференциала\n。Система контроля давления в шинах\n。Рекуперация энергии торможения\n。Автоматическая коррекция угла наклона фар\n。Сервотроник\n。Датчики парковки спереди и сзади\n。Обогрев  боковых зеркал\n。Обогрев форсунок стеклоомывателей\n。Атермальное остекление\n。Магнитола Concert\n。CD-проигрыватель\n。Поддержка MP3\n。8 и более динамиков\n。Многофункциональный цветной дисплей\n。Сабвуфер\n。2 комплекта ключей\n\n☛ Все заявленные автомобили находятся в наличии.\n☛ Два комплекта ключей.\n\nЦена действительна при соблюдении ряда условий.\n\n☛ Выгода по программе Trade-In до 50 тысяч рублей.\n☛ Выгода в кредит до 100 тысяч рублей.\n\n\n\n▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼\n\n                       Условия при покупке автомобиля в кредит:\n\n➥ Ставка от 4.9% годовых;\n➥ Первоначальный взнос от 0%;\n➥ Оформление по двум документам;\n➥ Срок кредитования от 6 месяцев до 7 лет;\n➥ Без оформления КАСКО;\n\n● При покупке автомобиля каждый клиент получает подарок на выбор: \n\n   ✔ Комплект резины.\n   ✔ Полное комплексное ТО. \n   ✔ Страховой полис ОСАГО сроком на 3 месяца.\n\n● Приглашаем на бесплатный тест-драйв! Подробную информацию можно получить у специалистов автоцентра по телефону.\n● Мы работаем до последнего клиента.', 'discount_options': {'credit': 100000, 'max_discount': 100000}, 'documents': {'owners_number': 1, 'pts_original': True, 'custom_cleared': True, 'year': 2012, 'vin': 'WAU**************', 'pts': 'ORIGINAL', 'vin_resolution': 'OK'}, 'is_favorite': False, 'old_category_id': 15, 'owner_expenses': {'transport_tax': {'tax_by_year': 40650, 'year': 2020, 'rid': 213, 'rate': 150, 'horse_power': 271, 'holding_period_month': 12, 'boost': 1}, 'osago_insurance': [{'insurance_company': 'TINKOFF', 'price': 6309}]}, 'section': 'used', 'seller_type': 'COMMERCIAL', 'status': 'ACTIVE', 'tags': ['oversize', 'medium', 'fivestars', 'prestige', 'excellent_price', 'allowed_for_credit', 'wide-back-seats', 'big-trunk', 'all-terrain', 'vin_offers_history', 'options', 'discount_options', 'handling', 'vin_resolution_ok', 'vin_checked', 'one_owner', 'dealer_quarantine_calls', 'pts_original', 'equitable_price', 'safe_car', 'redemption'], 'multiposting': {'classifieds': []}, 'additional_info': {'hidden': False, 'is_on_moderation': False, 'exchange': True, 'update_date': '1607112632000', 'creation_date': '1607088593000', 'mobile_autoservices_url': 'https://m.auto.ru/autoservice/all_works/AUDI/?geo_id=213', 'hot_info': {'is_hot': False, 'start_time': '2020-10-17T09:09:22Z', 'end_time': '2020-10-17T09:09:22Z'}, 'redemption_available': True, 'fresh_date': '1607088593000', 'counters_start_date': '1607088593000', 'chat_only': False, 'dealer_card_promo': 'SLEEP_PROMO', 'review_summary': {'avg_rating': 4, 'counter': 31}, 'price_stats': {'last_year_price_percentage_diff': -7}, 'booking': {}, 'days_in_stock': 49, 'days_on_sale': 49}, 'counters': {}, 'grouping_info': None, 'hash': '15a8cefb', 'id': '1101280941', 'price_info': {'price': 949000, 'currency': 'RUR', 'EUR': 10514, 'RUR': 949000, 'USD': 12781, 'with_nds': False}, 'price_history': [{'EUR': 10514, 'RUR': 949000, 'USD': 12781, 'create_timestamp': 1607089054000}], 'recall_info': {}, 'saleId': '1101280941-15a8cefb', 'salon': {'actual_stock': True, 'client_id': '40782', 'code': 'avtograd_moskva', 'dealer_id': '21521943', 'logo_url': '//avatars.mds.yandex.net/get-verba/997355/2a0000016e3aaabd850c1eb1ef055fcedc9c/dealer_logo', 'offer_counters': {'cars_all': 144}, 'name': 'Автоградъ', 'phones': [{'phone': '+7 495 023-45-12'}], 'place': {'address': 'Варшавское шоссе, 170Е', 'coord': {'latitude': 55.580192, 'longitude': 37.587137}, 'geobase_id': '213', 'region_info': {'id': '213', 'name': 'Москва', 'genitive': 'Москвы', 'dative': 'Москве', 'accusative' ...

# %%
dict_columns
# Out:
# {'bodyType': 0,
#  'brand': 0,
#  'color': 0,
#  'fuelType': 0,
#  'modelDate': 0,
#  'name': 0,
#  'numberOfDoors': 0,
#  'productionDate': 0,
#  'vehicleConfiguration': 0,
#  'vehicleTransmission': 0,
#  'engineDisplacement': 0,
#  'enginePower': 0,
#  'description': 0,
#  'mileage': 0,
#  'Комплектация': 0,
#  'Привод': 0,
#  'Руль': 0,
#  'Состояние': 0,
#  'Владельцы': 0,
#  'ПТС': 'ORIGINAL',
#  'Таможня': 0,
#  'Владение': 0,
#  'price': 0}

# %%
dict_columns = {'bodyType':0, 'brand':0, 'color':0, 'fuelType':0, 'modelDate':0, 
                'name':0, 'numberOfDoors':0, 'productionDate':0, 
                'vehicleConfiguration':0, 'vehicleTransmission':0, 
                'engineDisplacement':0, 'enginePower':0, 'description':0, 
                'mileage':0, 'Комплектация':0, 'Привод':0, 'Руль':0, 
                'Состояние':0, 'Владельцы':0, 'ПТС':0, 'Таможня':0, 
                'Владение':0,'price':0, }

# создаем функцию для обработки 23 необходимых столбцов
def from_elem_to_dict(d_elem, d_dict):
    utils_clean_values_dict(d_dict)
    
    try: d_dict['bodyType'] = d_elem['vehicle_info']['configuration']['human_name']
    except: d_dict['bodyType'] = None
    
    try d_dict['model'] = d_elem['vehicle_info']['model_info']['code']
    except: d_dict['model'] = None
        
auto_ru = {}

iter_of_ads, iter_of_marks, old_iter_of_ads, sum_ads, sum_ads_from_dict = 0,0,0,0,0
space = ' '

for mark in list_of_relevant_marks:
    #list_of_models = json.loads(df_marks_and_models.loc[mark, 'Models'].replace("'", '"'))
    #for model in list_of_models:
    for num_page in range(1, 2):
        param = {
                'catalog_filter' : [{"mark": mark}],
                'section': "all",
                'category': "cars",
                'sort': "fresh_relevance_1-desc",
                "top_days":"900",
                "geo_radius":200,
                "geo_id":[213],
                'page': num_page
            }
        response = requests.post(url, json=param, headers = HEADERS)
        data = response.json()
        #print(data)
        if data['offers'] != []:
            for elem in data['offers']:
                from_elem_to_dict(elem, dict_columns)
                auto_ru[iter_of_ads] = dict_columns.copy()
                iter_of_ads += 1
        else:
            break

# %%
'model_info': {'code': 'A6', 'name': 'A6', 'ru_name': 'А6', 'morphology': {}, 'nameplate': {'code': '', 'name': '', 'semantic_url': ''}}
'documents': {'owners_number': 2, 'pts_original': True, 'custom_cleared': True, 'year': 2012, 'vin': 'WAU**************', 'pts': 'ORIGINAL', 'license_plate': '******|790', 'vin_resolution': 'OK'},

# %%
auto_ru = {}

iter_of_ads, iter_of_marks, old_iter_of_ads, sum_ads, sum_ads_from_dict = 0,0,0,0,0
space = ' '
start_time_global = time.perf_counter()
df_marks= []
for mark in list_of_relevant_marks:
    start_time = time.perf_counter()
    #list_of_models = json.loads(df_marks_and_models.loc[mark, 'Models'].replace("'", '"'))
    #for model in list_of_models:
    for num_page in range(1, 2):
        param = {
                'catalog_filter' : [{"mark": mark}],
                'section': "all",
                'category': "cars",
                'sort': "fresh_relevance_1-desc",
                "top_days":"900",
                "geo_radius":200,
                "geo_id":[213],
                'page': num_page
            }
        response = requests.post(url, json=param, headers = HEADERS)
        data = response.json()
        #print(data)
        
        if data['offers'] != []:
            for elem in data['offers']:
                from_elem_to_dict(elem, dict_columns)
                auto_ru[iter_of_ads] = dict_columns.copy()
                iter_of_ads += 1
    
                a = elem['vehicle_info']['mark_info']['code']
                if a in df_marks:
                    pass
                else:
                    df_marks.append(a)
                
        else:
            break
            
    iter_of_marks +=1
    temp_1 = iter_of_ads-old_iter_of_ads
    temp_2 = dict_of_num_cars_of_models[mark]
    temp_3 = temp_1/temp_2
    temp_4 = space*abs(13-len(mark)-len(str(iter_of_marks)))
    temp_5 = int(time.perf_counter() - start_time)
    temp_8 = round(temp_3*100,2)
    temp_7 = space*abs(18-len(str(temp_1))-len(str(temp_2))-len(str(temp_8))-len(str(temp_5)))
    temp_9 = int(time.perf_counter() - start_time_global)
    

    sum_ads += temp_1
    sum_ads_from_dict += temp_2
    temp_def = sum_ads/sum_ads_from_dict
    temp_6 = (sum_of_ads*temp_def - iter_of_ads)*temp_9/sum_ads


    print (f'{iter_of_marks}.{mark} {temp_4} ушло:{temp_5} сек., стр. {temp_1} из {temp_2} {temp_8}%,{temp_7}всего стр. {iter_of_ads}, прогноз {int(temp_6/60)} мин.')

    old_iter_of_ads=iter_of_ads

#print (f'Всего спарсили := {iter_of_ads} строк, на это ушло: {int((time.perf_counter() - start_time_global)/60)} мин., ')
# Out:
# 1.AUDI          ушло:1 сек., стр. 38 из 4093 0.93%,       всего стр. 38, прогноз 0 мин.
# 2.BMW           ушло:0 сек., стр. 38 из 7423 0.51%,       всего стр. 76, прогноз 0 мин.
# 3.CADILLAC      ушло:0 сек., стр. 38 из 321 11.84%,       всего стр. 114, прогноз 0 мин.
# 4.CHERY         ушло:0 сек., стр. 38 из 593 6.41%,        всего стр. 152, прогноз 0 мин.
# 5.CHEVROLET     ушло:0 сек., стр. 38 из 3670 1.04%,       всего стр. 190, прогноз 0 мин.
# 6.CHRYSLER      ушло:0 сек., стр. 38 из 316 12.03%,       всего стр. 228, прогноз 0 мин.
# 7.CITROEN       ушло:1 сек., стр. 38 из 1142 3.33%,       всего стр. 266, прогноз 0 мин.
# 8.DAEWOO        ушло:0 сек., стр. 38 из 1024 3.71%,       всего стр. 304, прогноз 0 мин.
# 9.DODGE         ушло:0 сек., стр. 38 из 413 9.2%,         всего стр. 342, прогноз 0 мин.
# 10.FORD         ушло:0 сек., стр. 38 из 4812 0.79%,       всего стр. 380, прогноз 0 мин.
# 11.GEELY        ушло:0 сек., стр. 38 из 302 12.58%,       всего стр. 418, прогноз 0 мин.
# 12.HONDA        ушло:0 сек., стр. 38 из 1179 3.22%,       всего стр. 456, прогноз 0 мин.
# 13.HYUNDAI      ушло:0 сек., стр. 38 из 5712 0.67%,       всего стр. 494, прогноз 0 мин.
# 14.INFINITI     ушло:0 сек., стр. 38 из 1041 3.65%,       всего стр. 532, прогноз 0 мин.
# 15.JAGUAR       ушло:0 сек., стр. 38 из 308 12.34%,       всего стр. 570, прогноз 0 мин.
# 16.JEEP         ушло:0 сек., стр. 37 из 466 7.94%,        всего стр. 607, прогноз 0 мин.
# 17.KIA          ушло:0 сек., стр. 38 из 5595 0.68%,       всего стр. 645, прогноз 0 мин.
# 18.LEXUS        ушло:0 сек., стр. 38 из 985 3.86%,        всего стр. 683, прогноз 0 мин.
# 19.MAZDA        ушло:0 сек., стр. 38 из 2311 1.64%,       всего стр. 721, прогноз 0 мин.
# 20.MINI         ушло:0 сек., стр. 38 из 313 12.14%,       всего стр. 759, прогноз 0 мин.
# 21.MITSUBISHI   ушло:0 сек., стр. 38 из 3935 0.97%,       всего стр. 797, прогноз 0 мин.
# 22.NISSAN       ушло:0 сек., стр. 38 из 5776 0.66%,       всего стр. 835, прогноз 0 мин.
# 23.OPEL         ушло:0 сек., стр. 38 из 3131 1.21%,       всего стр. 873, прогноз 0 мин.
# 24.PEUGEOT      ушло:0 сек., стр. 38 из 1636 2.32%,       всего стр. 911, прогноз 0 мин.
# 25.PORSCHE      ушло:0 сек., стр. 38 из 714 5.32%,        всего стр. 949, прогноз 0 мин.
# 26.RENAULT      ушло:0 сек., стр. 38 из 2771 1.37%,       всего стр. 987, прогноз 0 мин.
# 27.SKODA        ушло:0 сек., стр. 38 из 2810 1.35%,       всего стр. 1025, прогноз 0 мин.
# 28.SUBARU       ушло:0 сек., стр. 38 из 934 4.07%,        всего стр. 1063, прогноз 0 мин.
# 29.SUZUKI       ушло:0 сек., стр. 38 из 878 4.33%,        всего стр. 1101, прогноз 0 мин.
# 30.TOYOTA       ушло:0 сек., стр. 38 из 4648 0.82%,       всего стр. 1139, прогноз 0 мин.
# 31.VOLKSWAGEN   ушло:0 сек., стр. 38 из 7109 0.53%,       всего стр. 1177, прогноз 0 мин.
# 32.VOLVO        ушло:0 сек., стр. 38 из 2069 1.84%,       всего стр. 1215, прогноз 0 мин.
# 33.GREAT_WALL   ушло:0 сек., стр. 38 из 420 9.05%,        всего стр. 1253, прогноз 0 мин.
# 34.LAND_ROVER   ушло:0 сек., стр. 38 из 1616 2.35%,       всего стр. 1291, прогноз 0 мин.
# 35.MERCEDES     ушло:0 сек., стр. 38 из 8005 0.47%,       всего стр. 1329, прогноз 0 мин.
# 36.SSANG_YONG   ушло:0 сек., стр. 37 из 718 5.15%,        всего стр. 1366, прогноз 0 мин.

# %%
print(df_marks)
# Out:
# ['AUDI', 'BMW', 'CADILLAC', 'CHERY', 'CHEVROLET', 'CHRYSLER', 'CITROEN', 'DAEWOO', 'DODGE', 'FORD', 'GEELY', 'HONDA', 'HYUNDAI', 'INFINITI', 'JAGUAR', 'JEEP', 'KIA', 'LEXUS', 'MAZDA', 'MINI', 'MITSUBISHI', 'NISSAN', 'OPEL', 'PEUGEOT', 'PORSCHE', 'RENAULT', 'SKODA', 'SUBARU', 'SUZUKI', 'TOYOTA', 'VOLKSWAGEN', 'VOLVO', 'GREAT_WALL', 'LAND_ROVER', 'MERCEDES', 'SSANG_YONG']

# %%
df_auto_ru = pd.DataFrame(auto_ru).T
df_auto_ru.head(3)

# %%
# запись датасета
df_auto_ru = pd.DataFrame(auto_ru).T
df_auto_ru.to_csv('all_auto_ru.csv', index=False)
print(f'кол-во строк датасета:= {len(df_auto_ru)}')

# %%
pd.read_csv('all_auto_ru.csv').head(2)
